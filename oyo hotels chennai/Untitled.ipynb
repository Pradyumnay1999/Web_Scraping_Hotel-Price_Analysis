# %%
import numpy as np
import pandas as pd

# %%
import requests
from bs4 import BeautifulSoup
import time

# %%
url='https://www.oyorooms.com/search?location=Chennai%2C%20Tamil%20Nadu%2C%20India&city=Chennai&searchType=city&coupon=&checkin=13%2F11%2F2022&checkout=14%2F11%2F2022&roomConfig%5B%5D=2&showSearchElements=false&guests=2&rooms=1&countryName=India&country=india&filters%5Bcity_id%5D=12'

# %%
page = requests.get(url, headers={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36'})
print(page.status_code)       #page = requests.get(url)
# Out:
# 200

# %%
pagecontent = page.text
pagecontent
# Out:
# '\n    <!doctype html>\n    <html lang="en" dir=ltr>\n    <head>\n      <meta charSet="utf-8" />\n      <meta httpEquiv="x-ua-compatible" content="ie=edge; chrome=1" />\n      <meta name="google-site-verification" content="lCkLu-7S0Eb5LOgDgmoWxSWzbopNfzKW01ZEe3ldsOc" />\n      <script type="text/javascript">\n      \twindow.renderingSource=\'server\'\n        var host = window.location.hostname;\n        if (!String.prototype.endsWith) {\n\t        String.prototype.endsWith = function(search, this_len) {\n\t\t        if (this_len === undefined || this_len > this.length) {\n\t\t\t        this_len = this.length;\n\t\t        }\n\t      \t  return this.substring(this_len - search.length, this_len) === search;\n\t        };\n        }\n        if (! (host.endsWith("oyorooms.com") || host.endsWith("oyorooms.ms") || host.endsWith("oyohotels.co.jp") || host.endsWith("hotelesoyo.com") || host.endsWith("oyohotels.com") || host.endsWith("belvilla.co.in") || host.endsWith("oyorooms.io")) && host.indexOf(\'localhost\') < 0){\n          window.location.href="https://www.oyorooms.com";\n        }\n        </script>\n      <meta httpEquiv="content-language" content="en-IN" />\n      <meta name="viewport" content="width=device-width, initial-scale=1.0, user-scalable=0, minimum-scale=1.0" />\n      \n      <meta name="full-screen" content="yes" />\n\n      <meta name="theme-color" content="#F5F5F5" />\n      <link rel="manifest" href="/manifest.json" />\n      <link rel="alternate" href="android-app://com.oyo.consumer/https/www.oyorooms.com/" />\n      <meta name="google" content="notranslate" />\n\n      <meta name="apple-mobile-web-app-capable" content="yes">\n      <meta name="mobile-web-app-capable" content="yes">\n\n\n      <link rel="preconnect" href="https://assets.oyoroomscdn.com" />\n      <link rel="preconnect" href="https://images.oyoroomscdn.com" />\n      <link rel="preconnect" href="https://cdn.moengage.com" />\n      <link rel="preconnect" href="https://www.google-analytics.com" />\n      <link rel="dns-prefetch" href="https://assets.oyoroomscdn.com" />\n      <link rel="dns-prefetch" href="https://images.oyoroomscdn.com" />\n      <link rel="dns-prefetch" href="https://cdn.moengage.com" />\n      <link rel="dns-prefetch" href="https://www.google-analytics.com" />\n      <link href=/assets/desktop/main.e953701e38dac851bad4.css rel="stylesheet" type="text/css" />\n      <link href=/assets/desktop/commoncss.4b11f9835e190a537f3c.css rel="stylesheet" type="text/css" />\n      <link href=/assets/desktop/listing.f60cc288d2f35137d287.css rel="stylesheet" type="text/css" />\n      <script type="text/javascript">\n          window.trackingId = "UA-52365165-1";\n          window.user_id = undefined || \'\';\n          (function(i,s,o,g,r,a,m){i[\'GoogleAnalyticsObject\']=r;i[r]=i[r]||function(){\n                      (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),\n                  m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)\n          })(window,document,\'script\',\'https://www.google-analytics.com/analytics.js\',\'ga\');\n          ga(\'create\', {\n              userId : window.user_id || \'\',\n              trackingId: window.trackingId,\n              cookieDomain: \'auto\',\n              siteSpeedSampleRate: 30,\n              useAmpClientId: true,\n              cookieFlags: "SameSite=None; Secure"\n          });\n          ga(\'require\',\'ec\');\n      </script>\n\n      <script type="application/ld+json">\n        {\n          "@context": "https://schema.org/",\n          "@type": "Organization",\n          "name": "OYO Rooms",\n          "url":"https://www.oyorooms.com/",\n          "logo":"https://www.oyorooms.com/favicon.ico",\n          "sameAs":["https://www.facebook.com/oyorooms", "https://twitter.com/oyorooms", "https://www.pinterest.com/oyorooms/", "https://plus.google.com/u/0/116027434827284400729/posts"],\n          "contactPoint":{\n            "@t ...

# %%
soup = BeautifulSoup(pagecontent)
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# <html dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="ie=edge; chrome=1" httpequiv="x-ua-compatible"/>
# <meta content="lCkLu-7S0Eb5LOgDgmoWxSWzbopNfzKW01ZEe3ldsOc" name="google-site-verification"/>
# <script type="text/javascript">
#       	window.renderingSource='server'
#         var host = window.location.hostname;
#         if (!String.prototype.endsWith) {
# 	        String.prototype.endsWith = function(search, this_len) {
# 		        if (this_len === undefined || this_len > this.length) {
# 			        this_len = this.length;
# 		        }
# 	      	  return this.substring(this_len - search.length, this_len) === search;
# 	        };
#         }
#         if (! (host.endsWith("oyorooms.com") || host.endsWith("oyorooms.ms") || host.endsWith("oyohotels.co.jp") || host.endsWith("hotelesoyo.com") || host.endsWith("oyohotels.com") || host.endsWith("belvilla.co.in") || host.endsWith("oyorooms.io")) && host.indexOf('localhost') < 0){
#           window.location.href="https://www.oyorooms.com";
#         }
#         </script>
# <meta content="en-IN" httpequiv="content-language"/>
# <meta content="width=device-width, initial-scale=1.0, user-scalable=0, minimum-scale=1.0" name="viewport"/>
# <meta content="yes" name="full-screen"/>
# <meta content="#F5F5F5" name="theme-color"/>
# <link href="/manifest.json" rel="manifest"/>
# <link href="android-app://com.oyo.consumer/https/www.oyorooms.com/" rel="alternate"/>
# <meta content="notranslate" name="google"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="yes" name="mobile-web-app-capable"/>
# <link href="https://assets.oyoroomscdn.com" rel="preconnect"/>
# <link href="https://images.oyoroomscdn.com" rel="preconnect"/>
# <link href="https://cdn.moengage.com" rel="preconnect"/>
# <link href="https://www.google-analytics.com" rel="preconnect"/>
# <link href="https://assets.oyoroomscdn.com" rel="dns-prefetch"/>
# <link href="https://images.oyoroomscdn.com" rel="dns-prefetch"/>
# <link href="https://cdn.moengage.com" rel="dns-prefetch"/>
# <link href="https://www.google-analytics.com" rel="dns-prefetch"/>
# <link href="/assets/desktop/main.e953701e38dac851bad4.css" rel="stylesheet" type="text/css"/>
# <link href="/assets/desktop/commoncss.4b11f9835e190a537f3c.css" rel="stylesheet" type="text/css"/>
# <link href="/assets/desktop/listing.f60cc288d2f35137d287.css" rel="stylesheet" type="text/css"/>
# <script type="text/javascript">
#           window.trackingId = "UA-52365165-1";
#           window.user_id = undefined || '';
#           (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#                       (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#                   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#           })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#           ga('create', {
#               userId : window.user_id || '',
#               trackingId: window.trackingId,
#               cookieDomain: 'auto',
#               siteSpeedSampleRate: 30,
#               useAmpClientId: true,
#               cookieFlags: "SameSite=None; Secure"
#           });
#           ga('require','ec');
#       </script>
# <script type="application/ld+json">
#         {
#           "@context": "https://schema.org/",
#           "@type": "Organization",
#           "name": "OYO Rooms",
#           "url":"https://www.oyorooms.com/",
#           "logo":"https://www.oyorooms.com/favicon.ico",
#           "sameAs":["https://www.facebook.com/oyorooms", "https://twitter.com/oyorooms", "https://www.pinterest.com/oyorooms/", "https://plus.google.com/u/0/116027434827284400729/posts"],
#           "contactPoint":{
#             "@type":"ContactPoint",
#             "telephone":"+91 9313 9313 93",
#             "contactType":"Customer Service"
#           }
#         }
#       </script>
# <title data-react-helmet="true">Hotels in Chennai Starting @ ₹368 - Upto 81% OFF on 157 Chennai Hotels</title>
# <meta content="https://www.facebook.com/oyorooms" data-react-helmet="true" property="og:publisher"/><meta content="/search/?location=Chennai%2C%20Tamil%20Nadu%2C%20India&amp;city=Chennai&amp;searchType=city&amp;coupon=&amp;checkin=13%2F11%2F2022&amp;checkout=14%2F11%2F2022&amp;roomConfig%5B%5D=2&amp;showSearchElements=false&amp;guests=2&amp;rooms=1&amp;countryName=India&amp;country=india&amp;filters%5Bcity_id%5D=12" data-react-helmet="true" property="og:url"/><meta content="1576475359296300" data-react-helmet="true" property="fb:app_id"/><meta content="app" data-react-helmet="true" name="twitter:card"/><meta content="in" data-react-helmet="true" name="twitter:app:country"/><meta content="OYO Rooms" data-react-helmet="true" name="twitter:text:title"/><meta content="https://assets.oyoroomscdn.com/pwa/icons/oyo-logo-120x120.jpg" data-react-helmet="true" name="twitter:image"/><meta content="Book Hotels in Chennai &amp; Save up to 81%, Price starts @₹368. OYO Promises &amp;#9989Complimentary Breakfast &amp;#9989Free Cancellation &amp;#9989Free WiFi &amp;#9989AC Room &amp;#9989Spotless linen &amp; &amp;#9989Clean Washrooms." data-react-helmet="true" name="description"/><meta content="OYO Rooms, OYO Hotels, OYO Inn, Budget Hotels, Guest House, Budget Hotels in Gurgaon, Guest House in Gurgaon, Budget Hotels in Delhi, Guest House in Delhi, Budget Hotels in Noida, Guest House in Noida, Budget Hotels in Bangalore, Guest House in Bangalore, Budget Hotels in Mumbai, Guest House in Mumbai, Cheap Hotels in Delhi, Cheap Hotels in Gurgaon, Cheap Hotels in Noida, Cheap Hotels in Bangalore, Cheap Hotels in Mumbai" data-react-helmet="true" name="keywords"/><meta content="Hotels in Chennai Starting @ ₹368 - Upto 81% OFF on 157 Chennai Hotels" data-react-helmet="true" property="og:title"/><meta content="Book Hotels in Chennai &amp; Save up to 81%, Price starts @₹368. OYO Promises &amp;#9989Complimentary Breakfast &amp;#9989Free Cancellation &amp;#9989Free WiFi &amp;#9989AC Room &amp;#9989Spotless linen &amp; &amp;#9989Clean Washrooms." data-react-helmet="true" property="og:description"/><meta content="Hotels in Chennai Starting @ ₹368 - Upto 81% OFF on 157 Chennai Hotels" data-react-helmet="true" name="twitter:title"/><meta content="Book Hotels in Chennai &amp; Save up to 81%, Price starts @₹368. OYO Promises &amp;#9989Complimentary Breakfast &amp;#9989Free Cancellation &amp;#9989Free WiFi &amp;#9989AC Room &amp;#9989Spotless linen &amp; &amp;#9989Clean Washrooms." data-react-helmet="true" name="twitter:description"/><meta content="OYO Rooms" data-react-helmet="true" property="og:site_name"/><meta content="https://images.oyoroomscdn.com/uploads/hotel_image/14677/6d3ecdb2a3450322.jpg" data-react-helmet="true" property="og:image"/><meta content="hotel" data-react-helmet="true" property="og:type"/><meta content="https://www.oyorooms.com/" data-react-helmet="true" name="twitter:url"/><meta content="NOINDEX, NOFOLLOW" data-react-helmet="true" name="ROBOTS"/><meta content="unavailable_after: Wednesday, 01-Jan-20 01:00:00 IST" data-react-helmet="true" name="robots"/>
# <link data-react-helmet="true" href="https://www.oyorooms.com/favicon.ico" rel="icon"/><link data-react-helmet="true" href="https://www.oyorooms.com/favicon.ico" rel="icon" sizes="48x48" type="image/x-icon"/><link data-react-helmet="true" href="https://assets.oyoroomscdn.com/pwa/icons/oyo-logo-48x48.jpg" rel="apple-touch-icon" sizes="48x48"/><link data-react-helmet="true" href="https://assets.oyoroomscdn.com/pwa/icons/oyo-logo-76x76.jpg" rel="apple-touch-icon" sizes="76x76"/><link data-react-helmet="true" href="https://assets.oyoroomscdn.com/pwa/icons/oyo-logo-120x120.jpg" rel="apple-touch-icon" sizes="120x120"/><link data-react-helmet="true" href="https://assets.oyoroomscdn.com/pwa/icons/oyo-logo-152x152.jpg" rel="apple-touch-icon" sizes="152x152"/><link data-react-helmet="true" href="/" rel="canonical"/>
# <link as="script" href="/assets/desktop/runtime.d4e4471e99372df5fcc3.js" rel="preload"/>
# <link as="script" href="/assets/desktop/externalvendor.1fd4612a45561d7117bb.js" rel="preload"/>
# <link as="script" href="/assets/desktop/common.cb6bb20e01d65d694f3a.js" rel="preload"/>
# <link as="script" href="/assets/desktop/commoncss.209925228a244e033ddd.js" rel="preload"/>
# <link as="script" href="/assets/desktop/listing.06b76248591c9a1458b8.js" rel="preload"/>
# <link as="script" href="/assets/desktop/main.6059aab2c8be16cb6f0a.js" rel="preload"/>
# </head>
# <body itemscope="" itemtype="http://schema.org/WebPage">
# <script type="text/javascript">
#             window.abExpConfig = {"sold":{"val":0,"v":1},"mww2":{"val":"1","v":"4"},"hbad":{"val":0,"v":1},"BnTc":{"val":0,"v":1},"near":{"val":0,"v":1},"ioab":{"val":"1","v":"2"},"mhdp":{"val":"1","v":"5"},"bcrp":{"val":"1","v":"5"},"pwbs":{"val":"1","v":"3"},"mwsb":{"val":0,"v":1},"slin":{"val":"1","v":"11"},"hsdm":{"val":"2","v":"2"},"lpex":{"val":0,"v":1},"lphv":{"val":0,"v":1},"dpcv":{"val":0,"v":1},"gmab":{"val":0,"v":1},"urhe":{"val":0,"v":1},"prdp":{"val":0,"v":1},"comp":{"val":"0","v":"5"},"sldw":{"val":0,"v":1},"mdab":{"val":0,"v":1},"nrmp":{"val":"1","v":"3"},"nhyw":{"val":"1","v":"1"},"wboi":{"val":0,"v":1},"sst":{"val":0,"v":1},"txwb":{"val":0,"v":1},"pod2":{"val":0,"v":1},"lnhd":{"val":0,"v":1},"ppsi":{"val":"0","v":"1"},"gcer":{"val":"1","v":"3"},"recs":{"val":"1","v":"1"},"swhp":{"val":0,"v":1},"lvhm":{"val":"1","v":"3"},"gmbr":{"val":"1","v":"15"},"yolo":{"val":"1","v":"6"},"rcta":{"val":"1","v":"3"},"cbot":{"val":"1","v":"5"},"otpv":{"val":"1","v":"7"},"trtr":{"val":0,"v":1},"lbhw":{"val":0,"v":1},"ndbp":{"val":"0","v":"2"},"mapu":{"val":"1","v":"3"},"nclc":{"val":"1","v":"5"},"dwsl":{"val":"1","v":"2"},"eopt":{"val":"1","v":"3"},"wizi":{"val":"1","v":"2"},"morr":{"val":"1","v":"2"},"yopb":{"val":"0","v":"3"},"TTP":{"val":"1","v":"4"},"Dweb":{"val":"1","v":1},"aimw":{"val":"1","v":"2"},"hdpn":{"val":"1","v":"4"},"web2":{"val":"0","v":"3"},"log2":{"val":"0","v":"3"},"spw1":{"val":0,"v":1},"strf":{"val":0,"v":1},"ugce":{"val":"0","v":"2"},"ltvr":{"val":"1","v":"4"},"hwiz":{"val":"0","v":"3"},"wizz":{"val":"1","v":"5"},"lpcp":{"val":"0","v":"2"},"clhp":{"val":"0","v":"2"},"prwt":{"val":"0","v":"2"},"cbhd":{"val":"0","v":"2"},"ins2":{"val":"2","v":"8"}};
#
#             // SW-INSTALLATION
#             (function() {
#               if ('serviceWorker' in navigator ) {
#                   window.addEventListener('load', function(){
#                     navigator.serviceWorker.register("/service-worker-desktop.js",{scope: "/"});
#                   });
#               }
#           })();
#         </script>
# <div id="root" style="height:100vh;"><style data-emotion-c="1acbpvw r9lts4 g49e0i 1iupfd9 s2hsb0 162c9d0 8ijf8a p2g0oj jj695s xotlao 1t05q14 mk5v0g bxjamc 1x32axc g7fw8n gcjisk qwx4r ml1sc2">@-webkit-keyframes animation-1acbpvw{0%{opacity:0;}100%{opacity:1;}}@keyframes animation-1acbpvw{0%{opacity:0;}100%{opacity:1;}}@-webkit-keyframes animation-r9lts4{0%{background-position:-350px 0;}100%{background-position:350px 0;}}@keyframes animation-r9lts4{0%{background-position:-350px 0;}100%{background-position:350px 0;}}@-webkit-keyframes animation-g49e0i{from{-webkit-transform:translate3d(0,-100 %,0);-ms-transform:translate3d(0,-100 %,0);transform:translate3d(0,-100 %,0);visibility:visible;}to{-webkit-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);transform:translate3d(0,0,0);}}@keyframes animation-g49e0i{from{-webkit-transform:translate3d(0,-100 %,0);-ms-transform:translate3d(0,-100 %,0);transform:translate3d(0,-100 %,0);visibility:visible;}to{-webkit-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);transform:translate3d(0,0,0);}}@-webkit-keyframes animation-1iupfd9{from{-webkit-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);transform:translate3d(0,0,0);}to{visibility:hidden;-webkit-transform:translate3d(0,-100 %,0);-ms-transform:translate3d(0,-100 %,0);transform:translate3d(0,-100 %,0);}}@keyframes animation-1iupfd9{from{-webkit-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);transform:translate3d(0,0,0);}to{visibility:hidden;-webkit-transform:translate3d(0,-100 %,0);-ms-transform:translate3d(0,-100 %,0);transform:translate3d(0,-100 %,0);}}@-webkit-keyframes animation-s2hsb0{from{-webkit-transform:translate3d(100 %,0,0);-ms-transform:translate3d(100 %,0,0);transform:translate3d(100 %,0,0);visibility:visible;}to{-webkit-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);transform:translate3d(0,0,0);}}@keyframes animation-s2hsb0{from{-webkit-transform:translate3d(100 %,0,0);-ms-transform:translate3d(100 %,0,0);transform:translate3d(100 %,0,0);visibility:visible;}to{-webkit-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);transform:translate3d(0,0,0);}}@-webkit-keyframes animation-162c9d0{from{-webkit-transform:translate3d(0,100 %,0);-ms-transform:translate3d(0,100 %,0);transform:translate3d(0,100 %,0);visibility:visible;}to{-webkit-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);transform:translate3d(0,0,0);}}@keyframes animation-162c9d0{from{-webkit-transform:translate3d(0,100 %,0);-ms-transform:translate3d(0,100 %,0);transform:translate3d(0,100 %,0);visibility:visible;}to{-webkit-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);transform:translate3d(0,0,0);}}@-webkit-keyframes animation-8ijf8a{from{-webkit-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);transform:translate3d(0,0,0);}to{visibility:hidden;-webkit-transform:translate3d(100 %,0,0);-ms-transform:translate3d(100 %,0,0);transform:translate3d(100 %,0,0);}}@keyframes animation-8ijf8a{from{-webkit-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);transform:translate3d(0,0,0);}to{visibility:hidden;-webkit-transform:translate3d(100 %,0,0);-ms-transform:translate3d(100 %,0,0);transform:translate3d(100 %,0,0);}}@-webkit-keyframes animation-p2g0oj{from{-webkit-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);transform:translate3d(0,0,0);opacity:0;}to{opacity:1;-webkit-transform:translate3d(0,100%,0);-ms-transform:translate3d(0,100%,0);transform:translate3d(0,100%,0);}}@keyframes animation-p2g0oj{from{-webkit-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);transform:translate3d(0,0,0);opacity:0;}to{opacity:1;-webkit-transform:translate3d(0,100%,0);-ms-transform:translate3d(0,100%,0);transform:translate3d(0,100%,0);}}@-webkit-keyframes animation-jj695s{0%{-webkit-transform:scale(1) translate3d(0,0,0);-ms-transform:scale(1) translate3d(0,0,0);transform:scale(1) translate3d(0,0,0);-webkit-transform-origin:50% 16%;-ms-transfo ...
# <script>
#           window.__PRELOADED_STATE__ = {"home":{"loading":true,"error":null,"data":[{"data":{"left_icons":[{"icon_name":"OyoIcon","icon_title":"","icon_description":"","cta":{"type":"","data":{"action_url":"/"}}}],"right_icons":[{"icon_name":"Text","icon_title":"About us","icon_description":"","cta":{"type":"","data":{"action_url":"https://www.oyorooms.com/about"}}},{"icon_name":"Text","icon_title":"Partner with us","icon_description":"","cta":{"type":"","data":{"action_url":"https://partner.oyorooms.com/?utm_campaign=dweb&utm_medium=dweb&utm_source=dweb"}}},{"icon_name":"TextWithBorder","icon_title":"Login","icon_description":"","show_sticky":true,"cta":{"type":"","data":{"action_url":"https://www.oyorooms.com/login?country=us&retUrl=/us"}}}],"search_data":{"hint":"Search for a city or hotel","show_near_me":true,"near_me_data":{"icon_name":"near me","icon_title":"Near me","icon_description":"","cta":{"type":"","data":{}}},"show_search_bar":true,"error_message":"Please enter your destination","show_sticky":true},"datepax_data":{"checkin_title":"Check-in","checkout_title":"Check-out","show_datepax_picker":true,"nights":"%sN","guest_title":"Rooms and guests","rooms_config":"1,0,0","date_title":"Date"},"search_button_cta":{"title":"Search"},"content_list":["search_data","datepax_data","search_button_cta"],"bgData":[{"media_url":"http://assets.oyoroomscdn.com/Homepageimagewithoverlay.png","media_type":"image"}],"tagLine":{"title":"You are on your way","sub_title":"Book hotels & homes in","sub_titles":["250+ locations","80+ Countries","3 Taps"]}},"id":3767,"type":"home_header_web","data_source":"inline"}],"loaded":false,"extra":false},"searchobj":{"location":"Chennai, Tamil Nadu, India","city":"chennai","searchType":"city","tag":"","coupon":"","checkin":"13/11/2022","checkout":"14/11/2022","roomConfig":[2],"localityId":"","showSearchElements":false,"guests":2,"rooms":1,"countryName":"India","cityId":"12"},"deal":{"isFetching":true,"data":{},"error":""},"citiesByChar":{"isFetching":true,"data":{},"error":{}},"cities":{"count":195,"isFetching":true,"data":[{"name":"Agra","country_name":"India"},{"name":"Ahmedabad","country_name":"India"},{"name":"Ajmer","country_name":"India"},{"name":"Alappuzha","country_name":"India"},{"name":"Alibag","country_name":"India"},{"name":"Aligarh","country_name":"India"},{"name":"Allahabad","country_name":"India"},{"name":"Alwar","country_name":"India"},{"name":"Ambala","country_name":"India"},{"name":"Amritsar","country_name":"India"},{"name":"Anand","country_name":"India"},{"name":"Aurangabad","country_name":"India"},{"name":"Baddi","country_name":"India"},{"name":"Bangalore","country_name":"India"},{"name":"Bareilly","country_name":"India"},{"name":"Bathinda","country_name":"India"},{"name":"Behrampur","country_name":"India"},{"name":"Bhilai","country_name":"India"},{"name":"Bhilwara","country_name":"India"},{"name":"Bhiwadi","country_name":"India"},{"name":"Bhopal","country_name":"India"},{"name":"Bhubaneswar","country_name":"India"},{"name":"Bijainagar","country_name":"India"},{"name":"Bikaner","country_name":"India"},{"name":"Bilaspur","country_name":"India"},{"name":"Bodhgaya","country_name":"India"},{"name":"Calicut","country_name":"India"},{"name":"Cameron-Highlands","country_name":"Malaysia"},{"name":"Chandigarh","country_name":"India"},{"name":"Chennai","country_name":"India"},{"name":"Chikmagalur","country_name":"India"},{"name":"Chittorgarh","country_name":"India"},{"name":"Coimbatore","country_name":"India"},{"name":"Coonoor","country_name":"India"},{"name":"Coorg","country_name":"India"},{"name":"Corbett-Ramnagar","country_name":"India"},{"name":"Cuttack","country_name":"India"},{"name":"Dahej","country_name":"India"},{"name":"Dalhousie","country_name":"India"},{"name":"Daman","country_name":"India"},{"name":"Darjeeling","country_name":"India"},{"name":"Dehradun","country_name":"India"},{"name":"Delhi","country_name":"India"},{"name":"Dewas","country_name":"India"},{"name":"Dharamshala"," ...
#         </script>
# <script>
#             window.__ROUTE_NAME__ = 'listing'
#         </script>
# <script src="/assets/desktop/runtime.d4e4471e99372df5fcc3.js"></script>
# <script src="/assets/desktop/externalvendor.1fd4612a45561d7117bb.js"></script>
# <script src="/assets/desktop/common.cb6bb20e01d65d694f3a.js"></script>
# <script src="/assets/desktop/commoncss.209925228a244e033ddd.js"></script>
# <script src="/assets/desktop/listing.06b76248591c9a1458b8.js"></script>
# <script src="/assets/desktop/main.6059aab2c8be16cb6f0a.js"></script>
# <noscript>
# <iframe height="0" src="http://www.googletagmanager.com/ns.html?id=GTM-PTZF36" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <script>
#         var prefetchExcludedList = [
#           '/assets/desktop/listing.06b76248591c9a1458b8.js'
#
#           ]
#           if (false){
#             prefetchExcludedList = [
#             '/assets/desktop/listing.b3cfc7a1b429e59faa40.v1.mjs'
#             ]
#           }
#           function script(url) {
#             if((url == "undefined") || (prefetchExcludedList.indexOf(url)>=0)){
#               return null;
#             }
#             var s = document.createElement('link');
#             s.rel = 'prefetch';
#             s.href = url;
#             var x = document.getElementsByTagName('head')[0];
#              //send simply
#             x.appendChild(s);
#           }
#           if (window.addEventListener) {
#               window.addEventListener('load', loadThirdPartyScript, false);
#           } else if (window.attachEvent) {
#               window.attachEvent('onload', loadThirdPartyScript);
#           }
#
#
#
#           function loadThirdPartyScript() {
#               var scriptNameArr = ["countryFlag","assist","home","newHome","listing","detail","bookingDetails","allcities","staticPage","wizard","wizardPlus","trust-and-safety","fourOfour","saveCard","postSaveCard","myBooking","unmarriedCouplesPage","accountDetails","deal","auth","SearchAffiliate","main","oyoforukraine","intl-id","intl-es","intl-ar","intl-vi","intl-hi","intl-pt","intl-ja","intl-th","intl-en","couponOffersPopup","PaymentWrapper/b","PaymentWrapper","authOld","yoImageUploadTemplate","sockjs","externalvendor","common","commoncss","","runtime"];
#               var isSWSupported = 'serviceWorker' in navigator;
#
#             //for other browsers
#             var legacyScriptsToLoad = [
#               '/assets/desktop/listing.06b76248591c9a1458b8.js',
#               '/assets/desktop/home.c75406d1d0c2d35f257d.js',
#               '/assets/desktop/detail.1314717f407dc8f9e11e.js',
#               ''
#             ]
#             for(var i=0 ; i<legacyScriptsToLoad.length;i++){
#                 !isSWSupported && script(legacyScriptsToLoad[i]);
#             }
#
#
#               // GTM
#               (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#               new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#               j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#               '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#               })(window,document,'script','dataLayer','GTM-PTZF36');
#
#               //Load moengage script
#               (function(i,s,o,g,r,a,m,n){
# 	          i['moengage_object']=r;t={}; q = function(f){return function(){(i['moengage_q']=i['moengage_q']||[]).push({f:f,a:arguments});};};
# 	          f = ['track_event','add_user_attribute','add_first_name','add_last_name','add_email','add_mobile',
# 	          'add_user_name','add_gender','add_birthday','destroy_session','add_unique_user_id','moe_events','call_web_push','track','location_type_attribute'];
# 	          for(k in f){t[f[k]]=q(f[k]);}
# 	          a=s.createElement(o);m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m);
# 	          i['moe']=i['moe'] || function(){n=arguments[0];return t;}; a.onload=function(){if(n){i[r] = moe(n);}};
# 	          })(window,document,'script','https://cdn.moengage.com/webpush/moe_webSdk.min.latest.js','Moengage');
# 	          Moengage = moe({
# 	            app_id:"MIJ2OM5MK5YSUOX8XMBAZJHD",
#               debug_logs: 0,
#               swPath: "/service-worker-desktop.js"
#             });
#           }
#         </script>
# </body>
# </html>>

# %%
HotelS = []
RatingS = []
ReviweS= []
PriceS = []
DiscountS=[]
Total_PriceS=[]
AmenitieS=[]
LocationS=[]
Information=[]


for i in range(1,30):
    start_time=time.time()
    url = 'https://www.oyorooms.com/search?location=Chennai%2C%20Tamil%20Nadu%2C%20India&city=Chennai&searchType=city&coupon=&checkin=13%2F11%2F2022&checkout=14%2F11%2F2022&roomConfig%5B%5D=2&showSearchElements=false&guests=2&rooms=1&countryName=India&country=india&filters%5Bcity_id%5D=12&page={}'.format(i)
    page = requests.get(url, headers={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36'})
    pagecontent=page.text
    soup = BeautifulSoup(page.text)
    
    for x in soup.find_all('div', attrs = {'class': 'oyo-cell--12-col oyo-cell--8-col-tablet oyo-cell--4-col-phone'}):
        
        
        #Hotels
        
        hotel_name = x.find('h3', attrs = {'class': 'listingHotelDescription__hotelName d-textEllipsis'})
        
        if hotel_name is None:
            HotelS.append(np.NaN)
        else:
            HotelS.append(hotel_name.text)
            
        
        #Ratings
        
        Ratings = x.find('span', attrs = {'class': 'is-fontBold hotelRating__rating hotelRating__rating--verygood hotelRating__rating--clickable'})

        if Ratings is None:
            RatingS.append(np.NaN)
        else:
            RatingS.append(Ratings.text)   
      
        #Reviwes
        
        Reviwes = x.find('span', attrs = {'class': 'hotelRating__ratingSummary'})

        if Reviwes is None:
            
            ReviweS.append(np.NaN)
        else:
            ReviweS.append(Reviwes.text)   

        
        #Price
        
        price = x.find('span',attrs = {'class': 'listingPrice__finalPrice'})
        
        if price is None:
            PriceS.append(np.NaN)
        else:
            PriceS.append(price.text)


        
        #Discounts
        
        Discount_on_price = x.find('span',attrs = {'class': 'listingPrice__percentage'})
        
        if Discount_on_price is None:
            DiscountS.append(np.NaN)
        else:
            DiscountS.append(Discount_on_price.text)
        
        
         #Total_price
            
        Total_price = x.find('span',attrs = {'class': 'listingPrice__slashedPrice d-body-lg'})
        
        if Total_price is None:
            Total_PriceS.append(np.NaN)
        else:
            Total_PriceS.append(Total_price.text)
        
        #Amenities
        
        Amenities = x.find('span', attrs = {'class':'d-body-sm'})
        
        if Amenities is None:
            AmenitieS.append(np.NaN)
        else:
            AmenitieS.append(Amenities.text)
            
            
            
            
        #Location
        
        Location = x.find('div',attrs = {'class': 'd-body-lg listingHotelDescription__hotelAddress'})
        
        if Location is None:
            LocationS.append(np.NaN)
        else:
            LocationS.append(Location.text)
            
            
            
        #Information
        
        Info = x.find('div',attrs = {'class': 'c-1sugwtq'})
        
        if Info is None:
            Information.append(np.NaN)
        else:
            Information.append(Info.text)
            
            
    end_time = time.time()
    print('Page {} completed in {} seconds'. format(i, end_time-start_time))
# Out:
# Page 1 completed in 5.6871044635772705 seconds
# Page 2 completed in 4.718045234680176 seconds
# Page 3 completed in 3.783830404281616 seconds
# Page 4 completed in 4.32319450378418 seconds
# Page 5 completed in 9.125962018966675 seconds
# Page 6 completed in 11.605398654937744 seconds
# Page 7 completed in 5.1285364627838135 seconds
# Page 8 completed in 4.536625385284424 seconds
# Page 9 completed in 4.822251319885254 seconds
# Page 10 completed in 3.4203386306762695 seconds
# Page 11 completed in 5.88369345664978 seconds
# Page 12 completed in 3.1883182525634766 seconds
# Page 13 completed in 2.7285513877868652 seconds
# Page 14 completed in 3.902352809906006 seconds
# Page 15 completed in 2.7863152027130127 seconds
# Page 16 completed in 2.62630558013916 seconds
# Page 17 completed in 2.9320530891418457 seconds
# Page 18 completed in 4.617746591567993 seconds
# Page 19 completed in 4.32805323600769 seconds
# Page 20 completed in 4.648499965667725 seconds
# Page 21 completed in 4.5280678272247314 seconds
# Page 22 completed in 4.552715301513672 seconds
# Page 23 completed in 4.876673460006714 seconds
# Page 24 completed in 4.579718112945557 seconds
# Page 25 completed in 5.476557493209839 seconds
# Page 26 completed in 3.798872947692871 seconds
# Page 27 completed in 3.9140310287475586 seconds
# Page 28 completed in 4.67911696434021 seconds
# Page 29 completed in 4.816888809204102 seconds

# %%
print(len(HotelS))
print(len(RatingS))
print(len(PriceS))
print(len(Total_PriceS))
print(len(DiscountS))
print(len(AmenitieS))
print(len(LocationS))
print(len(Information))
print(len(ReviweS))
# Out:
# 157
# 157
# 157
# 157
# 157
# 157
# 157
# 157
# 157

# %%
df1 = pd.DataFrame({'Hotels':HotelS,
                    'Prices':PriceS,
                    'Total_Price':Total_PriceS,
                    'Ratings':RatingS,
                    'Booking_Discounts(%)':DiscountS,
                    'Reviews':ReviweS,
                    'Facilities':AmenitieS,
                    'Address':LocationS,
                    'Informations':Information})
df1
# Out:
#                                                 Hotels Prices Total_Price  \
# 0                          Townhouse 1143 Admire Rooms   ₹578       ₹2065
# 1                        OYO Townhouse 834 Jp Paradise  ₹1292       ₹3692
# 2                         OYO 7697 India Gate Par View   ₹699       ₹2678
# 3                    OYO Townhouse 1116 Kinglive Stays  ₹1123       ₹4011
# 4                          OYO Home 78068 Jj Residency   ₹840       ₹2998
# ..                                                 ...    ...         ...
# 152               OYO 90966 Dakshin Serviced Apartment    NaN         NaN
# 153                   Flagship 36726 Chellam Residency    NaN         NaN
# 154                             Flagship 92574 G Cloud    NaN         NaN
# 155                               Townhouse 1155 Porur    NaN         NaN
# 156  OYO Townhouse 237 Near Pallavaram - Thoraipakk...    NaN         NaN
#
#     Ratings Booking_Discounts(%)         Reviews          Facilities  \
# 0       NaN              72% off    (10 Ratings)           Elevator
# 1       NaN              65% off   (503 Ratings)   Parking facility
# 2       NaN              73% off  (1502 Ratings)       Power backup
# 3       NaN              72% off    (68 Ratings)          Reception
# 4      4.1               71% off   (838 Ratings)                 AC
# ..      ...                  ...             ...                 ...
# 152     NaN                  NaN    (49 Ratings)         Hair Dryer
# 153     NaN                  NaN   (399 Ratings)          Reception
# 154     NaN                  NaN   (128 Ratings)   Parking facility
# 155     NaN                  NaN    (13 Ratings)   Parking facility
# 156     NaN                  NaN  (4248 Ratings)   Private entrance
#
#                                                Address  \
# 0                                        TNHB, Chennai
# 1    Anna Avenue,Rathnapuri Layout, Koyambedu, Chennai
# 2    Near Thiruvanmiyur EB Office, Kamaraj Nagar, C...
# 3                                   Tamilnadu, Chennai
# 4            Near Chennai Airport, Pallavaram, Chennai
# ..                                                 ...
# 152                 3rd south cross street,Neelangarai
# 153  Near Arumbakkam Megamart, Sai Chellam Complex,...
# 154                     Hasthinapuram Chrompe, Chennai
# 155      Opposite Chandra Metro mall Near Porur Bridge
# 156              Near bus stop, Kovilambakkam, Chennai
#
#                                     Informations
# 0     8 people booked this hotel in last 6 hours
# 1     6 people booked this hotel in last 6 hours
# 2             All staff vaccinated with 1st dose
# 3                       Hurry, Only 1 room left!
# 4             All staff vaccinated with 1st dose
# ..                                           ...
# 152                                          NaN
# 153  1k+ people booked this OYO in last 6 months
# 154                                          NaN
# 155                                          NaN
# 156           All staff vaccinated with 1st dose
#
# [157 rows x 9 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Hotels                157 non-null    object
#  1   Prices                119 non-null    object
#  2   Total_Price           119 non-null    object
#  3   Ratings               34 non-null     object
#  4   Booking_Discounts(%)  119 non-null    object
#  5   Reviews               147 non-null    object
#  6   Facilities            157 non-null    object
#  7   Address               157 non-null    object
#  8   Informations          119 non-null    object
# dtypes: object(9)
# memory usage: 11.2+ KB

# %%
df1['Prices'] = df1['Prices'].astype(str)

# %%
df1['Prices'] = df1['Prices'].apply(lambda x: x.replace('NaN','0000'))

# %%
df1['Prices'] = df1['Prices'].apply(lambda x: x.replace('₹',''))

# %%
df1['Prices'] = df1['Prices'].astype(float)

# %%
df1['Prices'].fillna(df1['Prices'].mean(), inplace = True)

# %%
df1
# Out:
#                                                 Hotels       Prices  \
# 0                          Townhouse 1143 Admire Rooms   578.000000
# 1                        OYO Townhouse 834 Jp Paradise  1292.000000
# 2                         OYO 7697 India Gate Par View   699.000000
# 3                    OYO Townhouse 1116 Kinglive Stays  1123.000000
# 4                          OYO Home 78068 Jj Residency   840.000000
# ..                                                 ...          ...
# 152               OYO 90966 Dakshin Serviced Apartment  1167.151261
# 153                   Flagship 36726 Chellam Residency  1167.151261
# 154                             Flagship 92574 G Cloud  1167.151261
# 155                               Townhouse 1155 Porur  1167.151261
# 156  OYO Townhouse 237 Near Pallavaram - Thoraipakk...  1167.151261
#
#     Total_Price Ratings Booking_Discounts(%)         Reviews  \
# 0         ₹2065     NaN              72% off    (10 Ratings)
# 1         ₹3692     NaN              65% off   (503 Ratings)
# 2         ₹2678     NaN              73% off  (1502 Ratings)
# 3         ₹4011     NaN              72% off    (68 Ratings)
# 4         ₹2998    4.1               71% off   (838 Ratings)
# ..          ...     ...                  ...             ...
# 152         NaN     NaN                  NaN    (49 Ratings)
# 153         NaN     NaN                  NaN   (399 Ratings)
# 154         NaN     NaN                  NaN   (128 Ratings)
# 155         NaN     NaN                  NaN    (13 Ratings)
# 156         NaN     NaN                  NaN  (4248 Ratings)
#
#              Facilities                                            Address  \
# 0             Elevator                                       TNHB, Chennai
# 1     Parking facility   Anna Avenue,Rathnapuri Layout, Koyambedu, Chennai
# 2         Power backup   Near Thiruvanmiyur EB Office, Kamaraj Nagar, C...
# 3            Reception                                  Tamilnadu, Chennai
# 4                   AC           Near Chennai Airport, Pallavaram, Chennai
# ..                  ...                                                ...
# 152         Hair Dryer                  3rd south cross street,Neelangarai
# 153          Reception   Near Arumbakkam Megamart, Sai Chellam Complex,...
# 154   Parking facility                      Hasthinapuram Chrompe, Chennai
# 155   Parking facility       Opposite Chandra Metro mall Near Porur Bridge
# 156   Private entrance               Near bus stop, Kovilambakkam, Chennai
#
#                                     Informations
# 0     8 people booked this hotel in last 6 hours
# 1     6 people booked this hotel in last 6 hours
# 2             All staff vaccinated with 1st dose
# 3                       Hurry, Only 1 room left!
# 4             All staff vaccinated with 1st dose
# ..                                           ...
# 152                                          NaN
# 153  1k+ people booked this OYO in last 6 months
# 154                                          NaN
# 155                                          NaN
# 156           All staff vaccinated with 1st dose
#
# [157 rows x 9 columns]

# %%
df1['Total_Price'] = df1['Total_Price'].astype(str)

# %%
df1['Total_Price'] = df1['Total_Price'].apply(lambda x: x.replace('NaN','0'))

# %%
df1['Total_Price'] = df1['Total_Price'].apply(lambda x: x.replace('₹',''))

# %%
df1['Total_Price'] = df1['Total_Price'].astype(float)

# %%
df1['Total_Price'].fillna(df1['Total_Price'].mean(), inplace = True)

# %%
df1
# Out:
#                                                 Hotels       Prices  \
# 0                          Townhouse 1143 Admire Rooms   578.000000
# 1                        OYO Townhouse 834 Jp Paradise  1292.000000
# 2                         OYO 7697 India Gate Par View   699.000000
# 3                    OYO Townhouse 1116 Kinglive Stays  1123.000000
# 4                          OYO Home 78068 Jj Residency   840.000000
# ..                                                 ...          ...
# 152               OYO 90966 Dakshin Serviced Apartment  1167.151261
# 153                   Flagship 36726 Chellam Residency  1167.151261
# 154                             Flagship 92574 G Cloud  1167.151261
# 155                               Townhouse 1155 Porur  1167.151261
# 156  OYO Townhouse 237 Near Pallavaram - Thoraipakk...  1167.151261
#
#      Total_Price Ratings Booking_Discounts(%)         Reviews  \
# 0    2065.000000     NaN              72% off    (10 Ratings)
# 1    3692.000000     NaN              65% off   (503 Ratings)
# 2    2678.000000     NaN              73% off  (1502 Ratings)
# 3    4011.000000     NaN              72% off    (68 Ratings)
# 4    2998.000000    4.1               71% off   (838 Ratings)
# ..           ...     ...                  ...             ...
# 152  3815.184874     NaN                  NaN    (49 Ratings)
# 153  3815.184874     NaN                  NaN   (399 Ratings)
# 154  3815.184874     NaN                  NaN   (128 Ratings)
# 155  3815.184874     NaN                  NaN    (13 Ratings)
# 156  3815.184874     NaN                  NaN  (4248 Ratings)
#
#              Facilities                                            Address  \
# 0             Elevator                                       TNHB, Chennai
# 1     Parking facility   Anna Avenue,Rathnapuri Layout, Koyambedu, Chennai
# 2         Power backup   Near Thiruvanmiyur EB Office, Kamaraj Nagar, C...
# 3            Reception                                  Tamilnadu, Chennai
# 4                   AC           Near Chennai Airport, Pallavaram, Chennai
# ..                  ...                                                ...
# 152         Hair Dryer                  3rd south cross street,Neelangarai
# 153          Reception   Near Arumbakkam Megamart, Sai Chellam Complex,...
# 154   Parking facility                      Hasthinapuram Chrompe, Chennai
# 155   Parking facility       Opposite Chandra Metro mall Near Porur Bridge
# 156   Private entrance               Near bus stop, Kovilambakkam, Chennai
#
#                                     Informations
# 0     8 people booked this hotel in last 6 hours
# 1     6 people booked this hotel in last 6 hours
# 2             All staff vaccinated with 1st dose
# 3                       Hurry, Only 1 room left!
# 4             All staff vaccinated with 1st dose
# ..                                           ...
# 152                                          NaN
# 153  1k+ people booked this OYO in last 6 months
# 154                                          NaN
# 155                                          NaN
# 156           All staff vaccinated with 1st dose
#
# [157 rows x 9 columns]

# %%
df1['Ratings'] = df1['Ratings'].astype(str)

# %%
df1['Ratings'] = df1['Ratings'].apply(lambda x: x.replace('NaN','0000'))

# %%
df1['Ratings'] = df1['Ratings'].astype(float)

# %%
df1['Ratings'].fillna(df1['Ratings'].mean(), inplace = True)

# %%
df1
# Out:
#                                                 Hotels       Prices  \
# 0                          Townhouse 1143 Admire Rooms   578.000000
# 1                        OYO Townhouse 834 Jp Paradise  1292.000000
# 2                         OYO 7697 India Gate Par View   699.000000
# 3                    OYO Townhouse 1116 Kinglive Stays  1123.000000
# 4                          OYO Home 78068 Jj Residency   840.000000
# ..                                                 ...          ...
# 152               OYO 90966 Dakshin Serviced Apartment  1167.151261
# 153                   Flagship 36726 Chellam Residency  1167.151261
# 154                             Flagship 92574 G Cloud  1167.151261
# 155                               Townhouse 1155 Porur  1167.151261
# 156  OYO Townhouse 237 Near Pallavaram - Thoraipakk...  1167.151261
#
#      Total_Price   Ratings Booking_Discounts(%)         Reviews  \
# 0    2065.000000  4.173529              72% off    (10 Ratings)
# 1    3692.000000  4.173529              65% off   (503 Ratings)
# 2    2678.000000  4.173529              73% off  (1502 Ratings)
# 3    4011.000000  4.173529              72% off    (68 Ratings)
# 4    2998.000000  4.100000              71% off   (838 Ratings)
# ..           ...       ...                  ...             ...
# 152  3815.184874  4.173529                  NaN    (49 Ratings)
# 153  3815.184874  4.173529                  NaN   (399 Ratings)
# 154  3815.184874  4.173529                  NaN   (128 Ratings)
# 155  3815.184874  4.173529                  NaN    (13 Ratings)
# 156  3815.184874  4.173529                  NaN  (4248 Ratings)
#
#              Facilities                                            Address  \
# 0             Elevator                                       TNHB, Chennai
# 1     Parking facility   Anna Avenue,Rathnapuri Layout, Koyambedu, Chennai
# 2         Power backup   Near Thiruvanmiyur EB Office, Kamaraj Nagar, C...
# 3            Reception                                  Tamilnadu, Chennai
# 4                   AC           Near Chennai Airport, Pallavaram, Chennai
# ..                  ...                                                ...
# 152         Hair Dryer                  3rd south cross street,Neelangarai
# 153          Reception   Near Arumbakkam Megamart, Sai Chellam Complex,...
# 154   Parking facility                      Hasthinapuram Chrompe, Chennai
# 155   Parking facility       Opposite Chandra Metro mall Near Porur Bridge
# 156   Private entrance               Near bus stop, Kovilambakkam, Chennai
#
#                                     Informations
# 0     8 people booked this hotel in last 6 hours
# 1     6 people booked this hotel in last 6 hours
# 2             All staff vaccinated with 1st dose
# 3                       Hurry, Only 1 room left!
# 4             All staff vaccinated with 1st dose
# ..                                           ...
# 152                                          NaN
# 153  1k+ people booked this OYO in last 6 months
# 154                                          NaN
# 155                                          NaN
# 156           All staff vaccinated with 1st dose
#
# [157 rows x 9 columns]

# %%
df1['Booking_Discounts(%)'] = df1['Booking_Discounts(%)'].str.replace('\D+','')
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_9852\2563500470.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df1['Booking_Discounts(%)'] = df1['Booking_Discounts(%)'].str.replace('\D+','')

# %%
df1['Booking_Discounts(%)']=df1['Booking_Discounts(%)'].astype(float)

# %%
df1['Booking_Discounts(%)'].fillna(df1['Booking_Discounts(%)'].mean(),inplace=True)

# %%
df1
# Out:
#                                                 Hotels       Prices  \
# 0                          Townhouse 1143 Admire Rooms   578.000000
# 1                        OYO Townhouse 834 Jp Paradise  1292.000000
# 2                         OYO 7697 India Gate Par View   699.000000
# 3                    OYO Townhouse 1116 Kinglive Stays  1123.000000
# 4                          OYO Home 78068 Jj Residency   840.000000
# ..                                                 ...          ...
# 152               OYO 90966 Dakshin Serviced Apartment  1167.151261
# 153                   Flagship 36726 Chellam Residency  1167.151261
# 154                             Flagship 92574 G Cloud  1167.151261
# 155                               Townhouse 1155 Porur  1167.151261
# 156  OYO Townhouse 237 Near Pallavaram - Thoraipakk...  1167.151261
#
#      Total_Price   Ratings  Booking_Discounts(%)         Reviews  \
# 0    2065.000000  4.173529             72.000000    (10 Ratings)
# 1    3692.000000  4.173529             65.000000   (503 Ratings)
# 2    2678.000000  4.173529             73.000000  (1502 Ratings)
# 3    4011.000000  4.173529             72.000000    (68 Ratings)
# 4    2998.000000  4.100000             71.000000   (838 Ratings)
# ..           ...       ...                   ...             ...
# 152  3815.184874  4.173529             68.739496    (49 Ratings)
# 153  3815.184874  4.173529             68.739496   (399 Ratings)
# 154  3815.184874  4.173529             68.739496   (128 Ratings)
# 155  3815.184874  4.173529             68.739496    (13 Ratings)
# 156  3815.184874  4.173529             68.739496  (4248 Ratings)
#
#              Facilities                                            Address  \
# 0             Elevator                                       TNHB, Chennai
# 1     Parking facility   Anna Avenue,Rathnapuri Layout, Koyambedu, Chennai
# 2         Power backup   Near Thiruvanmiyur EB Office, Kamaraj Nagar, C...
# 3            Reception                                  Tamilnadu, Chennai
# 4                   AC           Near Chennai Airport, Pallavaram, Chennai
# ..                  ...                                                ...
# 152         Hair Dryer                  3rd south cross street,Neelangarai
# 153          Reception   Near Arumbakkam Megamart, Sai Chellam Complex,...
# 154   Parking facility                      Hasthinapuram Chrompe, Chennai
# 155   Parking facility       Opposite Chandra Metro mall Near Porur Bridge
# 156   Private entrance               Near bus stop, Kovilambakkam, Chennai
#
#                                     Informations
# 0     8 people booked this hotel in last 6 hours
# 1     6 people booked this hotel in last 6 hours
# 2             All staff vaccinated with 1st dose
# 3                       Hurry, Only 1 room left!
# 4             All staff vaccinated with 1st dose
# ..                                           ...
# 152                                          NaN
# 153  1k+ people booked this OYO in last 6 months
# 154                                          NaN
# 155                                          NaN
# 156           All staff vaccinated with 1st dose
#
# [157 rows x 9 columns]

# %%
df1['Reviews'] = df1['Reviews'].str.replace('\D+','')
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_9852\629340285.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df1['Reviews'] = df1['Reviews'].str.replace('\D+','')

# %%
df1['Reviews']=df1['Reviews'].astype(float)

# %%
df1['Reviews'].fillna(df1['Reviews'].mean(),inplace=True)

# %%
df1
# Out:
#                                                 Hotels       Prices  \
# 0                          Townhouse 1143 Admire Rooms   578.000000
# 1                        OYO Townhouse 834 Jp Paradise  1292.000000
# 2                         OYO 7697 India Gate Par View   699.000000
# 3                    OYO Townhouse 1116 Kinglive Stays  1123.000000
# 4                          OYO Home 78068 Jj Residency   840.000000
# ..                                                 ...          ...
# 152               OYO 90966 Dakshin Serviced Apartment  1167.151261
# 153                   Flagship 36726 Chellam Residency  1167.151261
# 154                             Flagship 92574 G Cloud  1167.151261
# 155                               Townhouse 1155 Porur  1167.151261
# 156  OYO Townhouse 237 Near Pallavaram - Thoraipakk...  1167.151261
#
#      Total_Price   Ratings  Booking_Discounts(%)  Reviews          Facilities  \
# 0    2065.000000  4.173529             72.000000     10.0           Elevator
# 1    3692.000000  4.173529             65.000000    503.0   Parking facility
# 2    2678.000000  4.173529             73.000000   1502.0       Power backup
# 3    4011.000000  4.173529             72.000000     68.0          Reception
# 4    2998.000000  4.100000             71.000000    838.0                 AC
# ..           ...       ...                   ...      ...                 ...
# 152  3815.184874  4.173529             68.739496     49.0         Hair Dryer
# 153  3815.184874  4.173529             68.739496    399.0          Reception
# 154  3815.184874  4.173529             68.739496    128.0   Parking facility
# 155  3815.184874  4.173529             68.739496     13.0   Parking facility
# 156  3815.184874  4.173529             68.739496   4248.0   Private entrance
#
#                                                Address  \
# 0                                        TNHB, Chennai
# 1    Anna Avenue,Rathnapuri Layout, Koyambedu, Chennai
# 2    Near Thiruvanmiyur EB Office, Kamaraj Nagar, C...
# 3                                   Tamilnadu, Chennai
# 4            Near Chennai Airport, Pallavaram, Chennai
# ..                                                 ...
# 152                 3rd south cross street,Neelangarai
# 153  Near Arumbakkam Megamart, Sai Chellam Complex,...
# 154                     Hasthinapuram Chrompe, Chennai
# 155      Opposite Chandra Metro mall Near Porur Bridge
# 156              Near bus stop, Kovilambakkam, Chennai
#
#                                     Informations
# 0     8 people booked this hotel in last 6 hours
# 1     6 people booked this hotel in last 6 hours
# 2             All staff vaccinated with 1st dose
# 3                       Hurry, Only 1 room left!
# 4             All staff vaccinated with 1st dose
# ..                                           ...
# 152                                          NaN
# 153  1k+ people booked this OYO in last 6 months
# 154                                          NaN
# 155                                          NaN
# 156           All staff vaccinated with 1st dose
#
# [157 rows x 9 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Hotels                157 non-null    object
#  1   Prices                157 non-null    float64
#  2   Total_Price           157 non-null    float64
#  3   Ratings               157 non-null    float64
#  4   Booking_Discounts(%)  157 non-null    float64
#  5   Reviews               157 non-null    float64
#  6   Facilities            157 non-null    object
#  7   Address               157 non-null    object
#  8   Informations          119 non-null    object
# dtypes: float64(5), object(4)
# memory usage: 11.2+ KB

# %%
df1["City_Name"] = df1['Address'].apply(lambda x: x.split(',')[-1])
df1
# Out:
#                                                 Hotels       Prices  \
# 0                          Townhouse 1143 Admire Rooms   578.000000
# 1                        OYO Townhouse 834 Jp Paradise  1292.000000
# 2                         OYO 7697 India Gate Par View   699.000000
# 3                    OYO Townhouse 1116 Kinglive Stays  1123.000000
# 4                          OYO Home 78068 Jj Residency   840.000000
# ..                                                 ...          ...
# 152               OYO 90966 Dakshin Serviced Apartment  1167.151261
# 153                   Flagship 36726 Chellam Residency  1167.151261
# 154                             Flagship 92574 G Cloud  1167.151261
# 155                               Townhouse 1155 Porur  1167.151261
# 156  OYO Townhouse 237 Near Pallavaram - Thoraipakk...  1167.151261
#
#      Total_Price   Ratings  Booking_Discounts(%)  Reviews          Facilities  \
# 0    2065.000000  4.173529             72.000000     10.0           Elevator
# 1    3692.000000  4.173529             65.000000    503.0   Parking facility
# 2    2678.000000  4.173529             73.000000   1502.0       Power backup
# 3    4011.000000  4.173529             72.000000     68.0          Reception
# 4    2998.000000  4.100000             71.000000    838.0                 AC
# ..           ...       ...                   ...      ...                 ...
# 152  3815.184874  4.173529             68.739496     49.0         Hair Dryer
# 153  3815.184874  4.173529             68.739496    399.0          Reception
# 154  3815.184874  4.173529             68.739496    128.0   Parking facility
# 155  3815.184874  4.173529             68.739496     13.0   Parking facility
# 156  3815.184874  4.173529             68.739496   4248.0   Private entrance
#
#                                                Address  \
# 0                                        TNHB, Chennai
# 1    Anna Avenue,Rathnapuri Layout, Koyambedu, Chennai
# 2    Near Thiruvanmiyur EB Office, Kamaraj Nagar, C...
# 3                                   Tamilnadu, Chennai
# 4            Near Chennai Airport, Pallavaram, Chennai
# ..                                                 ...
# 152                 3rd south cross street,Neelangarai
# 153  Near Arumbakkam Megamart, Sai Chellam Complex,...
# 154                     Hasthinapuram Chrompe, Chennai
# 155      Opposite Chandra Metro mall Near Porur Bridge
# 156              Near bus stop, Kovilambakkam, Chennai
#
#                                     Informations  \
# 0     8 people booked this hotel in last 6 hours
# 1     6 people booked this hotel in last 6 hours
# 2             All staff vaccinated with 1st dose
# 3                       Hurry, Only 1 room left!
# 4             All staff vaccinated with 1st dose
# ..                                           ...
# 152                                          NaN
# 153  1k+ people booked this OYO in last 6 months
# 154                                          NaN
# 155                                          NaN
# 156           All staff vaccinated with 1st dose
#
#                                          City_Name
# 0                                          Chennai
# 1                                          Chennai
# 2                                          Chennai
# 3                                          Chennai
# 4                                          Chennai
# ..                                             ...
# 152                                    Neelangarai
# 153                                        Chennai
# 154                                        Chennai
# 155  Opposite Chandra Metro mall Near Porur Bridge
# 156                                        Chennai
#
# [157 rows x 10 columns]

# %%
df1['Address']
# Out:
# 0                                          TNHB, Chennai
# 1      Anna Avenue,Rathnapuri Layout, Koyambedu, Chennai
# 2      Near Thiruvanmiyur EB Office, Kamaraj Nagar, C...
# 3                                     Tamilnadu, Chennai
# 4              Near Chennai Airport, Pallavaram, Chennai
#                              ...
# 152                   3rd south cross street,Neelangarai
# 153    Near Arumbakkam Megamart, Sai Chellam Complex,...
# 154                       Hasthinapuram Chrompe, Chennai
# 155        Opposite Chandra Metro mall Near Porur Bridge
# 156                Near bus stop, Kovilambakkam, Chennai
# Name: Address, Length: 157, dtype: object

# %%
city = []
for i in df1['Address']:
    city.append(i.split())
city
# Out:
# [['TNHB,', 'Chennai'],
#  ['Anna', 'Avenue,Rathnapuri', 'Layout,', 'Koyambedu,', 'Chennai'],
#  ['Near', 'Thiruvanmiyur', 'EB', 'Office,', 'Kamaraj', 'Nagar,', 'Chennai'],
#  ['Tamilnadu,', 'Chennai'],
#  ['Near', 'Chennai', 'Airport,', 'Pallavaram,', 'Chennai'],
#  ['Near', 'Panagal', 'Park', 'T.Nagar,', 'Chennai'],
#  ['Chennai,', 'Chennai'],
#  ['3/80', 'Omr', 'Road', '(opp', 'To', 'Sathyabama', 'College),', 'Chennai'],
#  ['Chennai,', 'Chennai'],
#  ['Karappakam,', 'Chennai'],
#  ['Opposite',
#   'D.M.K',
#   'Head',
#   'Office,',
#   'Anna',
#   'Salai,',
#   'Near',
#   'Student',
#   'Xerox,',
#   'Teynampet,',
#   'Chennai'],
#  ['ECR,', 'Chennai'],
#  ['Opposite', 'Balaji', 'Dental', 'College,', 'Pallikaranai'],
#  ['Triplicane,', 'Chennai'],
#  ['Karapakkam,', 'Chennai'],
#  ['Triplicane,', 'Chennai'],
#  ['Near',
#   'Pantaloons,',
#   'N',
#   'Usman',
#   'Rd,',
#   'Parthasarathi',
#   'Puram,',
#   'T.',
#   'Nagar'],
#  ['Porur,', 'Chennai'],
#  ['Opposite',
#   'To',
#   'Chennai',
#   'Central',
#   'Near',
#   'To',
#   'Rippon',
#   'Building,',
#   'Chennai'],
#  ['Plot',
#   'no',
#   '23/13,',
#   'Sakthi',
#   'krishna',
#   'apartment,',
#   'coats',
#   'road',
#   ',',
#   'North',
#   'usman',
#   'street,',
#   'T',
#   'nagar,',
#   'Chennai',
#   '-',
#   '600017'],
#  ['Kelambakkam', 'Junction,', 'OMR,', 'Chennai'],
#  ['OMR,', 'Shollinganallur', 'junction'],
#  ['Opposite',
#   'Balaji',
#   'Dental',
#   'College',
#   'street,',
#   'Kamakotti',
#   'Nagar,',
#   'Pallikaranai.'],
#  ['Opposite',
#   'Kanathur',
#   'Poorvika',
#   'Showroom,',
#   'CLV',
#   'Nagar',
#   '1st',
#   'Street,',
#   'ECR,',
#   'Chenai'],
#  ['Andavar', 'Nagar,', 'Chennai'],
#  ['Near', 'Jain', 'Temple,', 'Purasaiwakkam,', 'Chennai'],
#  ['TNHB,', 'Chennai'],
#  ['NO.1/42,',
#   'Main',
#   'Bazzar',
#   'JJ',
#   'Nagar,',
#   'Mogappair',
#   'East,',
#   'Chennai-600037'],
#  ['Triplicane,', 'Chennai'],
#  ['Reddikuppam,', 'Chennai'],
#  ['No.', '34', 'Near', 'Rippon', 'Building', 'Periyamet', 'Chennai'],
#  ['Elango', 'Nagar,', 'Virugambakkam,', 'Chennai'],
#  ['Dr,',
#   'Singaravelu',
#   'St,',
#   'Pondy',
#   'Bazaar,',
#   'Parthasarathi',
#   'Puram,',
#   'T.',
#   'Nagar,',
#   'Chennai,',
#   'Tamil',
#   'Nadu',
#   '600017'],
#  ['Pillayar', 'Koil', 'St', 'Triplicane.,', 'Chennai'],
#  ['Near', 'US', 'Consult,', 'Gemini', 'Bridge,', 'Nungambakkam,', 'Chennai'],
#  ['Near', 'Bougainvillea', 'park,', 'Anna', 'Nagar,', 'Chennai'],
#  ['Near',
#   'Arumbakkam',
#   'Metro',
#   'Station,',
#   'Loganathan',
#   'Nagar',
#   '2nd',
#   'street,',
#   'Chennai'],
#  ['Tiruvottiyur', 'Theradi', 'Metro', 'Station,', 'Chennai.'],
#  ['Near', 'Meenambakkam', 'Metro', 'station&', 'Chennai', 'Airport'],
#  ['Near', 'Mayajal', 'multiplex,', 'Kanathur,', 'Chennai'],
#  ['Opposite', 'Balaji', 'Dental', 'College,', 'Pallikaranai'],
#  ['Near', 'Singaperumal', 'Koil', 'Railway', 'Station,', 'Chennai'],
#  ['3.1', 'km', 'From', 'Chennai', 'Airport'],
#  ['Near', 'Bus', 'Stand,', 'Drj', 'Hospital,', 'Kolathur,', 'Chennai'],
#  ['Near', 'Triplicane', 'Police', 'station,', 'Chennai'],
#  ['Arumbakkam(mmda', 'Bustop),', 'Chennai'],
#  ['Periamet,', 'Chennai'],
#  ['Near',
#   'Pantaloons,',
#   'N',
#   'Usman',
#   'Rd,',
#   'Parthasarathi',
#   'Puram,',
#   'T.',
#   'Nagar'],
#  ['Near', 'MIOT', 'Hospital,', 'Manapakkam,', 'Chennai'],
#  ['Opp', 'To', 'Uco', 'Bank,', 'Chennai'],
#  ['Ponniamman', 'Koil', 'Street,', 'Chennai'],
#  ['Near', 'Thiruvanmiyur', 'EB', 'Office,', 'Kamaraj', 'Nagar,', 'Chennai'],
#  ['Near', 'Central', 'Metro', 'Station,', 'Chennai'],
#  ['Chengalpattu', 'District,', 'Chennai'],
#  ['Mugappair', 'West,', 'Chennai'],
#  ['Karappakam,', 'Chennai'],
#  ['Near',
#   'T',
#   'Nagar',
#   'Pondy',
#   'Bazzar,',
#   '1st',
#   'Ext',
#   'Nandanam,',
#   'Chennai'],
#  ['Pallavaram,', 'Chennai'],
#  ['Thoraipakkam,', 'Chennai'],
#  ['Plot',
#   'no',
#   '23/13,',
#   'Sakthi',
#   'krishna',
#   'apartment,',
#   'coats',
#   'road',
#   ',',
#   'North',
#   'usman',
#   'street,',
#   'T',
#   'nagar,',
#   'Chennai',
#   '-',
#   '600017'],
#  ['Opposite',
#   'D.M.K',
#   'Head',
#   'Office,',
#   'Anna',
#   'Salai,',
#   'Near',
#   'Student',
#   'Xerox,',
#   'Teynampet,',
#   'Chennai'],
#  ['Chennai,', 'Chennai'],
#  ['Kovalam,', 'Chennai'],
#  ['Plot',
#   'No.',
#   '53',
#   '&',
#   '60,',
#   'Abirami',
#   'Nagar,',
#   '2nd',
#   'cross',
#   'street,',
#   'Urapakkam'],
#  ['Near',
#   'Annaji',
#   'Nagar,',
#   'Mariamman',
#   'Kovil',
#   'Cross',
#   'Street,',
#   'Chennai'],
#  ['Adyar,', 'Chennai'],
#  ['Near', 'Guduvanchery,', 'Nandhivaram,', 'Chennai'],
#  ['Near', 'to', 'Bus', 'Stop,', 'Kovilambakkam,', 'Chennai'],
#  ['Near', 'True', 'valley,', 'Avadi,', 'Chennai'],
#  ['Chennai,', 'Chennai'],
#  ['1/218', 'Padavattamman', 'Kovil', 'Street,', 'Chennai'],
#  ['Near', 'US', 'consulate', 'Nungambakkam'],
#  ['Near', 'Fiat', 'Showroom,', 'Kattupakkam,', 'Chennai'],
#  ['600073,', 'Chennai'],
#  ['Near', 'Sipcot,', 'Egattur,', 'Chennai'],
#  ['Chennai,', 'Chennai'],
#  ['Tamilnadu,', 'Chennai'],
#  ['Opp', 'Chennai', 'Central', 'Railway', 'Station', ',', 'PH', 'Road'],
#  ['Near', 'Chennai', 'Airport,', 'Pallavaram,', 'Chennai'],
#  ['Near', 'OMR', 'Apollo', 'Hospitals'],
#  ['Near', 'Fathima', 'Jewllery,', 'T.', 'Nagar,', 'Chennai'],
#  ['Near', 'Jaya', 'TV,', 'Defence', 'Colony,', 'Chennai'],
#  ['3/80', 'Omr', 'Road', '(opp', 'To', 'Sathyabama', 'College),', 'Chennai'],
#  ['Chennai', 'District,', 'Chennai'],
#  ['Near', 'CMBT', '&', 'Arumbakkam', 'Metro', 'Station,', 'Chennai'],
#  ['Near', 'PG', 'ILLAM,', 'Venkatnaraya', 'Road,', 'Chennai'],
#  ['GNT', 'Road,', 'Chennai'],
#  ['Near', 'Panagal', 'Park', 'T.Nagar,', 'Chennai'],
#  ['Near', 'Arumbakam', 'Metro', 'Station,', 'loganathan', 'nagar,', 'Chennai'],
#  ['Near', 'Central', 'Railway', 'Station,', 'Park', 'Town,', 'Chennai'],
#  ['Near', 'Infosys', 'Sholinganallur,', 'Sholinganallur,', 'Chennai'],
#  ['Mogappair', 'East,', 'Chennai'],
#  ['Near', 'Prince', 'Techno', 'Park,', 'Jothi', 'Nagar,', 'Chennai'],
#  ['Pallavaram,', 'Chennai'],
#  ['Rich', 'Mount,', 'Ritchi', 'Street,', 'Anna', 'Salai', 'Chennai'],
#  ['Velayutham', 'Colony,', 'Chennai'],
#  ['Chengalpattu', '44,', 'Chennai'],
#  ['Opposite',
#   'To',
#   'Chennai',
#   'Central',
#   'Near',
#   'To',
#   'Rippon',
#   'Building,',
#   'Chennai'],
#  ['Madipakkam,', 'Chennai'],
#  ['India,', 'Chennai'],
#  ['Near', 'Egmore', 'Railway', 'Hospital,', 'Periamet,', 'Chennai'],
#  ['Chennai', 'District,', 'Chennai'],
#  ['Near', 'tnagar', 'bus', 'stop,', 'Parthasarathi', 'Puram,', 'Chennai'],
#  ['Opposite', 'AVM', 'studio', '&', 'Fortis', 'hospital,', 'vadapalani'],
#  ['Zidan',
#   'Residency',
#   'Opposite',
#   'US',
#   'Consulate,',
#   'near',
#   'Apollo',
#   'Hospital,',
#   'Nungabakkam'],
#  ['Kodandarama', 'Nagar,', 'Chennai'],
#  ['Opposite',
#   'to',
#   'DKM',
#   'office',
#   'above',
#   'AG',
#   'DMS',
#   'Metro',
#   'station',
#   'Anna',
#   'Salai'],
#  ['Perumbakkam', 'Main', 'Rd,', 'Chennai'],
#  ['Near', 'Airport,', 'Nanganallur'],
#  ['Omr,', 'Chennai'],
#  ['Koyambedu,', 'Chennai'],
#  ['Anna', 'Nagar', 'Extn', 'Behind', 'Mmm', 'Hospital,', 'Chennai'],
#  ['Pallavaram,Chennai'],
#  ['Near', 'GG', 'fertility', 'hosppital,', 'Tirumurthy', 'Nagar,', 'Chennai'],
#  ['Pondybazzar,', 'T.Nagar,', 'Opposite', 'GRT', 'Hotels'],
#  ['Sri', 'Sakthi', 'Nagar,', 'Chennai'],
#  ['Near', 'Panimalr', 'College', ',', 'Varadharajapuram,', 'Chennai'],
#  ['Near', 'Soorya', 'Hospital,', 'Saligramam,', 'Chennai'],
#  ['Opposite', 'US', 'Consulate'],
#  ['Near', 'airport,', 'Nanganallur,', 'Chennai'],
#  ['Velachery,', 'Chennai'],
#  ['Omr,', 'shollinganallur', 'junction'],
#  ['Chennai', 'District,', 'Chennai'],
#  ['Near', 'Elcot', 'Sez', 'Sholinganallur,Perumbakkam'],
#  ['Near', 'by', 'Padapai', 'bus', 'stand'],
#  ['Near', 'Meenabakkam', 'Metro', 'Station,', 'Nanganallur,', 'Chennai'],
#  ['Near', 'Janatha', 'Theatre,', 'Pallavaram,', 'Chennai'],
#  ['2nd', 'Street,', 'Chennai'],
#  ['Tambaram,', 'Chennai'],
#  ['95,', 'Gowdia', 'Mutt', 'RD,', 'Near', 'Express', 'Avenune', 'Mall'],
#  ['Kanathur', 'Reddikuppam,', 'Chennai'],
#  ['Near', 'Velachery', 'Railway', 'station,', 'Ram', 'Nagar,', 'Chennai'],
#  ['India,', 'Chennai'],
#  ['Padi,', 'Chennai'],
#  ['MCN', 'Nagar,', 'Thoraipakkam,', 'Chennai'],
#  ['Near', 'Vandalur', 'Zoo,', 'Urapakkam,', 'Chennai'],
#  ['Medavakkam,', 'Chennai'],
#  ['Nallamuthu', 'Street', 'Corner', 'Chennai,', 'Chennai'],
#  ['Thiruvallur', 'District,', 'Chennai'],
#  ['Chennai-600042,', 'Chennai'],
#  ['Near', 'Valluvar', 'Salai,', 'Ramapuram,', 'Chennai'],
#  ['Behind', 'Koyambedu', 'Market', 'and', 'Bus', 'Teminal,', 'Chennai'],
#  ['India,', 'Chennai'],
#  ['Chengalpattu', 'District,', 'Chennai'],
#  ['Venkateswara', 'Nagar,', 'AGS', 'Colony,', 'Kottivakkam', 'ECR'],
#  ['Nearby', 'Samsung', 'factory', 'and', 'pengubin'],
#  ['Near',
#   'shenoy',
#   'nagar',
#   'metro',
#   'station,',
#   'Shenoy',
#   'Nagar,',
#   'Chennai'],
#  ['Kunrathur', 'Tamil', 'Nadu,', 'Chennai'],
#  ['Nolambur', 'Phsase', '2,', 'Chennai'],
#  ['Near', 'airport,', 'pallavaram,', 'chennai'],
#  ['porur,', 'Chennai'],
#  ['Near', 'Tambaram', 'Railwaystation,', 'Tambaram,', 'Chennai'],
#  ['3rd', 'south', 'cross', 'street,Neelangarai'],
#  ['Near', 'Arumbakkam', 'Megamart,', 'Sai', 'Chellam', 'Complex,', 'Chennai'],
#  ['Hasthinapuram', 'Chrompe,', 'Chennai'],
#  ['Opposite', 'Chandra', 'Metro', 'mall', 'Near', 'Porur', 'Bridge'],
#  ['Near', 'bus', 'stop,', 'Kovilambakkam,', 'Chennai']]

# %%
City = []
for i in city:
    if i == "Chennai":
        City.append(i)
    else:
        City.append("Chennai")
City
# Out:
# ['Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai']

# %%
df1['City_Name']=City
df1
# Out:
#                                                 Hotels       Prices  \
# 0                          Townhouse 1143 Admire Rooms   578.000000
# 1                        OYO Townhouse 834 Jp Paradise  1292.000000
# 2                         OYO 7697 India Gate Par View   699.000000
# 3                    OYO Townhouse 1116 Kinglive Stays  1123.000000
# 4                          OYO Home 78068 Jj Residency   840.000000
# ..                                                 ...          ...
# 152               OYO 90966 Dakshin Serviced Apartment  1167.151261
# 153                   Flagship 36726 Chellam Residency  1167.151261
# 154                             Flagship 92574 G Cloud  1167.151261
# 155                               Townhouse 1155 Porur  1167.151261
# 156  OYO Townhouse 237 Near Pallavaram - Thoraipakk...  1167.151261
#
#      Total_Price   Ratings  Booking_Discounts(%)  Reviews          Facilities  \
# 0    2065.000000  4.173529             72.000000     10.0           Elevator
# 1    3692.000000  4.173529             65.000000    503.0   Parking facility
# 2    2678.000000  4.173529             73.000000   1502.0       Power backup
# 3    4011.000000  4.173529             72.000000     68.0          Reception
# 4    2998.000000  4.100000             71.000000    838.0                 AC
# ..           ...       ...                   ...      ...                 ...
# 152  3815.184874  4.173529             68.739496     49.0         Hair Dryer
# 153  3815.184874  4.173529             68.739496    399.0          Reception
# 154  3815.184874  4.173529             68.739496    128.0   Parking facility
# 155  3815.184874  4.173529             68.739496     13.0   Parking facility
# 156  3815.184874  4.173529             68.739496   4248.0   Private entrance
#
#                                                Address  \
# 0                                        TNHB, Chennai
# 1    Anna Avenue,Rathnapuri Layout, Koyambedu, Chennai
# 2    Near Thiruvanmiyur EB Office, Kamaraj Nagar, C...
# 3                                   Tamilnadu, Chennai
# 4            Near Chennai Airport, Pallavaram, Chennai
# ..                                                 ...
# 152                 3rd south cross street,Neelangarai
# 153  Near Arumbakkam Megamart, Sai Chellam Complex,...
# 154                     Hasthinapuram Chrompe, Chennai
# 155      Opposite Chandra Metro mall Near Porur Bridge
# 156              Near bus stop, Kovilambakkam, Chennai
#
#                                     Informations City_Name
# 0     8 people booked this hotel in last 6 hours   Chennai
# 1     6 people booked this hotel in last 6 hours   Chennai
# 2             All staff vaccinated with 1st dose   Chennai
# 3                       Hurry, Only 1 room left!   Chennai
# 4             All staff vaccinated with 1st dose   Chennai
# ..                                           ...       ...
# 152                                          NaN   Chennai
# 153  1k+ people booked this OYO in last 6 months   Chennai
# 154                                          NaN   Chennai
# 155                                          NaN   Chennai
# 156           All staff vaccinated with 1st dose   Chennai
#
# [157 rows x 10 columns]

# %%
df1.to_csv('Oyo Hotels Chennai.csv',index=False)

# %%
df1 = pd.read_csv('Oyo Hotels Chennai.csv')
df1
# Out:
#                                                 Hotels       Prices  \
# 0                          Townhouse 1143 Admire Rooms   578.000000
# 1                        OYO Townhouse 834 Jp Paradise  1292.000000
# 2                         OYO 7697 India Gate Par View   699.000000
# 3                    OYO Townhouse 1116 Kinglive Stays  1123.000000
# 4                          OYO Home 78068 Jj Residency   840.000000
# ..                                                 ...          ...
# 152               OYO 90966 Dakshin Serviced Apartment  1167.151261
# 153                   Flagship 36726 Chellam Residency  1167.151261
# 154                             Flagship 92574 G Cloud  1167.151261
# 155                               Townhouse 1155 Porur  1167.151261
# 156  OYO Townhouse 237 Near Pallavaram - Thoraipakk...  1167.151261
#
#      Total_Price   Ratings  Booking_Discounts(%)  Reviews          Facilities  \
# 0    2065.000000  4.173529             72.000000     10.0           Elevator
# 1    3692.000000  4.173529             65.000000    503.0   Parking facility
# 2    2678.000000  4.173529             73.000000   1502.0       Power backup
# 3    4011.000000  4.173529             72.000000     68.0          Reception
# 4    2998.000000  4.100000             71.000000    838.0                 AC
# ..           ...       ...                   ...      ...                 ...
# 152  3815.184874  4.173529             68.739496     49.0         Hair Dryer
# 153  3815.184874  4.173529             68.739496    399.0          Reception
# 154  3815.184874  4.173529             68.739496    128.0   Parking facility
# 155  3815.184874  4.173529             68.739496     13.0   Parking facility
# 156  3815.184874  4.173529             68.739496   4248.0   Private entrance
#
#                                                Address  \
# 0                                        TNHB, Chennai
# 1    Anna Avenue,Rathnapuri Layout, Koyambedu, Chennai
# 2    Near Thiruvanmiyur EB Office, Kamaraj Nagar, C...
# 3                                   Tamilnadu, Chennai
# 4            Near Chennai Airport, Pallavaram, Chennai
# ..                                                 ...
# 152                 3rd south cross street,Neelangarai
# 153  Near Arumbakkam Megamart, Sai Chellam Complex,...
# 154                     Hasthinapuram Chrompe, Chennai
# 155      Opposite Chandra Metro mall Near Porur Bridge
# 156              Near bus stop, Kovilambakkam, Chennai
#
#                                     Informations City_Name
# 0     8 people booked this hotel in last 6 hours   Chennai
# 1     6 people booked this hotel in last 6 hours   Chennai
# 2             All staff vaccinated with 1st dose   Chennai
# 3                       Hurry, Only 1 room left!   Chennai
# 4             All staff vaccinated with 1st dose   Chennai
# ..                                           ...       ...
# 152                                          NaN   Chennai
# 153  1k+ people booked this OYO in last 6 months   Chennai
# 154                                          NaN   Chennai
# 155                                          NaN   Chennai
# 156           All staff vaccinated with 1st dose   Chennai
#
# [157 rows x 10 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Hotels                157 non-null    object
#  1   Prices                157 non-null    float64
#  2   Total_Price           157 non-null    float64
#  3   Ratings               157 non-null    float64
#  4   Booking_Discounts(%)  157 non-null    float64
#  5   Reviews               157 non-null    float64
#  6   Facilities            157 non-null    object
#  7   Address               157 non-null    object
#  8   Informations          119 non-null    object
#  9   City_Name             157 non-null    object
# dtypes: float64(5), object(5)
# memory usage: 12.4+ KB

# %%
df1.shape
# Out:
# (157, 10)

# %%
df1.describe()
# Out:
#             Prices   Total_Price     Ratings  Booking_Discounts(%)  \
# count   157.000000    157.000000  157.000000            157.000000
# mean   1167.151261   3815.184874    4.173529             68.739496
# std     576.896556   1805.998985    0.067281              4.616667
# min     423.000000   1482.000000    4.000000             47.000000
# 25%     791.000000   2675.000000    4.173529             67.000000
# 50%    1167.151261   3815.184874    4.173529             68.739496
# 75%    1178.000000   3991.000000    4.173529             72.000000
# max    4494.000000  12839.000000    4.400000             77.000000
#
#            Reviews
# count   157.000000
# mean    737.061224
# std     868.309876
# min       7.000000
# 25%     170.000000
# 50%     512.000000
# 75%     919.000000
# max    5516.000000

# %%
df1.corr()
# Out:
#                         Prices  Total_Price   Ratings  Booking_Discounts(%)  \
# Prices                1.000000     0.957896  0.175658             -0.155173
# Total_Price           0.957896     1.000000  0.147624              0.097389
# Ratings               0.175658     0.147624  1.000000             -0.052369
# Booking_Discounts(%) -0.155173     0.097389 -0.052369              1.000000
# Reviews               0.396877     0.361191  0.215610             -0.052257
#
#                        Reviews
# Prices                0.396877
# Total_Price           0.361191
# Ratings               0.215610
# Booking_Discounts(%) -0.052257
# Reviews               1.000000

# %%
df1.Hotels.value_counts()
# Out:
# Townhouse 1143 Admire Rooms                              2
# OYO Home 78004 G-cloud                                   2
# OYO 73610 Home Tree Service Apartment                    2
# OYO Townhouse 1080 Chennai Central                       2
# Flagship 5765 Chennai Residency T Nagar                  2
#                                                         ..
# Flagship 1246 Raaj Residency                             1
# OYO Townhouse 1067 Nandanam                              1
# OYO Home 78185 Harma Residency                           1
# OYO 92943 Ram Krish Mahal                                1
# OYO Townhouse 237 Near Pallavaram - Thoraipakkam Road    1
# Name: Hotels, Length: 143, dtype: int64

# %%
df1.duplicated().sum()
# Out:
# 14
