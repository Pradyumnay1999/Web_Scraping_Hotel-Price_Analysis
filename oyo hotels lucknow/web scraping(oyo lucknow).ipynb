# %%
import numpy as np 
import pandas as pd

# %%
import time
import requests
from bs4 import BeautifulSoup

# %%
url='https://www.oyorooms.com/search?location=Lucknow%2C%20Uttar%20Pradesh%2C%20India&city=Lucknow&searchType=city&checkin=13%2F11%2F2022&checkout=14%2F11%2F2022&roomConfig%5B%5D=2&country=india&guests=2&rooms=1&filters%5Bcity_id%5D=24'

# %%
page = requests.get(url, headers={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36'})
#page = requests.get(url)
print(page.status_code)
# Out:
# 200

# %%
pagecontent = page.text
pagecontent
# Out:
# '\n    <!doctype html>\n    <html lang="en" dir=ltr>\n    <head>\n      <meta charSet="utf-8" />\n      <meta httpEquiv="x-ua-compatible" content="ie=edge; chrome=1" />\n      <meta name="google-site-verification" content="lCkLu-7S0Eb5LOgDgmoWxSWzbopNfzKW01ZEe3ldsOc" />\n      <script type="text/javascript">\n      \twindow.renderingSource=\'server\'\n        var host = window.location.hostname;\n        if (!String.prototype.endsWith) {\n\t        String.prototype.endsWith = function(search, this_len) {\n\t\t        if (this_len === undefined || this_len > this.length) {\n\t\t\t        this_len = this.length;\n\t\t        }\n\t      \t  return this.substring(this_len - search.length, this_len) === search;\n\t        };\n        }\n        if (! (host.endsWith("oyorooms.com") || host.endsWith("oyorooms.ms") || host.endsWith("oyohotels.co.jp") || host.endsWith("hotelesoyo.com") || host.endsWith("oyohotels.com") || host.endsWith("belvilla.co.in") || host.endsWith("oyorooms.io")) && host.indexOf(\'localhost\') < 0){\n          window.location.href="https://www.oyorooms.com";\n        }\n        </script>\n      <meta httpEquiv="content-language" content="en-IN" />\n      <meta name="viewport" content="width=device-width, initial-scale=1.0, user-scalable=0, minimum-scale=1.0" />\n      \n      <meta name="full-screen" content="yes" />\n\n      <meta name="theme-color" content="#F5F5F5" />\n      <link rel="manifest" href="/manifest.json" />\n      <link rel="alternate" href="android-app://com.oyo.consumer/https/www.oyorooms.com/" />\n      <meta name="google" content="notranslate" />\n\n      <meta name="apple-mobile-web-app-capable" content="yes">\n      <meta name="mobile-web-app-capable" content="yes">\n\n\n      <link rel="preconnect" href="https://assets.oyoroomscdn.com" />\n      <link rel="preconnect" href="https://images.oyoroomscdn.com" />\n      <link rel="preconnect" href="https://cdn.moengage.com" />\n      <link rel="preconnect" href="https://www.google-analytics.com" />\n      <link rel="dns-prefetch" href="https://assets.oyoroomscdn.com" />\n      <link rel="dns-prefetch" href="https://images.oyoroomscdn.com" />\n      <link rel="dns-prefetch" href="https://cdn.moengage.com" />\n      <link rel="dns-prefetch" href="https://www.google-analytics.com" />\n      <link href=/assets/desktop/main.e953701e38dac851bad4.css rel="stylesheet" type="text/css" />\n      <link href=/assets/desktop/commoncss.4b11f9835e190a537f3c.css rel="stylesheet" type="text/css" />\n      <link href=/assets/desktop/listing.f60cc288d2f35137d287.css rel="stylesheet" type="text/css" />\n      <script type="text/javascript">\n          window.trackingId = "UA-52365165-1";\n          window.user_id = undefined || \'\';\n          (function(i,s,o,g,r,a,m){i[\'GoogleAnalyticsObject\']=r;i[r]=i[r]||function(){\n                      (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),\n                  m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)\n          })(window,document,\'script\',\'https://www.google-analytics.com/analytics.js\',\'ga\');\n          ga(\'create\', {\n              userId : window.user_id || \'\',\n              trackingId: window.trackingId,\n              cookieDomain: \'auto\',\n              siteSpeedSampleRate: 30,\n              useAmpClientId: true,\n              cookieFlags: "SameSite=None; Secure"\n          });\n          ga(\'require\',\'ec\');\n      </script>\n\n      <script type="application/ld+json">\n        {\n          "@context": "https://schema.org/",\n          "@type": "Organization",\n          "name": "OYO Rooms",\n          "url":"https://www.oyorooms.com/",\n          "logo":"https://www.oyorooms.com/favicon.ico",\n          "sameAs":["https://www.facebook.com/oyorooms", "https://twitter.com/oyorooms", "https://www.pinterest.com/oyorooms/", "https://plus.google.com/u/0/116027434827284400729/posts"],\n          "contactPoint":{\n            "@t ...

# %%
soup = BeautifulSoup(pagecontent)
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# <html dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="ie=edge; chrome=1" httpequiv="x-ua-compatible"/>
# <meta content="lCkLu-7S0Eb5LOgDgmoWxSWzbopNfzKW01ZEe3ldsOc" name="google-site-verification"/>
# <script type="text/javascript">
#       	window.renderingSource='server'
#         var host = window.location.hostname;
#         if (!String.prototype.endsWith) {
# 	        String.prototype.endsWith = function(search, this_len) {
# 		        if (this_len === undefined || this_len > this.length) {
# 			        this_len = this.length;
# 		        }
# 	      	  return this.substring(this_len - search.length, this_len) === search;
# 	        };
#         }
#         if (! (host.endsWith("oyorooms.com") || host.endsWith("oyorooms.ms") || host.endsWith("oyohotels.co.jp") || host.endsWith("hotelesoyo.com") || host.endsWith("oyohotels.com") || host.endsWith("belvilla.co.in") || host.endsWith("oyorooms.io")) && host.indexOf('localhost') < 0){
#           window.location.href="https://www.oyorooms.com";
#         }
#         </script>
# <meta content="en-IN" httpequiv="content-language"/>
# <meta content="width=device-width, initial-scale=1.0, user-scalable=0, minimum-scale=1.0" name="viewport"/>
# <meta content="yes" name="full-screen"/>
# <meta content="#F5F5F5" name="theme-color"/>
# <link href="/manifest.json" rel="manifest"/>
# <link href="android-app://com.oyo.consumer/https/www.oyorooms.com/" rel="alternate"/>
# <meta content="notranslate" name="google"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="yes" name="mobile-web-app-capable"/>
# <link href="https://assets.oyoroomscdn.com" rel="preconnect"/>
# <link href="https://images.oyoroomscdn.com" rel="preconnect"/>
# <link href="https://cdn.moengage.com" rel="preconnect"/>
# <link href="https://www.google-analytics.com" rel="preconnect"/>
# <link href="https://assets.oyoroomscdn.com" rel="dns-prefetch"/>
# <link href="https://images.oyoroomscdn.com" rel="dns-prefetch"/>
# <link href="https://cdn.moengage.com" rel="dns-prefetch"/>
# <link href="https://www.google-analytics.com" rel="dns-prefetch"/>
# <link href="/assets/desktop/main.e953701e38dac851bad4.css" rel="stylesheet" type="text/css"/>
# <link href="/assets/desktop/commoncss.4b11f9835e190a537f3c.css" rel="stylesheet" type="text/css"/>
# <link href="/assets/desktop/listing.f60cc288d2f35137d287.css" rel="stylesheet" type="text/css"/>
# <script type="text/javascript">
#           window.trackingId = "UA-52365165-1";
#           window.user_id = undefined || '';
#           (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#                       (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#                   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#           })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#           ga('create', {
#               userId : window.user_id || '',
#               trackingId: window.trackingId,
#               cookieDomain: 'auto',
#               siteSpeedSampleRate: 30,
#               useAmpClientId: true,
#               cookieFlags: "SameSite=None; Secure"
#           });
#           ga('require','ec');
#       </script>
# <script type="application/ld+json">
#         {
#           "@context": "https://schema.org/",
#           "@type": "Organization",
#           "name": "OYO Rooms",
#           "url":"https://www.oyorooms.com/",
#           "logo":"https://www.oyorooms.com/favicon.ico",
#           "sameAs":["https://www.facebook.com/oyorooms", "https://twitter.com/oyorooms", "https://www.pinterest.com/oyorooms/", "https://plus.google.com/u/0/116027434827284400729/posts"],
#           "contactPoint":{
#             "@type":"ContactPoint",
#             "telephone":"+91 9313 9313 93",
#             "contactType":"Customer Service"
#           }
#         }
#       </script>
# <title data-react-helmet="true">Hotels in Lucknow Starting @ ₹382 - Upto 78% OFF on 213 Lucknow Hotels</title>
# <meta content="https://www.facebook.com/oyorooms" data-react-helmet="true" property="og:publisher"/><meta content="/search/?location=Lucknow%2C%20Uttar%20Pradesh%2C%20India&amp;city=Lucknow&amp;searchType=city&amp;checkin=13%2F11%2F2022&amp;checkout=14%2F11%2F2022&amp;roomConfig%5B%5D=2&amp;country=india&amp;guests=2&amp;rooms=1&amp;filters%5Bcity_id%5D=24" data-react-helmet="true" property="og:url"/><meta content="1576475359296300" data-react-helmet="true" property="fb:app_id"/><meta content="app" data-react-helmet="true" name="twitter:card"/><meta content="in" data-react-helmet="true" name="twitter:app:country"/><meta content="OYO Rooms" data-react-helmet="true" name="twitter:text:title"/><meta content="https://assets.oyoroomscdn.com/pwa/icons/oyo-logo-120x120.jpg" data-react-helmet="true" name="twitter:image"/><meta content="Book Hotels in Lucknow &amp; Save up to 78%, Price starts @₹382. OYO Promises &amp;#9989Complimentary Breakfast &amp;#9989Free Cancellation &amp;#9989Free WiFi &amp;#9989AC Room &amp;#9989Spotless linen &amp; &amp;#9989Clean Washrooms." data-react-helmet="true" name="description"/><meta content="OYO Rooms, OYO Hotels, OYO Inn, Budget Hotels, Guest House, Budget Hotels in Gurgaon, Guest House in Gurgaon, Budget Hotels in Delhi, Guest House in Delhi, Budget Hotels in Noida, Guest House in Noida, Budget Hotels in Bangalore, Guest House in Bangalore, Budget Hotels in Mumbai, Guest House in Mumbai, Cheap Hotels in Delhi, Cheap Hotels in Gurgaon, Cheap Hotels in Noida, Cheap Hotels in Bangalore, Cheap Hotels in Mumbai" data-react-helmet="true" name="keywords"/><meta content="Hotels in Lucknow Starting @ ₹382 - Upto 78% OFF on 213 Lucknow Hotels" data-react-helmet="true" property="og:title"/><meta content="Book Hotels in Lucknow &amp; Save up to 78%, Price starts @₹382. OYO Promises &amp;#9989Complimentary Breakfast &amp;#9989Free Cancellation &amp;#9989Free WiFi &amp;#9989AC Room &amp;#9989Spotless linen &amp; &amp;#9989Clean Washrooms." data-react-helmet="true" property="og:description"/><meta content="Hotels in Lucknow Starting @ ₹382 - Upto 78% OFF on 213 Lucknow Hotels" data-react-helmet="true" name="twitter:title"/><meta content="Book Hotels in Lucknow &amp; Save up to 78%, Price starts @₹382. OYO Promises &amp;#9989Complimentary Breakfast &amp;#9989Free Cancellation &amp;#9989Free WiFi &amp;#9989AC Room &amp;#9989Spotless linen &amp; &amp;#9989Clean Washrooms." data-react-helmet="true" name="twitter:description"/><meta content="OYO Rooms" data-react-helmet="true" property="og:site_name"/><meta content="https://images.oyoroomscdn.com/uploads/hotel_image/195090/bvsovadfddar.jpg" data-react-helmet="true" property="og:image"/><meta content="hotel" data-react-helmet="true" property="og:type"/><meta content="https://www.oyorooms.com/" data-react-helmet="true" name="twitter:url"/><meta content="NOINDEX, NOFOLLOW" data-react-helmet="true" name="ROBOTS"/><meta content="unavailable_after: Wednesday, 01-Jan-20 01:00:00 IST" data-react-helmet="true" name="robots"/>
# <link data-react-helmet="true" href="https://www.oyorooms.com/favicon.ico" rel="icon"/><link data-react-helmet="true" href="https://www.oyorooms.com/favicon.ico" rel="icon" sizes="48x48" type="image/x-icon"/><link data-react-helmet="true" href="https://assets.oyoroomscdn.com/pwa/icons/oyo-logo-48x48.jpg" rel="apple-touch-icon" sizes="48x48"/><link data-react-helmet="true" href="https://assets.oyoroomscdn.com/pwa/icons/oyo-logo-76x76.jpg" rel="apple-touch-icon" sizes="76x76"/><link data-react-helmet="true" href="https://assets.oyoroomscdn.com/pwa/icons/oyo-logo-120x120.jpg" rel="apple-touch-icon" sizes="120x120"/><link data-react-helmet="true" href="https://assets.oyoroomscdn.com/pwa/icons/oyo-logo-152x152.jpg" rel="apple-touch-icon" sizes="152x152"/><link data-react-helmet="true" href="/" rel="canonical"/>
# <link as="script" href="/assets/desktop/runtime.d4e4471e99372df5fcc3.js" rel="preload"/>
# <link as="script" href="/assets/desktop/externalvendor.1fd4612a45561d7117bb.js" rel="preload"/>
# <link as="script" href="/assets/desktop/common.cb6bb20e01d65d694f3a.js" rel="preload"/>
# <link as="script" href="/assets/desktop/commoncss.209925228a244e033ddd.js" rel="preload"/>
# <link as="script" href="/assets/desktop/listing.06b76248591c9a1458b8.js" rel="preload"/>
# <link as="script" href="/assets/desktop/main.6059aab2c8be16cb6f0a.js" rel="preload"/>
# </head>
# <body itemscope="" itemtype="http://schema.org/WebPage">
# <script type="text/javascript">
#             window.abExpConfig = {"sold":{"val":0,"v":1},"mww2":{"val":"1","v":"4"},"hbad":{"val":0,"v":1},"BnTc":{"val":0,"v":1},"near":{"val":0,"v":1},"ioab":{"val":"1","v":"2"},"mhdp":{"val":"1","v":"5"},"bcrp":{"val":"0","v":"5"},"pwbs":{"val":"1","v":"3"},"mwsb":{"val":0,"v":1},"slin":{"val":"1","v":"11"},"hsdm":{"val":"2","v":"2"},"lpex":{"val":0,"v":1},"lphv":{"val":0,"v":1},"dpcv":{"val":0,"v":1},"gmab":{"val":0,"v":1},"urhe":{"val":0,"v":1},"prdp":{"val":0,"v":1},"comp":{"val":"0","v":"5"},"sldw":{"val":0,"v":1},"mdab":{"val":0,"v":1},"nrmp":{"val":"1","v":"3"},"nhyw":{"val":"1","v":"1"},"wboi":{"val":0,"v":1},"sst":{"val":0,"v":1},"txwb":{"val":0,"v":1},"pod2":{"val":0,"v":1},"lnhd":{"val":0,"v":1},"ppsi":{"val":"0","v":"1"},"gcer":{"val":"1","v":"3"},"recs":{"val":"1","v":"1"},"swhp":{"val":0,"v":1},"lvhm":{"val":"1","v":"3"},"gmbr":{"val":"1","v":"15"},"yolo":{"val":"1","v":"6"},"rcta":{"val":"1","v":"3"},"cbot":{"val":"1","v":"5"},"otpv":{"val":"1","v":"7"},"trtr":{"val":0,"v":1},"lbhw":{"val":0,"v":1},"ndbp":{"val":"0","v":"2"},"mapu":{"val":"1","v":"3"},"nclc":{"val":"1","v":"5"},"dwsl":{"val":"1","v":"2"},"eopt":{"val":"1","v":"3"},"wizi":{"val":"1","v":"2"},"morr":{"val":"1","v":"2"},"yopb":{"val":"0","v":"3"},"TTP":{"val":"1","v":"4"},"Dweb":{"val":"1","v":1},"aimw":{"val":"1","v":"2"},"hdpn":{"val":"1","v":"4"},"web2":{"val":"0","v":"3"},"log2":{"val":"0","v":"3"},"spw1":{"val":0,"v":1},"strf":{"val":0,"v":1},"ugce":{"val":"0","v":"2"},"ltvr":{"val":"1","v":"4"},"hwiz":{"val":"0","v":"3"},"wizz":{"val":"1","v":"5"},"lpcp":{"val":"0","v":"2"},"clhp":{"val":"0","v":"2"},"prwt":{"val":"0","v":"2"},"cbhd":{"val":"0","v":"2"},"ins2":{"val":"3","v":"8"}};
#
#             // SW-INSTALLATION
#             (function() {
#               if ('serviceWorker' in navigator ) {
#                   window.addEventListener('load', function(){
#                     navigator.serviceWorker.register("/service-worker-desktop.js",{scope: "/"});
#                   });
#               }
#           })();
#         </script>
# <div id="root" style="height:100vh;"><style data-emotion-c="1acbpvw r9lts4 g49e0i 1iupfd9 s2hsb0 162c9d0 8ijf8a p2g0oj jj695s 1x32axc xotlao 1t05q14 mk5v0g bxjamc g7fw8n gcjisk qwx4r ml1sc2">@-webkit-keyframes animation-1acbpvw{0%{opacity:0;}100%{opacity:1;}}@keyframes animation-1acbpvw{0%{opacity:0;}100%{opacity:1;}}@-webkit-keyframes animation-r9lts4{0%{background-position:-350px 0;}100%{background-position:350px 0;}}@keyframes animation-r9lts4{0%{background-position:-350px 0;}100%{background-position:350px 0;}}@-webkit-keyframes animation-g49e0i{from{-webkit-transform:translate3d(0,-100 %,0);-ms-transform:translate3d(0,-100 %,0);transform:translate3d(0,-100 %,0);visibility:visible;}to{-webkit-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);transform:translate3d(0,0,0);}}@keyframes animation-g49e0i{from{-webkit-transform:translate3d(0,-100 %,0);-ms-transform:translate3d(0,-100 %,0);transform:translate3d(0,-100 %,0);visibility:visible;}to{-webkit-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);transform:translate3d(0,0,0);}}@-webkit-keyframes animation-1iupfd9{from{-webkit-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);transform:translate3d(0,0,0);}to{visibility:hidden;-webkit-transform:translate3d(0,-100 %,0);-ms-transform:translate3d(0,-100 %,0);transform:translate3d(0,-100 %,0);}}@keyframes animation-1iupfd9{from{-webkit-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);transform:translate3d(0,0,0);}to{visibility:hidden;-webkit-transform:translate3d(0,-100 %,0);-ms-transform:translate3d(0,-100 %,0);transform:translate3d(0,-100 %,0);}}@-webkit-keyframes animation-s2hsb0{from{-webkit-transform:translate3d(100 %,0,0);-ms-transform:translate3d(100 %,0,0);transform:translate3d(100 %,0,0);visibility:visible;}to{-webkit-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);transform:translate3d(0,0,0);}}@keyframes animation-s2hsb0{from{-webkit-transform:translate3d(100 %,0,0);-ms-transform:translate3d(100 %,0,0);transform:translate3d(100 %,0,0);visibility:visible;}to{-webkit-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);transform:translate3d(0,0,0);}}@-webkit-keyframes animation-162c9d0{from{-webkit-transform:translate3d(0,100 %,0);-ms-transform:translate3d(0,100 %,0);transform:translate3d(0,100 %,0);visibility:visible;}to{-webkit-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);transform:translate3d(0,0,0);}}@keyframes animation-162c9d0{from{-webkit-transform:translate3d(0,100 %,0);-ms-transform:translate3d(0,100 %,0);transform:translate3d(0,100 %,0);visibility:visible;}to{-webkit-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);transform:translate3d(0,0,0);}}@-webkit-keyframes animation-8ijf8a{from{-webkit-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);transform:translate3d(0,0,0);}to{visibility:hidden;-webkit-transform:translate3d(100 %,0,0);-ms-transform:translate3d(100 %,0,0);transform:translate3d(100 %,0,0);}}@keyframes animation-8ijf8a{from{-webkit-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);transform:translate3d(0,0,0);}to{visibility:hidden;-webkit-transform:translate3d(100 %,0,0);-ms-transform:translate3d(100 %,0,0);transform:translate3d(100 %,0,0);}}@-webkit-keyframes animation-p2g0oj{from{-webkit-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);transform:translate3d(0,0,0);opacity:0;}to{opacity:1;-webkit-transform:translate3d(0,100%,0);-ms-transform:translate3d(0,100%,0);transform:translate3d(0,100%,0);}}@keyframes animation-p2g0oj{from{-webkit-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);transform:translate3d(0,0,0);opacity:0;}to{opacity:1;-webkit-transform:translate3d(0,100%,0);-ms-transform:translate3d(0,100%,0);transform:translate3d(0,100%,0);}}@-webkit-keyframes animation-jj695s{0%{-webkit-transform:scale(1) translate3d(0,0,0);-ms-transform:scale(1) translate3d(0,0,0);transform:scale(1) translate3d(0,0,0);-webkit-transform-origin:50% 16%;-ms-transfo ...
# <script>
#           window.__PRELOADED_STATE__ = {"home":{"loading":true,"error":null,"data":[{"data":{"left_icons":[{"icon_name":"OyoIcon","icon_title":"","icon_description":"","cta":{"type":"","data":{"action_url":"/"}}}],"right_icons":[{"icon_name":"Text","icon_title":"About us","icon_description":"","cta":{"type":"","data":{"action_url":"https://www.oyorooms.com/about"}}},{"icon_name":"Text","icon_title":"Partner with us","icon_description":"","cta":{"type":"","data":{"action_url":"https://partner.oyorooms.com/?utm_campaign=dweb&utm_medium=dweb&utm_source=dweb"}}},{"icon_name":"TextWithBorder","icon_title":"Login","icon_description":"","show_sticky":true,"cta":{"type":"","data":{"action_url":"https://www.oyorooms.com/login?country=us&retUrl=/us"}}}],"search_data":{"hint":"Search for a city or hotel","show_near_me":true,"near_me_data":{"icon_name":"near me","icon_title":"Near me","icon_description":"","cta":{"type":"","data":{}}},"show_search_bar":true,"error_message":"Please enter your destination","show_sticky":true},"datepax_data":{"checkin_title":"Check-in","checkout_title":"Check-out","show_datepax_picker":true,"nights":"%sN","guest_title":"Rooms and guests","rooms_config":"1,0,0","date_title":"Date"},"search_button_cta":{"title":"Search"},"content_list":["search_data","datepax_data","search_button_cta"],"bgData":[{"media_url":"http://assets.oyoroomscdn.com/Homepageimagewithoverlay.png","media_type":"image"}],"tagLine":{"title":"You are on your way","sub_title":"Book hotels & homes in","sub_titles":["250+ locations","80+ Countries","3 Taps"]}},"id":3767,"type":"home_header_web","data_source":"inline"}],"loaded":false,"extra":false},"searchobj":{"location":"Lucknow, Uttar Pradesh, India","city":"lucknow","searchType":"city","tag":"","coupon":"","checkin":"13/11/2022","checkout":"14/11/2022","roomConfig":[2],"localityId":"","showSearchElements":false,"guests":2,"rooms":1,"countryName":"India","cityId":"24"},"deal":{"isFetching":true,"data":{},"error":""},"citiesByChar":{"isFetching":true,"data":{},"error":{}},"cities":{"count":195,"isFetching":true,"data":[{"name":"Agra","country_name":"India"},{"name":"Ahmedabad","country_name":"India"},{"name":"Ajmer","country_name":"India"},{"name":"Alappuzha","country_name":"India"},{"name":"Alibag","country_name":"India"},{"name":"Aligarh","country_name":"India"},{"name":"Allahabad","country_name":"India"},{"name":"Alwar","country_name":"India"},{"name":"Ambala","country_name":"India"},{"name":"Amritsar","country_name":"India"},{"name":"Anand","country_name":"India"},{"name":"Aurangabad","country_name":"India"},{"name":"Baddi","country_name":"India"},{"name":"Bangalore","country_name":"India"},{"name":"Bareilly","country_name":"India"},{"name":"Bathinda","country_name":"India"},{"name":"Behrampur","country_name":"India"},{"name":"Bhilai","country_name":"India"},{"name":"Bhilwara","country_name":"India"},{"name":"Bhiwadi","country_name":"India"},{"name":"Bhopal","country_name":"India"},{"name":"Bhubaneswar","country_name":"India"},{"name":"Bijainagar","country_name":"India"},{"name":"Bikaner","country_name":"India"},{"name":"Bilaspur","country_name":"India"},{"name":"Bodhgaya","country_name":"India"},{"name":"Calicut","country_name":"India"},{"name":"Cameron-Highlands","country_name":"Malaysia"},{"name":"Chandigarh","country_name":"India"},{"name":"Chennai","country_name":"India"},{"name":"Chikmagalur","country_name":"India"},{"name":"Chittorgarh","country_name":"India"},{"name":"Coimbatore","country_name":"India"},{"name":"Coonoor","country_name":"India"},{"name":"Coorg","country_name":"India"},{"name":"Corbett-Ramnagar","country_name":"India"},{"name":"Cuttack","country_name":"India"},{"name":"Dahej","country_name":"India"},{"name":"Dalhousie","country_name":"India"},{"name":"Daman","country_name":"India"},{"name":"Darjeeling","country_name":"India"},{"name":"Dehradun","country_name":"India"},{"name":"Delhi","country_name":"India"},{"name":"Dewas","country_name":"India"},{"name":"Dharamshala ...
#         </script>
# <script>
#             window.__ROUTE_NAME__ = 'listing'
#         </script>
# <script src="/assets/desktop/runtime.d4e4471e99372df5fcc3.js"></script>
# <script src="/assets/desktop/externalvendor.1fd4612a45561d7117bb.js"></script>
# <script src="/assets/desktop/common.cb6bb20e01d65d694f3a.js"></script>
# <script src="/assets/desktop/commoncss.209925228a244e033ddd.js"></script>
# <script src="/assets/desktop/listing.06b76248591c9a1458b8.js"></script>
# <script src="/assets/desktop/main.6059aab2c8be16cb6f0a.js"></script>
# <noscript>
# <iframe height="0" src="http://www.googletagmanager.com/ns.html?id=GTM-PTZF36" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <script>
#         var prefetchExcludedList = [
#           '/assets/desktop/listing.06b76248591c9a1458b8.js'
#
#           ]
#           if (false){
#             prefetchExcludedList = [
#             '/assets/desktop/listing.b3cfc7a1b429e59faa40.v1.mjs'
#             ]
#           }
#           function script(url) {
#             if((url == "undefined") || (prefetchExcludedList.indexOf(url)>=0)){
#               return null;
#             }
#             var s = document.createElement('link');
#             s.rel = 'prefetch';
#             s.href = url;
#             var x = document.getElementsByTagName('head')[0];
#              //send simply
#             x.appendChild(s);
#           }
#           if (window.addEventListener) {
#               window.addEventListener('load', loadThirdPartyScript, false);
#           } else if (window.attachEvent) {
#               window.attachEvent('onload', loadThirdPartyScript);
#           }
#
#
#
#           function loadThirdPartyScript() {
#               var scriptNameArr = ["countryFlag","assist","home","newHome","listing","detail","bookingDetails","allcities","staticPage","wizard","wizardPlus","trust-and-safety","fourOfour","saveCard","postSaveCard","myBooking","unmarriedCouplesPage","accountDetails","deal","auth","SearchAffiliate","main","oyoforukraine","intl-id","intl-es","intl-ar","intl-vi","intl-hi","intl-pt","intl-ja","intl-th","intl-en","couponOffersPopup","PaymentWrapper/b","PaymentWrapper","authOld","yoImageUploadTemplate","sockjs","externalvendor","common","commoncss","","runtime"];
#               var isSWSupported = 'serviceWorker' in navigator;
#
#             //for other browsers
#             var legacyScriptsToLoad = [
#               '/assets/desktop/listing.06b76248591c9a1458b8.js',
#               '/assets/desktop/home.c75406d1d0c2d35f257d.js',
#               '/assets/desktop/detail.1314717f407dc8f9e11e.js',
#               ''
#             ]
#             for(var i=0 ; i<legacyScriptsToLoad.length;i++){
#                 !isSWSupported && script(legacyScriptsToLoad[i]);
#             }
#
#
#               // GTM
#               (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#               new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#               j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#               '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#               })(window,document,'script','dataLayer','GTM-PTZF36');
#
#               //Load moengage script
#               (function(i,s,o,g,r,a,m,n){
# 	          i['moengage_object']=r;t={}; q = function(f){return function(){(i['moengage_q']=i['moengage_q']||[]).push({f:f,a:arguments});};};
# 	          f = ['track_event','add_user_attribute','add_first_name','add_last_name','add_email','add_mobile',
# 	          'add_user_name','add_gender','add_birthday','destroy_session','add_unique_user_id','moe_events','call_web_push','track','location_type_attribute'];
# 	          for(k in f){t[f[k]]=q(f[k]);}
# 	          a=s.createElement(o);m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m);
# 	          i['moe']=i['moe'] || function(){n=arguments[0];return t;}; a.onload=function(){if(n){i[r] = moe(n);}};
# 	          })(window,document,'script','https://cdn.moengage.com/webpush/moe_webSdk.min.latest.js','Moengage');
# 	          Moengage = moe({
# 	            app_id:"MIJ2OM5MK5YSUOX8XMBAZJHD",
#               debug_logs: 0,
#               swPath: "/service-worker-desktop.js"
#             });
#           }
#         </script>
# </body>
# </html>>

# %%
HotelS = []
RatingS = []
ReviweS= []
PriceS = []
DiscountS=[]
Total_PriceS=[]
AmenitieS=[]
LocationS=[]
Information=[]


for i in range(1,25):
    start_time=time.time()
    url = 'https://www.oyorooms.com/search?location=Lucknow%2C%20Uttar%20Pradesh%2C%20India&city=Lucknow&searchType=city&checkin=13%2F11%2F2022&checkout=14%2F11%2F2022&roomConfig%5B%5D=2&country=india&guests=2&rooms=1&filters%5Bcity_id%5D=24&page={}'.format(i)
    page = requests.get(url, headers={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36'})
    pagecontent=page.text
    soup = BeautifulSoup(page.text)
    
    for x in soup.find_all('div', attrs = {'class': 'oyo-cell--12-col oyo-cell--8-col-tablet oyo-cell--4-col-phone'}):
        
        
        #Hotels
        
        hotel_name = x.find('h3', attrs = {'class': 'listingHotelDescription__hotelName d-textEllipsis'})
        
        if hotel_name is None:
            HotelS.append(np.NaN)
        else:
            HotelS.append(hotel_name.text)
            
        
        #Ratings
        
        Ratings = x.find('span', attrs = {'class': 'is-fontBold hotelRating__rating hotelRating__rating--verygood hotelRating__rating--clickable'})

        if Ratings is None:
            RatingS.append(np.NaN)
        else:
            RatingS.append(Ratings.text)   
      
        #Reviwes
        
        Reviwes = x.find('span', attrs = {'class': 'hotelRating__ratingSummary'})

        if Reviwes is None:
            
            ReviweS.append(np.NaN)
        else:
            ReviweS.append(Reviwes.text)   

        
        #Price
        
        price = x.find('span',attrs = {'class': 'listingPrice__finalPrice'})
        
        if price is None:
            PriceS.append(np.NaN)
        else:
            PriceS.append(price.text)


        
        #Discounts
        
        Discount_on_price = x.find('span',attrs = {'class': 'listingPrice__percentage'})
        
        if Discount_on_price is None:
            DiscountS.append(np.NaN)
        else:
            DiscountS.append(Discount_on_price.text)
        
        
         #Total_price
            
        Total_price = x.find('span',attrs = {'class': 'listingPrice__slashedPrice d-body-lg'})
        
        if Total_price is None:
            Total_PriceS.append(np.NaN)
        else:
            Total_PriceS.append(Total_price.text)
        
        #Amenities
        
        Amenities = x.find('span', attrs = {'class':'d-body-sm'})
        
        if Amenities is None:
            AmenitieS.append(np.NaN)
        else:
            AmenitieS.append(Amenities.text)
            
            
            
            
        #Location
        
        Location = x.find('div',attrs = {'class': 'd-body-lg listingHotelDescription__hotelAddress'})
        
        if Location is None:
            LocationS.append(np.NaN)
        else:
            LocationS.append(Location.text)
            
            
            
        #Information
        
        Info = x.find('div',attrs = {'class': 'c-1sugwtq'})
        
        if Info is None:
            Information.append(np.NaN)
        else:
            Information.append(Info.text)
            
            
    end_time = time.time()
    print('Page {} completed in {} seconds'. format(i, end_time-start_time))
# Out:
# Page 1 completed in 4.853135108947754 seconds
# Page 2 completed in 3.867581844329834 seconds
# Page 3 completed in 3.374126434326172 seconds
# Page 4 completed in 7.464280366897583 seconds
# Page 5 completed in 3.1717796325683594 seconds
# Page 6 completed in 3.21722674369812 seconds
# Page 7 completed in 4.606596946716309 seconds
# Page 8 completed in 3.741469144821167 seconds
# Page 9 completed in 4.275322675704956 seconds
# Page 10 completed in 4.145507335662842 seconds
# Page 11 completed in 2.7412638664245605 seconds
# Page 12 completed in 2.535848617553711 seconds
# Page 13 completed in 2.7375924587249756 seconds
# Page 14 completed in 2.365490674972534 seconds
# Page 15 completed in 2.74685001373291 seconds
# Page 16 completed in 2.700740337371826 seconds
# Page 17 completed in 2.8172876834869385 seconds
# Page 18 completed in 3.1428208351135254 seconds
# Page 19 completed in 3.221972703933716 seconds
# Page 20 completed in 3.622028112411499 seconds
# Page 21 completed in 3.662672281265259 seconds
# Page 22 completed in 2.868877649307251 seconds
# Page 23 completed in 7.056748390197754 seconds
# Page 24 completed in 3.3524715900421143 seconds

# %%
print(len(HotelS))
print(len(RatingS))
print(len(PriceS))
print(len(Total_PriceS))
print(len(DiscountS))
print(len(AmenitieS))
print(len(LocationS))
print(len(Information))
print(len(ReviweS))
# Out:
# 213
# 213
# 213
# 213
# 213
# 213
# 213
# 213
# 213

# %%
df1 = pd.DataFrame({'Hotels':HotelS,
                    'Prices':PriceS,
                    'Total_Price':Total_PriceS,
                    'Ratings':RatingS,
                    'Booking_Discounts(%)':DiscountS,
                    'Reviews':ReviweS,
                    'Facilities':AmenitieS,
                    'Address':LocationS,
                    'Informations':Information})
df1
# Out:
#                                         Hotels Prices Total_Price Ratings  \
# 0               OYO Townhouse 973 Jalsa Resort   ₹832       ₹3493    4.3
# 1                 OYO Townhouse 1094 North Inn   ₹603       ₹2154     NaN
# 2     OYO Flagship 77242 Radhey Krishna Bhawan   ₹499       ₹2664    4.0
# 3    Townhouse OAK Geetraj By Insight Services  ₹1448       ₹5169     NaN
# 4           OYO HOME 702340 Hotel Palassio Inn   ₹617       ₹2204     NaN
# ..                                         ...    ...         ...     ...
# 208               OYO 85551 Hotel Rudra Palace    NaN         NaN     NaN
# 209                 Flagship 79156 Hotel Tokyo    NaN         NaN    4.3
# 210       Flagship 92692 Star Stay Guest House    NaN         NaN     NaN
# 211      Capital O 84117 The Diamond Night Inn    NaN         NaN     NaN
# 212               OYO 45546 Woodstock Homestay    NaN         NaN     NaN
#
#     Booking_Discounts(%)         Reviews          Facilities  \
# 0                76% off   (818 Ratings)   Parking facility
# 1                72% off   (851 Ratings)   Parking facility
# 2                81% off   (914 Ratings)         Hair Dryer
# 3                71% off  (2353 Ratings)         Hair Dryer
# 4                72% off             NaN           Elevator
# ..                   ...             ...                 ...
# 208                  NaN   (542 Ratings)   Parking facility
# 209                  NaN   (452 Ratings)     Doctor on call
# 210                  NaN   (165 Ratings)   Parking facility
# 211                  NaN   (287 Ratings)     Doctor on call
# 212                  NaN    (65 Ratings)          Reception
#
#                                                Address  \
# 0         Near Khurdahi Bazar, Sultanpur Road, Lucknow
# 1                               Faizabad Road, Lucknow
# 2    Saraswati puram near convention center Raebare...
# 3                                    Alambagh, Lucknow
# 4                       Krishna Nagar Lucknow, Lucknow
# ..                                                 ...
# 208                                    226023, Lucknow
# 209  1/1000 Vinay Khand (patrakarpuram) Near Malik ...
# 210  Star Tower Aliganj Opp Kendriya Bhawan Lucknow...
# 211                               Gomti Nagar, Lucknow
# 212      Near Tender Hearts School, Mahanagar, Lucknow
#
#                                      Informations
# 0      6 people booked this hotel in last 6 hours
# 1     16 people booked this hotel in last 6 hours
# 2              All staff vaccinated with 1st dose
# 3              All staff vaccinated with 1st dose
# 4                                             NaN
# ..                                            ...
# 208  900+ people booked this OYO in last 6 months
# 209            All staff vaccinated with 1st dose
# 210                                           NaN
# 211    6 people booked this hotel in last 6 hours
# 212                                           NaN
#
# [213 rows x 9 columns]

# %%
df1.duplicated().sum()
# Out:
# 15

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213 entries, 0 to 212
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Hotels                213 non-null    object
#  1   Prices                196 non-null    object
#  2   Total_Price           196 non-null    object
#  3   Ratings               50 non-null     object
#  4   Booking_Discounts(%)  196 non-null    object
#  5   Reviews               176 non-null    object
#  6   Facilities            213 non-null    object
#  7   Address               213 non-null    object
#  8   Informations          107 non-null    object
# dtypes: object(9)
# memory usage: 15.1+ KB

# %%
df1['Prices'] = df1['Prices'].astype(str)

# %%
df1['Prices'] = df1['Prices'].apply(lambda x: x.replace('NaN','0000'))

# %%
df1['Prices'] = df1['Prices'].apply(lambda x: x.replace('₹',''))

# %%
df1['Prices'] = df1['Prices'].astype(float)

# %%
df1['Prices'].fillna(df1['Prices'].mean(), inplace = True)

# %%
df1
# Out:
#                                         Hotels       Prices Total_Price  \
# 0               OYO Townhouse 973 Jalsa Resort   832.000000       ₹3493
# 1                 OYO Townhouse 1094 North Inn   603.000000       ₹2154
# 2     OYO Flagship 77242 Radhey Krishna Bhawan   499.000000       ₹2664
# 3    Townhouse OAK Geetraj By Insight Services  1448.000000       ₹5169
# 4           OYO HOME 702340 Hotel Palassio Inn   617.000000       ₹2204
# ..                                         ...          ...         ...
# 208               OYO 85551 Hotel Rudra Palace   854.826531         NaN
# 209                 Flagship 79156 Hotel Tokyo   854.826531         NaN
# 210       Flagship 92692 Star Stay Guest House   854.826531         NaN
# 211      Capital O 84117 The Diamond Night Inn   854.826531         NaN
# 212               OYO 45546 Woodstock Homestay   854.826531         NaN
#
#     Ratings Booking_Discounts(%)         Reviews          Facilities  \
# 0      4.3               76% off   (818 Ratings)   Parking facility
# 1       NaN              72% off   (851 Ratings)   Parking facility
# 2      4.0               81% off   (914 Ratings)         Hair Dryer
# 3       NaN              71% off  (2353 Ratings)         Hair Dryer
# 4       NaN              72% off             NaN           Elevator
# ..      ...                  ...             ...                 ...
# 208     NaN                  NaN   (542 Ratings)   Parking facility
# 209    4.3                   NaN   (452 Ratings)     Doctor on call
# 210     NaN                  NaN   (165 Ratings)   Parking facility
# 211     NaN                  NaN   (287 Ratings)     Doctor on call
# 212     NaN                  NaN    (65 Ratings)          Reception
#
#                                                Address  \
# 0         Near Khurdahi Bazar, Sultanpur Road, Lucknow
# 1                               Faizabad Road, Lucknow
# 2    Saraswati puram near convention center Raebare...
# 3                                    Alambagh, Lucknow
# 4                       Krishna Nagar Lucknow, Lucknow
# ..                                                 ...
# 208                                    226023, Lucknow
# 209  1/1000 Vinay Khand (patrakarpuram) Near Malik ...
# 210  Star Tower Aliganj Opp Kendriya Bhawan Lucknow...
# 211                               Gomti Nagar, Lucknow
# 212      Near Tender Hearts School, Mahanagar, Lucknow
#
#                                      Informations
# 0      6 people booked this hotel in last 6 hours
# 1     16 people booked this hotel in last 6 hours
# 2              All staff vaccinated with 1st dose
# 3              All staff vaccinated with 1st dose
# 4                                             NaN
# ..                                            ...
# 208  900+ people booked this OYO in last 6 months
# 209            All staff vaccinated with 1st dose
# 210                                           NaN
# 211    6 people booked this hotel in last 6 hours
# 212                                           NaN
#
# [213 rows x 9 columns]

# %%
df1['Total_Price'] = df1['Total_Price'].astype(str)

# %%
df1['Total_Price'] = df1['Total_Price'].apply(lambda x: x.replace('NaN','0000'))

# %%
df1['Total_Price'] = df1['Total_Price'].apply(lambda x: x.replace('₹',''))

# %%
df1['Total_Price'] = df1['Total_Price'].astype(float)

# %%
df1['Total_Price'].fillna(df1['Total_Price'].mean(), inplace = True)

# %%
df1
# Out:
#                                         Hotels       Prices  Total_Price  \
# 0               OYO Townhouse 973 Jalsa Resort   832.000000  3493.000000
# 1                 OYO Townhouse 1094 North Inn   603.000000  2154.000000
# 2     OYO Flagship 77242 Radhey Krishna Bhawan   499.000000  2664.000000
# 3    Townhouse OAK Geetraj By Insight Services  1448.000000  5169.000000
# 4           OYO HOME 702340 Hotel Palassio Inn   617.000000  2204.000000
# ..                                         ...          ...          ...
# 208               OYO 85551 Hotel Rudra Palace   854.826531  2866.515306
# 209                 Flagship 79156 Hotel Tokyo   854.826531  2866.515306
# 210       Flagship 92692 Star Stay Guest House   854.826531  2866.515306
# 211      Capital O 84117 The Diamond Night Inn   854.826531  2866.515306
# 212               OYO 45546 Woodstock Homestay   854.826531  2866.515306
#
#     Ratings Booking_Discounts(%)         Reviews          Facilities  \
# 0      4.3               76% off   (818 Ratings)   Parking facility
# 1       NaN              72% off   (851 Ratings)   Parking facility
# 2      4.0               81% off   (914 Ratings)         Hair Dryer
# 3       NaN              71% off  (2353 Ratings)         Hair Dryer
# 4       NaN              72% off             NaN           Elevator
# ..      ...                  ...             ...                 ...
# 208     NaN                  NaN   (542 Ratings)   Parking facility
# 209    4.3                   NaN   (452 Ratings)     Doctor on call
# 210     NaN                  NaN   (165 Ratings)   Parking facility
# 211     NaN                  NaN   (287 Ratings)     Doctor on call
# 212     NaN                  NaN    (65 Ratings)          Reception
#
#                                                Address  \
# 0         Near Khurdahi Bazar, Sultanpur Road, Lucknow
# 1                               Faizabad Road, Lucknow
# 2    Saraswati puram near convention center Raebare...
# 3                                    Alambagh, Lucknow
# 4                       Krishna Nagar Lucknow, Lucknow
# ..                                                 ...
# 208                                    226023, Lucknow
# 209  1/1000 Vinay Khand (patrakarpuram) Near Malik ...
# 210  Star Tower Aliganj Opp Kendriya Bhawan Lucknow...
# 211                               Gomti Nagar, Lucknow
# 212      Near Tender Hearts School, Mahanagar, Lucknow
#
#                                      Informations
# 0      6 people booked this hotel in last 6 hours
# 1     16 people booked this hotel in last 6 hours
# 2              All staff vaccinated with 1st dose
# 3              All staff vaccinated with 1st dose
# 4                                             NaN
# ..                                            ...
# 208  900+ people booked this OYO in last 6 months
# 209            All staff vaccinated with 1st dose
# 210                                           NaN
# 211    6 people booked this hotel in last 6 hours
# 212                                           NaN
#
# [213 rows x 9 columns]

# %%
df1['Ratings'] = df1['Ratings'].astype(str)

# %%
df1['Ratings'] = df1['Ratings'].apply(lambda x: x.replace('NaN','0000'))

# %%
df1['Ratings'] = df1['Ratings'].astype(float)

# %%
df1['Ratings'].fillna(df1['Ratings'].mean(), inplace = True)

# %%
df1
# Out:
#                                         Hotels       Prices  Total_Price  \
# 0               OYO Townhouse 973 Jalsa Resort   832.000000  3493.000000
# 1                 OYO Townhouse 1094 North Inn   603.000000  2154.000000
# 2     OYO Flagship 77242 Radhey Krishna Bhawan   499.000000  2664.000000
# 3    Townhouse OAK Geetraj By Insight Services  1448.000000  5169.000000
# 4           OYO HOME 702340 Hotel Palassio Inn   617.000000  2204.000000
# ..                                         ...          ...          ...
# 208               OYO 85551 Hotel Rudra Palace   854.826531  2866.515306
# 209                 Flagship 79156 Hotel Tokyo   854.826531  2866.515306
# 210       Flagship 92692 Star Stay Guest House   854.826531  2866.515306
# 211      Capital O 84117 The Diamond Night Inn   854.826531  2866.515306
# 212               OYO 45546 Woodstock Homestay   854.826531  2866.515306
#
#      Ratings Booking_Discounts(%)         Reviews          Facilities  \
# 0      4.300              76% off   (818 Ratings)   Parking facility
# 1      4.188              72% off   (851 Ratings)   Parking facility
# 2      4.000              81% off   (914 Ratings)         Hair Dryer
# 3      4.188              71% off  (2353 Ratings)         Hair Dryer
# 4      4.188              72% off             NaN           Elevator
# ..       ...                  ...             ...                 ...
# 208    4.188                  NaN   (542 Ratings)   Parking facility
# 209    4.300                  NaN   (452 Ratings)     Doctor on call
# 210    4.188                  NaN   (165 Ratings)   Parking facility
# 211    4.188                  NaN   (287 Ratings)     Doctor on call
# 212    4.188                  NaN    (65 Ratings)          Reception
#
#                                                Address  \
# 0         Near Khurdahi Bazar, Sultanpur Road, Lucknow
# 1                               Faizabad Road, Lucknow
# 2    Saraswati puram near convention center Raebare...
# 3                                    Alambagh, Lucknow
# 4                       Krishna Nagar Lucknow, Lucknow
# ..                                                 ...
# 208                                    226023, Lucknow
# 209  1/1000 Vinay Khand (patrakarpuram) Near Malik ...
# 210  Star Tower Aliganj Opp Kendriya Bhawan Lucknow...
# 211                               Gomti Nagar, Lucknow
# 212      Near Tender Hearts School, Mahanagar, Lucknow
#
#                                      Informations
# 0      6 people booked this hotel in last 6 hours
# 1     16 people booked this hotel in last 6 hours
# 2              All staff vaccinated with 1st dose
# 3              All staff vaccinated with 1st dose
# 4                                             NaN
# ..                                            ...
# 208  900+ people booked this OYO in last 6 months
# 209            All staff vaccinated with 1st dose
# 210                                           NaN
# 211    6 people booked this hotel in last 6 hours
# 212                                           NaN
#
# [213 rows x 9 columns]

# %%
df1['Booking_Discounts(%)'] = df1['Booking_Discounts(%)'].str.replace('\D+','')
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_6004\2563500470.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df1['Booking_Discounts(%)'] = df1['Booking_Discounts(%)'].str.replace('\D+','')

# %%
df1['Booking_Discounts(%)']=df1['Booking_Discounts(%)'].astype(float)

# %%
df1['Booking_Discounts(%)'].fillna(df1['Booking_Discounts(%)'].mean(),inplace=True)

# %%
df1
# Out:
#                                         Hotels       Prices  Total_Price  \
# 0               OYO Townhouse 973 Jalsa Resort   832.000000  3493.000000
# 1                 OYO Townhouse 1094 North Inn   603.000000  2154.000000
# 2     OYO Flagship 77242 Radhey Krishna Bhawan   499.000000  2664.000000
# 3    Townhouse OAK Geetraj By Insight Services  1448.000000  5169.000000
# 4           OYO HOME 702340 Hotel Palassio Inn   617.000000  2204.000000
# ..                                         ...          ...          ...
# 208               OYO 85551 Hotel Rudra Palace   854.826531  2866.515306
# 209                 Flagship 79156 Hotel Tokyo   854.826531  2866.515306
# 210       Flagship 92692 Star Stay Guest House   854.826531  2866.515306
# 211      Capital O 84117 The Diamond Night Inn   854.826531  2866.515306
# 212               OYO 45546 Woodstock Homestay   854.826531  2866.515306
#
#      Ratings  Booking_Discounts(%)         Reviews          Facilities  \
# 0      4.300             76.000000   (818 Ratings)   Parking facility
# 1      4.188             72.000000   (851 Ratings)   Parking facility
# 2      4.000             81.000000   (914 Ratings)         Hair Dryer
# 3      4.188             71.000000  (2353 Ratings)         Hair Dryer
# 4      4.188             72.000000             NaN           Elevator
# ..       ...                   ...             ...                 ...
# 208    4.188             69.382653   (542 Ratings)   Parking facility
# 209    4.300             69.382653   (452 Ratings)     Doctor on call
# 210    4.188             69.382653   (165 Ratings)   Parking facility
# 211    4.188             69.382653   (287 Ratings)     Doctor on call
# 212    4.188             69.382653    (65 Ratings)          Reception
#
#                                                Address  \
# 0         Near Khurdahi Bazar, Sultanpur Road, Lucknow
# 1                               Faizabad Road, Lucknow
# 2    Saraswati puram near convention center Raebare...
# 3                                    Alambagh, Lucknow
# 4                       Krishna Nagar Lucknow, Lucknow
# ..                                                 ...
# 208                                    226023, Lucknow
# 209  1/1000 Vinay Khand (patrakarpuram) Near Malik ...
# 210  Star Tower Aliganj Opp Kendriya Bhawan Lucknow...
# 211                               Gomti Nagar, Lucknow
# 212      Near Tender Hearts School, Mahanagar, Lucknow
#
#                                      Informations
# 0      6 people booked this hotel in last 6 hours
# 1     16 people booked this hotel in last 6 hours
# 2              All staff vaccinated with 1st dose
# 3              All staff vaccinated with 1st dose
# 4                                             NaN
# ..                                            ...
# 208  900+ people booked this OYO in last 6 months
# 209            All staff vaccinated with 1st dose
# 210                                           NaN
# 211    6 people booked this hotel in last 6 hours
# 212                                           NaN
#
# [213 rows x 9 columns]

# %%
df1['Reviews'] = df1['Reviews'].str.replace('\D+','')
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_6004\629340285.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df1['Reviews'] = df1['Reviews'].str.replace('\D+','')

# %%
df1['Reviews']=df1['Reviews'].astype(float)

# %%
df1['Reviews'].fillna(df1['Reviews'].mean(),inplace=True)

# %%
df1
# Out:
#                                         Hotels       Prices  Total_Price  \
# 0               OYO Townhouse 973 Jalsa Resort   832.000000  3493.000000
# 1                 OYO Townhouse 1094 North Inn   603.000000  2154.000000
# 2     OYO Flagship 77242 Radhey Krishna Bhawan   499.000000  2664.000000
# 3    Townhouse OAK Geetraj By Insight Services  1448.000000  5169.000000
# 4           OYO HOME 702340 Hotel Palassio Inn   617.000000  2204.000000
# ..                                         ...          ...          ...
# 208               OYO 85551 Hotel Rudra Palace   854.826531  2866.515306
# 209                 Flagship 79156 Hotel Tokyo   854.826531  2866.515306
# 210       Flagship 92692 Star Stay Guest House   854.826531  2866.515306
# 211      Capital O 84117 The Diamond Night Inn   854.826531  2866.515306
# 212               OYO 45546 Woodstock Homestay   854.826531  2866.515306
#
#      Ratings  Booking_Discounts(%)      Reviews          Facilities  \
# 0      4.300             76.000000   818.000000   Parking facility
# 1      4.188             72.000000   851.000000   Parking facility
# 2      4.000             81.000000   914.000000         Hair Dryer
# 3      4.188             71.000000  2353.000000         Hair Dryer
# 4      4.188             72.000000   656.789773           Elevator
# ..       ...                   ...          ...                 ...
# 208    4.188             69.382653   542.000000   Parking facility
# 209    4.300             69.382653   452.000000     Doctor on call
# 210    4.188             69.382653   165.000000   Parking facility
# 211    4.188             69.382653   287.000000     Doctor on call
# 212    4.188             69.382653    65.000000          Reception
#
#                                                Address  \
# 0         Near Khurdahi Bazar, Sultanpur Road, Lucknow
# 1                               Faizabad Road, Lucknow
# 2    Saraswati puram near convention center Raebare...
# 3                                    Alambagh, Lucknow
# 4                       Krishna Nagar Lucknow, Lucknow
# ..                                                 ...
# 208                                    226023, Lucknow
# 209  1/1000 Vinay Khand (patrakarpuram) Near Malik ...
# 210  Star Tower Aliganj Opp Kendriya Bhawan Lucknow...
# 211                               Gomti Nagar, Lucknow
# 212      Near Tender Hearts School, Mahanagar, Lucknow
#
#                                      Informations
# 0      6 people booked this hotel in last 6 hours
# 1     16 people booked this hotel in last 6 hours
# 2              All staff vaccinated with 1st dose
# 3              All staff vaccinated with 1st dose
# 4                                             NaN
# ..                                            ...
# 208  900+ people booked this OYO in last 6 months
# 209            All staff vaccinated with 1st dose
# 210                                           NaN
# 211    6 people booked this hotel in last 6 hours
# 212                                           NaN
#
# [213 rows x 9 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213 entries, 0 to 212
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Hotels                213 non-null    object
#  1   Prices                213 non-null    float64
#  2   Total_Price           213 non-null    float64
#  3   Ratings               213 non-null    float64
#  4   Booking_Discounts(%)  213 non-null    float64
#  5   Reviews               213 non-null    float64
#  6   Facilities            213 non-null    object
#  7   Address               213 non-null    object
#  8   Informations          107 non-null    object
# dtypes: float64(5), object(4)
# memory usage: 15.1+ KB

# %%
df1["City_Name"] = df1['Address'].apply(lambda x: x.split(',')[-1])
df1
# Out:
#                                         Hotels       Prices  Total_Price  \
# 0               OYO Townhouse 973 Jalsa Resort   832.000000  3493.000000
# 1                 OYO Townhouse 1094 North Inn   603.000000  2154.000000
# 2     OYO Flagship 77242 Radhey Krishna Bhawan   499.000000  2664.000000
# 3    Townhouse OAK Geetraj By Insight Services  1448.000000  5169.000000
# 4           OYO HOME 702340 Hotel Palassio Inn   617.000000  2204.000000
# ..                                         ...          ...          ...
# 208               OYO 85551 Hotel Rudra Palace   854.826531  2866.515306
# 209                 Flagship 79156 Hotel Tokyo   854.826531  2866.515306
# 210       Flagship 92692 Star Stay Guest House   854.826531  2866.515306
# 211      Capital O 84117 The Diamond Night Inn   854.826531  2866.515306
# 212               OYO 45546 Woodstock Homestay   854.826531  2866.515306
#
#      Ratings  Booking_Discounts(%)      Reviews          Facilities  \
# 0      4.300             76.000000   818.000000   Parking facility
# 1      4.188             72.000000   851.000000   Parking facility
# 2      4.000             81.000000   914.000000         Hair Dryer
# 3      4.188             71.000000  2353.000000         Hair Dryer
# 4      4.188             72.000000   656.789773           Elevator
# ..       ...                   ...          ...                 ...
# 208    4.188             69.382653   542.000000   Parking facility
# 209    4.300             69.382653   452.000000     Doctor on call
# 210    4.188             69.382653   165.000000   Parking facility
# 211    4.188             69.382653   287.000000     Doctor on call
# 212    4.188             69.382653    65.000000          Reception
#
#                                                Address  \
# 0         Near Khurdahi Bazar, Sultanpur Road, Lucknow
# 1                               Faizabad Road, Lucknow
# 2    Saraswati puram near convention center Raebare...
# 3                                    Alambagh, Lucknow
# 4                       Krishna Nagar Lucknow, Lucknow
# ..                                                 ...
# 208                                    226023, Lucknow
# 209  1/1000 Vinay Khand (patrakarpuram) Near Malik ...
# 210  Star Tower Aliganj Opp Kendriya Bhawan Lucknow...
# 211                               Gomti Nagar, Lucknow
# 212      Near Tender Hearts School, Mahanagar, Lucknow
#
#                                      Informations  \
# 0      6 people booked this hotel in last 6 hours
# 1     16 people booked this hotel in last 6 hours
# 2              All staff vaccinated with 1st dose
# 3              All staff vaccinated with 1st dose
# 4                                             NaN
# ..                                            ...
# 208  900+ people booked this OYO in last 6 months
# 209            All staff vaccinated with 1st dose
# 210                                           NaN
# 211    6 people booked this hotel in last 6 hours
# 212                                           NaN
#
#                                              City_Name
# 0                                              Lucknow
# 1                                              Lucknow
# 2                                              Lucknow
# 3                                              Lucknow
# 4                                              Lucknow
# ..                                                 ...
# 208                                            Lucknow
# 209  1/1000 Vinay Khand (patrakarpuram) Near Malik ...
# 210                                            Lucknow
# 211                                            Lucknow
# 212                                            Lucknow
#
# [213 rows x 10 columns]

# %%
df1['Address']
# Out:
# 0           Near Khurdahi Bazar, Sultanpur Road, Lucknow
# 1                                 Faizabad Road, Lucknow
# 2      Saraswati puram near convention center Raebare...
# 3                                      Alambagh, Lucknow
# 4                         Krishna Nagar Lucknow, Lucknow
#                              ...
# 208                                      226023, Lucknow
# 209    1/1000 Vinay Khand (patrakarpuram) Near Malik ...
# 210    Star Tower Aliganj Opp Kendriya Bhawan Lucknow...
# 211                                 Gomti Nagar, Lucknow
# 212        Near Tender Hearts School, Mahanagar, Lucknow
# Name: Address, Length: 213, dtype: object

# %%
city = []
for i in df1['Address']:
    city.append(i.split())
city
# Out:
# [['Near', 'Khurdahi', 'Bazar,', 'Sultanpur', 'Road,', 'Lucknow'],
#  ['Faizabad', 'Road,', 'Lucknow'],
#  ['Saraswati',
#   'puram',
#   'near',
#   'convention',
#   'center',
#   'Raebareli',
#   'road',
#   'SGPI,',
#   'Lucknow'],
#  ['Alambagh,', 'Lucknow'],
#  ['Krishna', 'Nagar', 'Lucknow,', 'Lucknow'],
#  ['Near', 'Sahara', 'Hospital,', 'Viraj', 'Khand,', 'Lucknow'],
#  ['opposite', 'FI', 'hospital', 'near', 'burlington', 'crossing', 'Lucknow'],
#  ['64',
#   'A',
#   'Him',
#   'City',
#   'Khachapur',
#   'Matiyari',
#   'Chinnhat',
#   'Lucknow,',
#   'Lucknow'],
#  ['Near', 'Ekana', 'Stadium,', 'Gomtinagar', 'Ext.,', 'Lucknow'],
#  ['Near',
#   'Transport',
#   'Nagar',
#   'Metro',
#   'Station,',
#   'Labour',
#   'Chowk,',
#   'Lucknow'],
#  ['Gomti',
#   'Nagar',
#   'Extension',
#   'Near',
#   'Ekana',
#   'Cricket',
#   'Stadium,',
#   'Lucknow'],
#  ['Nirala',
#   'Nagar',
#   'Infront',
#   'The',
#   'Regnant',
#   'Hotel',
#   'Near',
#   'Ram',
#   'Krishna',
#   'Matt,',
#   'Lucknow'],
#  ['Near', 'PGI', 'Bijnaur,', 'Lucknow.'],
#  ['Vikalp', 'khand,', 'Lucknow'],
#  ['Ganeshpur', 'Rahmanpur,', 'Lucknow'],
#  ['Near',
#   'BBD',
#   'College',
#   'Faizabad',
#   'Road',
#   'Lucknow',
#   'Uttar',
#   'Pradesh',
#   ',',
#   'Lucknow'],
#  ['Kathauta',
#   'Chauraha,',
#   '1/187',
#   'Vinamra',
#   'Khand,',
#   'Gomti',
#   'Nagar',
#   ',',
#   'Lucknow'],
#  ['Ashraf',
#   'Vihar',
#   'Colony',
#   'Lucknow',
#   'Uttar',
#   'Pradesh',
#   'India',
#   ',',
#   'Lucknow'],
#  ['Near', 'Scooter', 'India', 'Chauraha,', 'Lucknow'],
#  ['Near', 'by', 'Polytechnic', 'Indira', 'Nagar', 'Sector', '8'],
#  ['Plot',
#   'No',
#   '26',
#   'Saidpur',
#   'Jageer',
#   'Jankipuram',
#   'Extension',
#   'Near',
#   'Krishna',
#   'Traders,',
#   'Lucknow'],
#  ['Near', 'Chinhat', 'Tiraha,', 'Lucknow'],
#  ['Saraswati',
#   'puram',
#   'near',
#   'convention',
#   'center',
#   'Raebareli',
#   'road',
#   'SGPI,',
#   'Lucknow'],
#  ['Near', 'Ambedkar', 'Chauraha,', 'Indra', 'Nagar,', 'Lucknow'],
#  ['Sector', '12', 'Vikas', 'Nagar,', 'Lucknow'],
#  ['Shankar', 'Puri,', 'Lucknow'],
#  ['Ganeshpur', 'Rahmanpur,', 'Lucknow'],
#  ['The',
#   'Best',
#   'Hotel,',
#   'Pandariba,',
#   'above',
#   'post',
#   'office',
#   'Charbagh,',
#   'Lucknow'],
#  ['Near', 'Chotelal', 'Nursery,', 'Vishesh', 'khand,', 'Lucknow'],
#  ['Chinhat,', 'Gomti', 'Nagar,', 'Lucknow'],
#  ['Near', 'Sahara,', 'Gomti', 'Nagar,', 'Lucknow'],
#  ['Near', 'S.m', 'Hospital', 'Muttakipur,', 'Lucknow'],
#  ['Gomti',
#   'Nagar',
#   'Extension',
#   'Near',
#   'Ekana',
#   'Cricket',
#   'Stadium,',
#   'Lucknow'],
#  ['Shaisheweer', 'Mandir,', 'Lucknow'],
#  ['Kh', 'No', '186', 'Semra', 'Chinahat,', 'Lucknow'],
#  ['Charbagh,', 'Lucknow'],
#  ['Sadar,', 'Lucknow'],
#  ['Raniganj',
#   'Chauraha,',
#   'Near',
#   'Charbagh',
#   'Railway',
#   'Station',
#   '&',
#   'Bus',
#   'Stand,',
#   'Lucknow.'],
#  ['Pancham', 'Khera', 'Haibat', 'Mau', 'Ibrahim', 'Pur', 'Ward,', 'Lucknow'],
#  ['Plot',
#   'no-4,',
#   'B.R',
#   'dubey',
#   'enclave',
#   ',',
#   'dhawa',
#   'mod',
#   ',deva',
#   'road',
#   ',lucknow'],
#  ['Chinhat,', 'Lucknow'],
#  ['House', 'no', '4/163', 'Vivek', 'khand', '4', 'Gomti', 'nagar'],
#  ['Gomti', 'Nagar,', 'Lucknow'],
#  ['Chota', 'Gurudwara,', 'Lucknow'],
#  ['Chinhat,', 'Lucknow'],
#  ['Near', 'PGI', 'Bijnaur,', 'Lucknow.'],
#  ['Lucknow.,', 'Lucknow'],
#  ['Vinay', 'Khand', '1,', 'Lucknow'],
#  ['Gomti', 'Nagar,', 'Lucknow'],
#  ['Mo.raipur', 'iim', 'road', 'neart', 'r.k.grand', 'hotel,', 'Lucknow'],
#  ['Near', 'Prabhat', 'Chauraha,', 'Jankipuram,', 'Lucknow'],
#  ['Near', 'Khurdahi', 'Bazar,', 'Sultanpur', 'Road,', 'Lucknow'],
#  ['Rvw,', 'Lucknow'],
#  ['Near',
#   'Husainganj',
#   'Chauraha,',
#   'Guru',
#   'Gobind',
#   'Singh',
#   'Marg,',
#   'Lucknow'],
#  ['Amity',
#   'University',
#   'gate',
#   'no3',
#   'STP',
#   'Road',
#   'nearly',
#   'arvind',
#   'academy',
#   'malhaur',
#   'Lucknow'],
#  ['Mohan', 'road,', 'Near', 'Shakuntala', 'Devi-University,', 'Lucknow'],
#  ['Vrindavan,', 'Lucknow'],
#  ['Sarojini', 'Nagar,', 'Lucknow,', 'Uttar', 'Pradesh'],
#  ['Near', 'Gauri', 'Bazar,', 'Sarojini', 'Nagar,', 'Lucknow'],
#  ['Near', 'Sahara', 'India', 'Tower,', 'Aliganj,', 'Lucknow'],
#  ['Pin', 'Code,', 'Lucknow'],
#  ['Sector', '7,', 'Vrindavan', 'Colony,', 'Lucknow'],
#  ['64',
#   'A',
#   'Him',
#   'City',
#   'Khachapur',
#   'Matiyari',
#   'Chinnhat',
#   'Lucknow,',
#   'Lucknow'],
#  ['Sadar,', 'Lucknow'],
#  ['Vibhav', 'Khand,', 'Lucknow'],
#  ['NEAR', 'HIGH', 'COURT,', 'INDIRA', 'NAGAR,', 'LUCKNOW'],
#  ['Indira', 'Nagar,', 'Lucknow'],
#  ['Chatameel',
#   'Petrol',
#   'Pump',
#   'Near',
#   'Changa',
#   'Market',
#   'Sarriya',
#   'Rod,',
#   'Lucknow'],
#  ['Choti', 'Gurudwara,', 'Lucknow'],
#  ['Near',
#   'BBD',
#   'University,',
#   'behind',
#   'four',
#   'season',
#   'lawn,',
#   'Lucknow'],
#  ['Krishna', 'Nagar', 'Lucknow,', 'Lucknow'],
#  ['Sarojini', 'Nagar', 'near', 'Chauhan', 'Palace,', 'Lucknow'],
#  ['Near', 'Uthrethya', 'Junction,', 'Uteratia,', 'Lucknow'],
#  ['Sadar,', 'Lucknow'],
#  ['Ashiyana,', 'Lucknow'],
#  ['Charbaghnull,', 'Lucknow'],
#  ['Near', 'Integral', 'University,', 'Village', 'Dasauli,', 'Lucknow'],
#  ['Mohanlalganj,', 'Lucknow'],
#  ['Near',
#   'Transport',
#   'Nagar',
#   'Metro',
#   'Station,',
#   'Labour',
#   'Chowk,',
#   'Lucknow'],
#  ['Jankipuram', 'Lucknow'],
#  ['Anora', 'Kala,', 'Lucknow'],
#  ['Sitapur',
#   'Road',
#   'Chathameel',
#   'New',
#   'Tiwaripuram',
#   'Tiwaripur',
#   'Road',
#   'Lucknow,',
#   'Lucknow'],
#  ['2/298', 'Vivek', 'Khand', 'Gomti', 'Nagar', 'Lucknow,', 'Lucknow'],
#  ['near', 'Tirupati', 'Balaji', 'Temple', 'kanpur', 'road.,', 'Lucknow'],
#  ['Near', 'Rail', 'vihar', 'colony', ',', 'Malhour,', 'Lucknow'],
#  ['Vineet',
#   'Khand',
#   'Gomti',
#   'Nagar',
#   'Lucknow',
#   '(',
#   'Next',
#   'To',
#   'Central',
#   'Bank',
#   'Of',
#   'India',
#   'Gomti',
#   'Nagar),',
#   'Lucknow'],
#  ['Near', 'Hussainganj', 'Kotwali,', 'Canal', 'Colony,', 'Lucknow'],
#  ['Village-digui', 'near', 'RR', 'institute', 'Bkt', 'lucknow,', 'Lucknow'],
#  ['Near', 'Burlington', 'Chauraha,', 'Aminabad,', 'Lucknow'],
#  ['India,', 'Lucknow'],
#  ['Near', 'SGPGI,', 'Ekta', 'Nagar,', 'Lucknow'],
#  ['Lucknow,', 'Lucknow'],
#  ['Lucknow.', '227150,', 'Lucknow'],
#  ['Gomti', 'Nagar', 'Extension,', 'Lucknow'],
#  ['Gomti', 'Nagar,', 'Lucknow'],
#  ['Near', 'Sapna', 'Sweets,', 'Lucknow'],
#  ['Hussainganj,', 'Lucknow'],
#  ['Gomti', 'Nagar,', 'Lucknow'],
#  ['Ashiyana', 'Road,', 'Lucknow'],
#  ['Viraj', 'Khand,', 'Lucknow'],
#  ['gb',
#   'marg',
#   'bans',
#   'mandi',
#   'chauraha',
#   'charbagh',
#   'lucknow,',
#   'Lucknow'],
#  ['Haibat', 'Mau', 'Mawaiya,', 'Lucknow'],
#  ['Matiyari', 'Gaon', 'Road,', 'Lucknow'],
#  ['Gomtinagar,', 'Lucknow'],
#  ['Maa',
#   'Chandrika',
#   'Devi',
#   'Road,',
#   'Nearby',
#   'GCRG',
#   'College',
#   ',Bakshi',
#   'Ka',
#   'Talab,Lucknow'],
#  ['Kathauta',
#   'Chauraha,',
#   '1/187',
#   'Vinamra',
#   'Khand,',
#   'Gomti',
#   'Nagar',
#   ',',
#   'Lucknow'],
#  ['Near', 'Malhaur', 'Railway', 'station,', 'Gomti', 'Nagar,', 'Lucknow'],
#  ['7wj,', 'Lucknow'],
#  ['Near', 'Shalimar', 'Tower,', 'Gomti', 'Nagar,', 'Lucknow'],
#  ['3/176', 'Vikrant', 'Khand', 'Gomti', 'Nagar,', 'Lucknow'],
#  ['Vistar', 'Lucknow,', 'Lucknow'],
#  ['Kanpur', 'Road,', 'Lucknow'],
#  ['Faizabad', 'Road,', 'Lucknow'],
#  ['Near',
#   'BBD',
#   'College',
#   'Faizabad',
#   'Road',
#   'Lucknow',
#   'Uttar',
#   'Pradesh',
#   ',',
#   'Lucknow'],
#  ['Jankipuram,', 'Lucknow'],
#  ['India,', 'Lucknow'],
#  ['Ashraf',
#   'Vihar',
#   'Colony',
#   'Lucknow',
#   'Uttar',
#   'Pradesh',
#   'India',
#   ',',
#   'Lucknow'],
#  ['Viraj', 'khand', 'road,', 'vigyan', 'khand', ',', 'Lucknow'],
#  ['Gomtinagar,', 'Lucknow'],
#  ['Near', 'Alambagh', 'Metro', 'Station,', 'Alambagh,', 'Lucknow'],
#  ['Sgpgi,', 'Lucknow'],
#  ['opposite', 'FI', 'hospital', 'near', 'burlington', 'crossing', 'Lucknow'],
#  ['Ashiyana,', 'Lucknow'],
#  ['Rkbk',
#   'cng',
#   'petrol',
#   'pump',
#   'bkt',
#   'lko',
#   'bakshi',
#   'ka',
#   'talab,',
#   'Lucknow'],
#  ['IIM',
#   'road',
#   'opp.',
#   'Urdu',
#   'Farsi',
#   'university',
#   'near',
#   'HP',
#   'petrol',
#   'pump',
#   'Lucknow',
#   '226013'],
#  ['226016,', 'Lucknow'],
#  ['Near', 'Madhav', 'Market,', 'Charbagh,', 'Lucknow'],
#  ['NEAR', 'GOLU', 'CHAURAHA,', 'Lucknow'],
#  ['Near', 'Medanta', 'Hospital,', 'Shaheed', 'Path,', 'Lucknow'],
#  ['Vibhuti', 'Khand,', 'Gomti', 'Nagar,', 'Lucknow'],
#  ['Near', 'RTO', 'Office,', 'Transport', 'Nagar,', 'Lucknow'],
#  ['Chattamil',
#   'Raitha',
#   'Road',
#   'Near',
#   'Hanuman',
#   'Mandir',
#   '(',
#   'Behind',
#   'Pragti',
#   'Mart),',
#   'Lucknow'],
#  ['Near', 'Singapore', 'Mall,', 'Gomti', 'Nagar,', 'Lucknow'],
#  ['Uttar',
#   'Pradesh',
#   '226010.near',
#   'Ssb',
#   'Apartment',
#   'On',
#   'Shaheedpath,',
#   'Lucknow'],
#  ['Udaiganj',
#   'Near',
#   'Burlington',
#   'Chouraha',
#   'Cantonment',
#   'Road',
#   'Lucknow',
#   'Pin,',
#   'Lucknow'],
#  ['Near', 'Bala', 'PCO,Tehsil', 'Rd,', 'Lucknow'],
#  ['Near', 'Tempo', 'Stand,', 'Lucknow'],
#  ['Arya', 'Nagar,', 'Lucknow'],
#  ['5/368',
#   'Viraj',
#   'Khand,',
#   'Gomti',
#   'Nagar,',
#   'Near',
#   'AMITY',
#   'School',
#   'Lucknow'],
#  ['India,', 'Lucknow'],
#  ['6C/894,', 'Sector', '6,', 'Gomti', 'Nagar,', 'Lucknow,', 'Lucknow'],
#  ['Chinhat,', 'Gomti', 'Nagar,', 'Lucknow'],
#  ['Devpur,', 'Lucknow'],
#  ['Near', 'Highcourt,', 'Kamata,', 'Lucknow'],
#  ['Near', 'Channilal', 'Chouraha,', 'Lucknow'],
#  ['Near', 'Powerhouse', 'Chouraha,', 'Aashiana,', 'Lucknow'],
#  ['B1/301,',
#   'SECTOR-G,',
#   'SAHARA',
#   'STATE',
#   'ROAD,',
#   'NEAR',
#   'ICON',
#   'HOSPITAL,',
#   'JANKIPURAM,',
#   'LUCKNOW.'],
#  ['Alambagh,', 'Lucknow'],
#  ['Near', 'Micro', 'mall,Gomti', 'Nagar,', 'Lucknow'],
#  ['Gomti', 'Nagar,', 'Lucknow'],
#  ['B1/274', 'Sector', 'G,', 'Lucknow'],
#  ['Near', 'CMS', 'School,', 'Gomti', 'Nagar,', 'Lucknow'],
#  ['Gomti', 'Nagar,', 'Lucknow'],
#  ['Near', 'bhoothnath,', 'Indira', 'Nagar,', 'Lucknow'],
#  ['Near', 'Alambag', 'Metro', 'Station,', 'Kanpur', 'Road,', 'Lucknow'],
#  ['Near', 'by', 'Polytechnic', 'Indira', 'Nagar', 'Sector', '8'],
#  ['Gomti', 'Nagar,', 'Lucknow'],
#  ['Arjun', 'Ganj,', 'Lucknow'],
#  ['Ashiyana,', 'Lucknow'],
#  ['Sadar,', 'Lucknow'],
#  ['Near', 'Amar', 'Shaheed', 'Path,', 'Transport', 'Nagar,', 'Lucknow'],
#  ['Sadar,', 'Lucknow'],
#  ['Sadar,', 'Lucknow'],
#  ['Hari', 'Om', 'Nagar,', 'Lucknow'],
#  ['Kesarbagh,', 'Lucknow'],
#  ['Lucknow', 'Junction,', 'Lucknow'],
#  ['Near', 'Patrakarpuram', 'Chaueraha,', 'Gomti', 'Nagar,', 'Lucknow'],
#  ['B',
#   '-1/122',
#   'Vineet',
#   'Khand',
#   'Gomti',
#   'Nagar',
#   'Near',
#   'Jaipuria',
#   'School,',
#   'Lucknow'],
#  ['Near', 'Sahara', 'Hospital,', 'Viraj', 'Khand,', 'Lucknow'],
#  ['Matiyari,', 'Lucknow'],
#  ['Near', 'Vikas', 'Nagar', 'Post', 'Office,', 'Sector', '2,', 'Lucknow'],
#  ['Near', 'Airport,', 'LDA', 'Colony,', 'Lucknow'],
#  ['viraj', 'Khand,', 'Lucknow'],
#  ['Near', 'Hussainganj', 'Chauraha,', 'Udaiganj,', 'Lucknow'],
#  ['Opp', 'Shringaar', 'Villa,', 'Lucknow'],
#  ['Gomti', 'Nagar', 'Extension,', 'Lucknow'],
#  ['Near',
#   'Utrathiya',
#   'Chauraha',
#   'Br',
#   'Ambedkar',
#   'University',
#   'Road',
#   'Lucknow,',
#   'Lucknow'],
#  ['Lucknow,', 'Lucknow'],
#  ['Near', 'Medanta', 'Hospital'],
#  ['Lucknow,', 'Lucknow'],
#  ['Near', 'Dayal', 'Chowk,', 'Gomti', 'Nagar,', 'Lucknow'],
#  ['Hazratganj', ',', 'Lucknow'],
#  ['Near', 'Ekana', 'Stadium,', 'Gomtinagar', 'Ext.,', 'Lucknow'],
#  ['Near', 'Vinamra', 'Khand,', 'Gomti', 'Nagar,', 'Lucknow'],
#  ['Udaiganj,', 'Lucknow'],
#  ['19/755', 'Sector', '19', 'Indira', 'Nagar', 'Lucknow,', 'Lucknow'],
#  ['2/653', 'Sector', 'H', 'Colony', 'Jankipuram', 'lucknow', ',', 'Lucknow'],
#  ['vibhav', 'khand', 'Near', 'Mantri', 'awas', 'Gomti', 'Nager', 'Lucknow'],
#  ['Lalkuan', 'Road', 'Lucknow,', 'Lucknow'],
#  ['Lucknow', 'Sadar,', 'Lucknow'],
#  ['Sharda', 'Nagar,', 'Lucknow'],
#  ['Near', 'C.B.C.I.D.', 'Office,', 'Gomti', 'Nagar,', 'Lucknow'],
#  ['Near', 'Munshipuliya', 'Chouraha,', 'Lucknow'],
#  ['House',
#   'No',
#   '7',
#   'Gate',
#   'No',
#   '5',
#   'Goushala',
#   'Road',
#   'Balaganj,',
#   'Lucknow'],
#  ['Near',
#   'Lekhraj',
#   'Metro',
#   'station,',
#   'Sanjay',
#   'Gandhi',
#   'Puram,',
#   'Lucknow'],
#  ['India,', 'Lucknow'],
#  ['Gomtinagar,', 'Lucknow'],
#  ['Lucknow,', 'Lucknow'],
#  ['Gomti', 'Nagar,', 'Lucknow'],
#  ['Indira', 'Nagar,', 'Lucknow'],
#  ['Near', 'Viraj', 'Khand,', 'Gomti', 'Nagar,', 'Lucknow'],
#  [':IIM', 'Road', 'Lucknow', 'Uttar', 'Pradesh', ',', 'Lucknow'],
#  ['Lucknow,', 'Lucknow'],
#  ['215/409', 'naka', 'hindola,', 'Lucknow'],
#  ['Near', 'Charbagh', 'Metro,', 'Rajendra', 'Nagar,', 'Lucknow'],
#  ['Lucknow', 'Lucknow', 'Uttarpradesh', 'India,', 'Lucknow'],
#  ['Pandariba', 'Opposite', 'Purana', 'Post', 'Office', 'Charbagh,', 'Lucknow'],
#  ['hardoi', 'bypass', 'road', 'alamnagar', 'lucknow', ',', 'Lucknow'],
#  ['226023,', 'Lucknow'],
#  ['1/1000',
#   'Vinay',
#   'Khand',
#   '(patrakarpuram)',
#   'Near',
#   'Malik',
#   'Timber',
#   'Gomtinagar'],
#  ['Star',
#   'Tower',
#   'Aliganj',
#   'Opp',
#   'Kendriya',
#   'Bhawan',
#   'Lucknow,',
#   'Lucknow'],
#  ['Gomti', 'Nagar,', 'Lucknow'],
#  ['Near', 'Tender', 'Hearts', 'School,', 'Mahanagar,', 'Lucknow']]

# %%
City = []
for i in city:
    if i == "Lucknow":
        City.append(i)
    else:
        City.append("Lucknow")
City
# Out:
# ['Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow']

# %%
df1['City_Name']=City
df1
# Out:
#                                         Hotels       Prices  Total_Price  \
# 0               OYO Townhouse 973 Jalsa Resort   832.000000  3493.000000
# 1                 OYO Townhouse 1094 North Inn   603.000000  2154.000000
# 2     OYO Flagship 77242 Radhey Krishna Bhawan   499.000000  2664.000000
# 3    Townhouse OAK Geetraj By Insight Services  1448.000000  5169.000000
# 4           OYO HOME 702340 Hotel Palassio Inn   617.000000  2204.000000
# ..                                         ...          ...          ...
# 208               OYO 85551 Hotel Rudra Palace   854.826531  2866.515306
# 209                 Flagship 79156 Hotel Tokyo   854.826531  2866.515306
# 210       Flagship 92692 Star Stay Guest House   854.826531  2866.515306
# 211      Capital O 84117 The Diamond Night Inn   854.826531  2866.515306
# 212               OYO 45546 Woodstock Homestay   854.826531  2866.515306
#
#      Ratings  Booking_Discounts(%)      Reviews          Facilities  \
# 0      4.300             76.000000   818.000000   Parking facility
# 1      4.188             72.000000   851.000000   Parking facility
# 2      4.000             81.000000   914.000000         Hair Dryer
# 3      4.188             71.000000  2353.000000         Hair Dryer
# 4      4.188             72.000000   656.789773           Elevator
# ..       ...                   ...          ...                 ...
# 208    4.188             69.382653   542.000000   Parking facility
# 209    4.300             69.382653   452.000000     Doctor on call
# 210    4.188             69.382653   165.000000   Parking facility
# 211    4.188             69.382653   287.000000     Doctor on call
# 212    4.188             69.382653    65.000000          Reception
#
#                                                Address  \
# 0         Near Khurdahi Bazar, Sultanpur Road, Lucknow
# 1                               Faizabad Road, Lucknow
# 2    Saraswati puram near convention center Raebare...
# 3                                    Alambagh, Lucknow
# 4                       Krishna Nagar Lucknow, Lucknow
# ..                                                 ...
# 208                                    226023, Lucknow
# 209  1/1000 Vinay Khand (patrakarpuram) Near Malik ...
# 210  Star Tower Aliganj Opp Kendriya Bhawan Lucknow...
# 211                               Gomti Nagar, Lucknow
# 212      Near Tender Hearts School, Mahanagar, Lucknow
#
#                                      Informations City_Name
# 0      6 people booked this hotel in last 6 hours   Lucknow
# 1     16 people booked this hotel in last 6 hours   Lucknow
# 2              All staff vaccinated with 1st dose   Lucknow
# 3              All staff vaccinated with 1st dose   Lucknow
# 4                                             NaN   Lucknow
# ..                                            ...       ...
# 208  900+ people booked this OYO in last 6 months   Lucknow
# 209            All staff vaccinated with 1st dose   Lucknow
# 210                                           NaN   Lucknow
# 211    6 people booked this hotel in last 6 hours   Lucknow
# 212                                           NaN   Lucknow
#
# [213 rows x 10 columns]

# %%
df1.to_csv('Oyo Hotels Lucknow.csv',index=False)

# %%
df1 = pd.read_csv('Oyo Hotels Lucknow.csv')
df1
# Out:
#                                         Hotels       Prices  Total_Price  \
# 0               OYO Townhouse 973 Jalsa Resort   832.000000  3493.000000
# 1                 OYO Townhouse 1094 North Inn   603.000000  2154.000000
# 2     OYO Flagship 77242 Radhey Krishna Bhawan   499.000000  2664.000000
# 3    Townhouse OAK Geetraj By Insight Services  1448.000000  5169.000000
# 4           OYO HOME 702340 Hotel Palassio Inn   617.000000  2204.000000
# ..                                         ...          ...          ...
# 208               OYO 85551 Hotel Rudra Palace   854.826531  2866.515306
# 209                 Flagship 79156 Hotel Tokyo   854.826531  2866.515306
# 210       Flagship 92692 Star Stay Guest House   854.826531  2866.515306
# 211      Capital O 84117 The Diamond Night Inn   854.826531  2866.515306
# 212               OYO 45546 Woodstock Homestay   854.826531  2866.515306
#
#      Ratings  Booking_Discounts(%)      Reviews          Facilities  \
# 0      4.300             76.000000   818.000000   Parking facility
# 1      4.188             72.000000   851.000000   Parking facility
# 2      4.000             81.000000   914.000000         Hair Dryer
# 3      4.188             71.000000  2353.000000         Hair Dryer
# 4      4.188             72.000000   656.789773           Elevator
# ..       ...                   ...          ...                 ...
# 208    4.188             69.382653   542.000000   Parking facility
# 209    4.300             69.382653   452.000000     Doctor on call
# 210    4.188             69.382653   165.000000   Parking facility
# 211    4.188             69.382653   287.000000     Doctor on call
# 212    4.188             69.382653    65.000000          Reception
#
#                                                Address  \
# 0         Near Khurdahi Bazar, Sultanpur Road, Lucknow
# 1                               Faizabad Road, Lucknow
# 2    Saraswati puram near convention center Raebare...
# 3                                    Alambagh, Lucknow
# 4                       Krishna Nagar Lucknow, Lucknow
# ..                                                 ...
# 208                                    226023, Lucknow
# 209  1/1000 Vinay Khand (patrakarpuram) Near Malik ...
# 210  Star Tower Aliganj Opp Kendriya Bhawan Lucknow...
# 211                               Gomti Nagar, Lucknow
# 212      Near Tender Hearts School, Mahanagar, Lucknow
#
#                                      Informations City_Name
# 0      6 people booked this hotel in last 6 hours   Lucknow
# 1     16 people booked this hotel in last 6 hours   Lucknow
# 2              All staff vaccinated with 1st dose   Lucknow
# 3              All staff vaccinated with 1st dose   Lucknow
# 4                                             NaN   Lucknow
# ..                                            ...       ...
# 208  900+ people booked this OYO in last 6 months   Lucknow
# 209            All staff vaccinated with 1st dose   Lucknow
# 210                                           NaN   Lucknow
# 211    6 people booked this hotel in last 6 hours   Lucknow
# 212                                           NaN   Lucknow
#
# [213 rows x 10 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213 entries, 0 to 212
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Hotels                213 non-null    object
#  1   Prices                213 non-null    float64
#  2   Total_Price           213 non-null    float64
#  3   Ratings               213 non-null    float64
#  4   Booking_Discounts(%)  213 non-null    float64
#  5   Reviews               213 non-null    float64
#  6   Facilities            213 non-null    object
#  7   Address               213 non-null    object
#  8   Informations          107 non-null    object
#  9   City_Name             213 non-null    object
# dtypes: float64(5), object(5)
# memory usage: 16.8+ KB

# %%
df1.shape
# Out:
# (213, 10)

# %%
df1.describe()
# Out:
#             Prices   Total_Price     Ratings  Booking_Discounts(%)  \
# count   213.000000    213.000000  213.000000            213.000000
# mean    854.826531   2866.515306    4.188000             69.382653
# std     418.520553   1398.943161    0.060376              5.176280
# min     382.000000   1399.000000    4.000000             47.000000
# 25%     599.000000   1991.000000    4.188000             65.000000
# 50%     781.000000   2527.000000    4.188000             71.000000
# 75%     949.000000   3017.000000    4.188000             72.000000
# max    4410.000000  15751.000000    4.400000             84.000000
#
#            Reviews
# count   213.000000
# mean    656.789773
# std     722.615732
# min       2.000000
# 25%      90.000000
# 50%     531.000000
# 75%     814.000000
# max    3480.000000

# %%
df1.corr()
# Out:
#                         Prices  Total_Price   Ratings  Booking_Discounts(%)  \
# Prices                1.000000     0.941457  0.026564             -0.181792
# Total_Price           0.941457     1.000000 -0.019299              0.138510
# Ratings               0.026564    -0.019299  1.000000             -0.119441
# Booking_Discounts(%) -0.181792     0.138510 -0.119441              1.000000
# Reviews               0.436847     0.405553  0.061096             -0.046183
#
#                        Reviews
# Prices                0.436847
# Total_Price           0.405553
# Ratings               0.061096
# Booking_Discounts(%) -0.046183
# Reviews               1.000000

# %%
df1.Hotels.value_counts()
# Out:
# OYO Townhouse 973 Jalsa Resort        2
# OYO Townhouse 311 Prithvi Resort      2
# Collection O 701724 Shivanya Hotel    2
# Collection O 67986 Pratik Inn         2
# Townhouse 1150 Hotel Dayal Palace     2
#                                      ..
# OYO Home 77778 Bbb Guest House        1
# SPOT ON 66546 Hotel Snow White        1
# OYO 703171 Fauji Hotel & Lawn         1
# OYO 8074 Hotel G 9                    1
# OYO 45546 Woodstock Homestay          1
# Name: Hotels, Length: 197, dtype: int64

# %%
df1.duplicated().sum()
# Out:
# 15
