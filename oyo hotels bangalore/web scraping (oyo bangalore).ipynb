# %%
import numpy as np
import pandas as pd

# %%
import requests
from bs4 import BeautifulSoup
import time

# %%
url='https://www.oyorooms.com/search?location=Bangalore%2C%20Karnataka%2C%20India&city=Bangalore&searchType=city&coupon=&checkin=13%2F11%2F2022&checkout=14%2F11%2F2022&roomConfig%5B%5D=2&country=india&guests=2&rooms=1&countryName=India&filters%5Bcity_id%5D=4'

# %%
page = requests.get(url, headers={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36'})
#page = requests.get(url)
print(page.status_code)
# Out:
# 200

# %%
pagecontent = page.text
pagecontent
# Out:
# '\n    <!doctype html>\n    <html lang="en" dir=ltr>\n    <head>\n      <meta charSet="utf-8" />\n      <meta httpEquiv="x-ua-compatible" content="ie=edge; chrome=1" />\n      <meta name="google-site-verification" content="lCkLu-7S0Eb5LOgDgmoWxSWzbopNfzKW01ZEe3ldsOc" />\n      <script type="text/javascript">\n      \twindow.renderingSource=\'server\'\n        var host = window.location.hostname;\n        if (!String.prototype.endsWith) {\n\t        String.prototype.endsWith = function(search, this_len) {\n\t\t        if (this_len === undefined || this_len > this.length) {\n\t\t\t        this_len = this.length;\n\t\t        }\n\t      \t  return this.substring(this_len - search.length, this_len) === search;\n\t        };\n        }\n        if (! (host.endsWith("oyorooms.com") || host.endsWith("oyorooms.ms") || host.endsWith("oyohotels.co.jp") || host.endsWith("hotelesoyo.com") || host.endsWith("oyohotels.com") || host.endsWith("belvilla.co.in") || host.endsWith("oyorooms.io")) && host.indexOf(\'localhost\') < 0){\n          window.location.href="https://www.oyorooms.com";\n        }\n        </script>\n      <meta httpEquiv="content-language" content="en-IN" />\n      <meta name="viewport" content="width=device-width, initial-scale=1.0, user-scalable=0, minimum-scale=1.0" />\n      \n      <meta name="full-screen" content="yes" />\n\n      <meta name="theme-color" content="#F5F5F5" />\n      <link rel="manifest" href="/manifest.json" />\n      <link rel="alternate" href="android-app://com.oyo.consumer/https/www.oyorooms.com/" />\n      <meta name="google" content="notranslate" />\n\n      <meta name="apple-mobile-web-app-capable" content="yes">\n      <meta name="mobile-web-app-capable" content="yes">\n\n\n      <link rel="preconnect" href="https://assets.oyoroomscdn.com" />\n      <link rel="preconnect" href="https://images.oyoroomscdn.com" />\n      <link rel="preconnect" href="https://cdn.moengage.com" />\n      <link rel="preconnect" href="https://www.google-analytics.com" />\n      <link rel="dns-prefetch" href="https://assets.oyoroomscdn.com" />\n      <link rel="dns-prefetch" href="https://images.oyoroomscdn.com" />\n      <link rel="dns-prefetch" href="https://cdn.moengage.com" />\n      <link rel="dns-prefetch" href="https://www.google-analytics.com" />\n      <link href=/assets/desktop/main.e953701e38dac851bad4.css rel="stylesheet" type="text/css" />\n      <link href=/assets/desktop/commoncss.4b11f9835e190a537f3c.css rel="stylesheet" type="text/css" />\n      <link href=/assets/desktop/listing.f60cc288d2f35137d287.css rel="stylesheet" type="text/css" />\n      <script type="text/javascript">\n          window.trackingId = "UA-52365165-1";\n          window.user_id = undefined || \'\';\n          (function(i,s,o,g,r,a,m){i[\'GoogleAnalyticsObject\']=r;i[r]=i[r]||function(){\n                      (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),\n                  m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)\n          })(window,document,\'script\',\'https://www.google-analytics.com/analytics.js\',\'ga\');\n          ga(\'create\', {\n              userId : window.user_id || \'\',\n              trackingId: window.trackingId,\n              cookieDomain: \'auto\',\n              siteSpeedSampleRate: 30,\n              useAmpClientId: true,\n              cookieFlags: "SameSite=None; Secure"\n          });\n          ga(\'require\',\'ec\');\n      </script>\n\n      <script type="application/ld+json">\n        {\n          "@context": "https://schema.org/",\n          "@type": "Organization",\n          "name": "OYO Rooms",\n          "url":"https://www.oyorooms.com/",\n          "logo":"https://www.oyorooms.com/favicon.ico",\n          "sameAs":["https://www.facebook.com/oyorooms", "https://twitter.com/oyorooms", "https://www.pinterest.com/oyorooms/", "https://plus.google.com/u/0/116027434827284400729/posts"],\n          "contactPoint":{\n            "@t ...

# %%
soup = BeautifulSoup(pagecontent)
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# <html dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="ie=edge; chrome=1" httpequiv="x-ua-compatible"/>
# <meta content="lCkLu-7S0Eb5LOgDgmoWxSWzbopNfzKW01ZEe3ldsOc" name="google-site-verification"/>
# <script type="text/javascript">
#       	window.renderingSource='server'
#         var host = window.location.hostname;
#         if (!String.prototype.endsWith) {
# 	        String.prototype.endsWith = function(search, this_len) {
# 		        if (this_len === undefined || this_len > this.length) {
# 			        this_len = this.length;
# 		        }
# 	      	  return this.substring(this_len - search.length, this_len) === search;
# 	        };
#         }
#         if (! (host.endsWith("oyorooms.com") || host.endsWith("oyorooms.ms") || host.endsWith("oyohotels.co.jp") || host.endsWith("hotelesoyo.com") || host.endsWith("oyohotels.com") || host.endsWith("belvilla.co.in") || host.endsWith("oyorooms.io")) && host.indexOf('localhost') < 0){
#           window.location.href="https://www.oyorooms.com";
#         }
#         </script>
# <meta content="en-IN" httpequiv="content-language"/>
# <meta content="width=device-width, initial-scale=1.0, user-scalable=0, minimum-scale=1.0" name="viewport"/>
# <meta content="yes" name="full-screen"/>
# <meta content="#F5F5F5" name="theme-color"/>
# <link href="/manifest.json" rel="manifest"/>
# <link href="android-app://com.oyo.consumer/https/www.oyorooms.com/" rel="alternate"/>
# <meta content="notranslate" name="google"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="yes" name="mobile-web-app-capable"/>
# <link href="https://assets.oyoroomscdn.com" rel="preconnect"/>
# <link href="https://images.oyoroomscdn.com" rel="preconnect"/>
# <link href="https://cdn.moengage.com" rel="preconnect"/>
# <link href="https://www.google-analytics.com" rel="preconnect"/>
# <link href="https://assets.oyoroomscdn.com" rel="dns-prefetch"/>
# <link href="https://images.oyoroomscdn.com" rel="dns-prefetch"/>
# <link href="https://cdn.moengage.com" rel="dns-prefetch"/>
# <link href="https://www.google-analytics.com" rel="dns-prefetch"/>
# <link href="/assets/desktop/main.e953701e38dac851bad4.css" rel="stylesheet" type="text/css"/>
# <link href="/assets/desktop/commoncss.4b11f9835e190a537f3c.css" rel="stylesheet" type="text/css"/>
# <link href="/assets/desktop/listing.f60cc288d2f35137d287.css" rel="stylesheet" type="text/css"/>
# <script type="text/javascript">
#           window.trackingId = "UA-52365165-1";
#           window.user_id = undefined || '';
#           (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#                       (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#                   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#           })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#           ga('create', {
#               userId : window.user_id || '',
#               trackingId: window.trackingId,
#               cookieDomain: 'auto',
#               siteSpeedSampleRate: 30,
#               useAmpClientId: true,
#               cookieFlags: "SameSite=None; Secure"
#           });
#           ga('require','ec');
#       </script>
# <script type="application/ld+json">
#         {
#           "@context": "https://schema.org/",
#           "@type": "Organization",
#           "name": "OYO Rooms",
#           "url":"https://www.oyorooms.com/",
#           "logo":"https://www.oyorooms.com/favicon.ico",
#           "sameAs":["https://www.facebook.com/oyorooms", "https://twitter.com/oyorooms", "https://www.pinterest.com/oyorooms/", "https://plus.google.com/u/0/116027434827284400729/posts"],
#           "contactPoint":{
#             "@type":"ContactPoint",
#             "telephone":"+91 9313 9313 93",
#             "contactType":"Customer Service"
#           }
#         }
#       </script>
# <title data-react-helmet="true">Hotels in Bangalore Starting @ ₹406 - Upto 79% OFF on 256 Bangalore Hotels</title>
# <meta content="https://www.facebook.com/oyorooms" data-react-helmet="true" property="og:publisher"/><meta content="/search/?location=Bangalore%2C%20Karnataka%2C%20India&amp;city=Bangalore&amp;searchType=city&amp;coupon=&amp;checkin=13%2F11%2F2022&amp;checkout=14%2F11%2F2022&amp;roomConfig%5B%5D=2&amp;country=india&amp;guests=2&amp;rooms=1&amp;countryName=India&amp;filters%5Bcity_id%5D=4" data-react-helmet="true" property="og:url"/><meta content="1576475359296300" data-react-helmet="true" property="fb:app_id"/><meta content="app" data-react-helmet="true" name="twitter:card"/><meta content="in" data-react-helmet="true" name="twitter:app:country"/><meta content="OYO Rooms" data-react-helmet="true" name="twitter:text:title"/><meta content="https://assets.oyoroomscdn.com/pwa/icons/oyo-logo-120x120.jpg" data-react-helmet="true" name="twitter:image"/><meta content="Book Hotels in Bangalore &amp; Save up to 79%, Price starts @₹406. OYO Promises &amp;#9989Complimentary Breakfast &amp;#9989Free Cancellation &amp;#9989Free WiFi &amp;#9989AC Room &amp;#9989Spotless linen &amp; &amp;#9989Clean Washrooms." data-react-helmet="true" name="description"/><meta content="OYO Rooms, OYO Hotels, OYO Inn, Budget Hotels, Guest House, Budget Hotels in Gurgaon, Guest House in Gurgaon, Budget Hotels in Delhi, Guest House in Delhi, Budget Hotels in Noida, Guest House in Noida, Budget Hotels in Bangalore, Guest House in Bangalore, Budget Hotels in Mumbai, Guest House in Mumbai, Cheap Hotels in Delhi, Cheap Hotels in Gurgaon, Cheap Hotels in Noida, Cheap Hotels in Bangalore, Cheap Hotels in Mumbai" data-react-helmet="true" name="keywords"/><meta content="Hotels in Bangalore Starting @ ₹406 - Upto 79% OFF on 256 Bangalore Hotels" data-react-helmet="true" property="og:title"/><meta content="Book Hotels in Bangalore &amp; Save up to 79%, Price starts @₹406. OYO Promises &amp;#9989Complimentary Breakfast &amp;#9989Free Cancellation &amp;#9989Free WiFi &amp;#9989AC Room &amp;#9989Spotless linen &amp; &amp;#9989Clean Washrooms." data-react-helmet="true" property="og:description"/><meta content="Hotels in Bangalore Starting @ ₹406 - Upto 79% OFF on 256 Bangalore Hotels" data-react-helmet="true" name="twitter:title"/><meta content="Book Hotels in Bangalore &amp; Save up to 79%, Price starts @₹406. OYO Promises &amp;#9989Complimentary Breakfast &amp;#9989Free Cancellation &amp;#9989Free WiFi &amp;#9989AC Room &amp;#9989Spotless linen &amp; &amp;#9989Clean Washrooms." data-react-helmet="true" name="twitter:description"/><meta content="OYO Rooms" data-react-helmet="true" property="og:site_name"/><meta content="https://images.oyoroomscdn.com/uploads/hotel_image/59954/655c330c4c943b7a.jpg" data-react-helmet="true" property="og:image"/><meta content="hotel" data-react-helmet="true" property="og:type"/><meta content="https://www.oyorooms.com/" data-react-helmet="true" name="twitter:url"/><meta content="NOINDEX, NOFOLLOW" data-react-helmet="true" name="ROBOTS"/><meta content="unavailable_after: Wednesday, 01-Jan-20 01:00:00 IST" data-react-helmet="true" name="robots"/>
# <link data-react-helmet="true" href="https://www.oyorooms.com/favicon.ico" rel="icon"/><link data-react-helmet="true" href="https://www.oyorooms.com/favicon.ico" rel="icon" sizes="48x48" type="image/x-icon"/><link data-react-helmet="true" href="https://assets.oyoroomscdn.com/pwa/icons/oyo-logo-48x48.jpg" rel="apple-touch-icon" sizes="48x48"/><link data-react-helmet="true" href="https://assets.oyoroomscdn.com/pwa/icons/oyo-logo-76x76.jpg" rel="apple-touch-icon" sizes="76x76"/><link data-react-helmet="true" href="https://assets.oyoroomscdn.com/pwa/icons/oyo-logo-120x120.jpg" rel="apple-touch-icon" sizes="120x120"/><link data-react-helmet="true" href="https://assets.oyoroomscdn.com/pwa/icons/oyo-logo-152x152.jpg" rel="apple-touch-icon" sizes="152x152"/><link data-react-helmet="true" href="/" rel="canonical"/>
# <link as="script" href="/assets/desktop/runtime.d4e4471e99372df5fcc3.js" rel="preload"/>
# <link as="script" href="/assets/desktop/externalvendor.1fd4612a45561d7117bb.js" rel="preload"/>
# <link as="script" href="/assets/desktop/common.cb6bb20e01d65d694f3a.js" rel="preload"/>
# <link as="script" href="/assets/desktop/commoncss.209925228a244e033ddd.js" rel="preload"/>
# <link as="script" href="/assets/desktop/listing.06b76248591c9a1458b8.js" rel="preload"/>
# <link as="script" href="/assets/desktop/main.6059aab2c8be16cb6f0a.js" rel="preload"/>
# </head>
# <body itemscope="" itemtype="http://schema.org/WebPage">
# <script type="text/javascript">
#             window.abExpConfig = {"sold":{"val":0,"v":1},"mww2":{"val":"1","v":"4"},"hbad":{"val":0,"v":1},"BnTc":{"val":0,"v":1},"near":{"val":0,"v":1},"ioab":{"val":"0","v":"2"},"mhdp":{"val":"1","v":"5"},"bcrp":{"val":"1","v":"5"},"pwbs":{"val":"1","v":"3"},"mwsb":{"val":0,"v":1},"slin":{"val":"1","v":"11"},"hsdm":{"val":"2","v":"2"},"lpex":{"val":0,"v":1},"lphv":{"val":0,"v":1},"dpcv":{"val":0,"v":1},"gmab":{"val":0,"v":1},"urhe":{"val":0,"v":1},"prdp":{"val":0,"v":1},"comp":{"val":"1","v":"5"},"sldw":{"val":0,"v":1},"mdab":{"val":0,"v":1},"nrmp":{"val":"1","v":"3"},"nhyw":{"val":"1","v":"1"},"wboi":{"val":0,"v":1},"sst":{"val":0,"v":1},"txwb":{"val":0,"v":1},"pod2":{"val":0,"v":1},"lnhd":{"val":0,"v":1},"ppsi":{"val":"0","v":"1"},"gcer":{"val":"0","v":"3"},"recs":{"val":"1","v":"1"},"swhp":{"val":0,"v":1},"lvhm":{"val":"1","v":"3"},"gmbr":{"val":"1","v":"15"},"yolo":{"val":"1","v":"6"},"rcta":{"val":"1","v":"3"},"cbot":{"val":"1","v":"5"},"otpv":{"val":"1","v":"7"},"trtr":{"val":0,"v":1},"lbhw":{"val":0,"v":1},"ndbp":{"val":"0","v":"2"},"mapu":{"val":"1","v":"3"},"nclc":{"val":"1","v":"5"},"dwsl":{"val":"1","v":"2"},"eopt":{"val":"1","v":"3"},"wizi":{"val":"1","v":"2"},"morr":{"val":"1","v":"2"},"yopb":{"val":"0","v":"3"},"TTP":{"val":"1","v":"4"},"Dweb":{"val":"1","v":1},"aimw":{"val":"1","v":"2"},"hdpn":{"val":"1","v":"4"},"web2":{"val":"0","v":"3"},"log2":{"val":"0","v":"3"},"spw1":{"val":0,"v":1},"strf":{"val":0,"v":1},"ugce":{"val":"0","v":"2"},"ltvr":{"val":"1","v":"4"},"hwiz":{"val":"0","v":"3"},"wizz":{"val":"1","v":"5"},"lpcp":{"val":"0","v":"2"},"clhp":{"val":"0","v":"2"},"prwt":{"val":"0","v":"2"},"cbhd":{"val":"0","v":"2"},"ins2":{"val":"3","v":"8"}};
#
#             // SW-INSTALLATION
#             (function() {
#               if ('serviceWorker' in navigator ) {
#                   window.addEventListener('load', function(){
#                     navigator.serviceWorker.register("/service-worker-desktop.js",{scope: "/"});
#                   });
#               }
#           })();
#         </script>
# <div id="root" style="height:100vh;"><style data-emotion-c="1acbpvw r9lts4 g49e0i 1iupfd9 s2hsb0 162c9d0 8ijf8a p2g0oj jj695s 1x32axc xotlao 1t05q14 mk5v0g bxjamc g7fw8n gcjisk qwx4r ml1sc2">@-webkit-keyframes animation-1acbpvw{0%{opacity:0;}100%{opacity:1;}}@keyframes animation-1acbpvw{0%{opacity:0;}100%{opacity:1;}}@-webkit-keyframes animation-r9lts4{0%{background-position:-350px 0;}100%{background-position:350px 0;}}@keyframes animation-r9lts4{0%{background-position:-350px 0;}100%{background-position:350px 0;}}@-webkit-keyframes animation-g49e0i{from{-webkit-transform:translate3d(0,-100 %,0);-ms-transform:translate3d(0,-100 %,0);transform:translate3d(0,-100 %,0);visibility:visible;}to{-webkit-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);transform:translate3d(0,0,0);}}@keyframes animation-g49e0i{from{-webkit-transform:translate3d(0,-100 %,0);-ms-transform:translate3d(0,-100 %,0);transform:translate3d(0,-100 %,0);visibility:visible;}to{-webkit-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);transform:translate3d(0,0,0);}}@-webkit-keyframes animation-1iupfd9{from{-webkit-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);transform:translate3d(0,0,0);}to{visibility:hidden;-webkit-transform:translate3d(0,-100 %,0);-ms-transform:translate3d(0,-100 %,0);transform:translate3d(0,-100 %,0);}}@keyframes animation-1iupfd9{from{-webkit-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);transform:translate3d(0,0,0);}to{visibility:hidden;-webkit-transform:translate3d(0,-100 %,0);-ms-transform:translate3d(0,-100 %,0);transform:translate3d(0,-100 %,0);}}@-webkit-keyframes animation-s2hsb0{from{-webkit-transform:translate3d(100 %,0,0);-ms-transform:translate3d(100 %,0,0);transform:translate3d(100 %,0,0);visibility:visible;}to{-webkit-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);transform:translate3d(0,0,0);}}@keyframes animation-s2hsb0{from{-webkit-transform:translate3d(100 %,0,0);-ms-transform:translate3d(100 %,0,0);transform:translate3d(100 %,0,0);visibility:visible;}to{-webkit-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);transform:translate3d(0,0,0);}}@-webkit-keyframes animation-162c9d0{from{-webkit-transform:translate3d(0,100 %,0);-ms-transform:translate3d(0,100 %,0);transform:translate3d(0,100 %,0);visibility:visible;}to{-webkit-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);transform:translate3d(0,0,0);}}@keyframes animation-162c9d0{from{-webkit-transform:translate3d(0,100 %,0);-ms-transform:translate3d(0,100 %,0);transform:translate3d(0,100 %,0);visibility:visible;}to{-webkit-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);transform:translate3d(0,0,0);}}@-webkit-keyframes animation-8ijf8a{from{-webkit-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);transform:translate3d(0,0,0);}to{visibility:hidden;-webkit-transform:translate3d(100 %,0,0);-ms-transform:translate3d(100 %,0,0);transform:translate3d(100 %,0,0);}}@keyframes animation-8ijf8a{from{-webkit-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);transform:translate3d(0,0,0);}to{visibility:hidden;-webkit-transform:translate3d(100 %,0,0);-ms-transform:translate3d(100 %,0,0);transform:translate3d(100 %,0,0);}}@-webkit-keyframes animation-p2g0oj{from{-webkit-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);transform:translate3d(0,0,0);opacity:0;}to{opacity:1;-webkit-transform:translate3d(0,100%,0);-ms-transform:translate3d(0,100%,0);transform:translate3d(0,100%,0);}}@keyframes animation-p2g0oj{from{-webkit-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);transform:translate3d(0,0,0);opacity:0;}to{opacity:1;-webkit-transform:translate3d(0,100%,0);-ms-transform:translate3d(0,100%,0);transform:translate3d(0,100%,0);}}@-webkit-keyframes animation-jj695s{0%{-webkit-transform:scale(1) translate3d(0,0,0);-ms-transform:scale(1) translate3d(0,0,0);transform:scale(1) translate3d(0,0,0);-webkit-transform-origin:50% 16%;-ms-transfo ...
# <script>
#           window.__PRELOADED_STATE__ = {"home":{"loading":true,"error":null,"data":[{"data":{"left_icons":[{"icon_name":"OyoIcon","icon_title":"","icon_description":"","cta":{"type":"","data":{"action_url":"/"}}}],"right_icons":[{"icon_name":"Text","icon_title":"About us","icon_description":"","cta":{"type":"","data":{"action_url":"https://www.oyorooms.com/about"}}},{"icon_name":"Text","icon_title":"Partner with us","icon_description":"","cta":{"type":"","data":{"action_url":"https://partner.oyorooms.com/?utm_campaign=dweb&utm_medium=dweb&utm_source=dweb"}}},{"icon_name":"TextWithBorder","icon_title":"Login","icon_description":"","show_sticky":true,"cta":{"type":"","data":{"action_url":"https://www.oyorooms.com/login?country=us&retUrl=/us"}}}],"search_data":{"hint":"Search for a city or hotel","show_near_me":true,"near_me_data":{"icon_name":"near me","icon_title":"Near me","icon_description":"","cta":{"type":"","data":{}}},"show_search_bar":true,"error_message":"Please enter your destination","show_sticky":true},"datepax_data":{"checkin_title":"Check-in","checkout_title":"Check-out","show_datepax_picker":true,"nights":"%sN","guest_title":"Rooms and guests","rooms_config":"1,0,0","date_title":"Date"},"search_button_cta":{"title":"Search"},"content_list":["search_data","datepax_data","search_button_cta"],"bgData":[{"media_url":"http://assets.oyoroomscdn.com/Homepageimagewithoverlay.png","media_type":"image"}],"tagLine":{"title":"You are on your way","sub_title":"Book hotels & homes in","sub_titles":["250+ locations","80+ Countries","3 Taps"]}},"id":3767,"type":"home_header_web","data_source":"inline"}],"loaded":false,"extra":false},"searchobj":{"location":"Bangalore, Karnataka, India","city":"bangalore","searchType":"city","tag":"","coupon":"","checkin":"13/11/2022","checkout":"14/11/2022","roomConfig":[2],"localityId":"","showSearchElements":false,"guests":2,"rooms":1,"countryName":"India","cityId":"4"},"deal":{"isFetching":true,"data":{},"error":""},"citiesByChar":{"isFetching":true,"data":{},"error":{}},"cities":{"count":195,"isFetching":true,"data":[{"name":"Agra","country_name":"India"},{"name":"Ahmedabad","country_name":"India"},{"name":"Ajmer","country_name":"India"},{"name":"Alappuzha","country_name":"India"},{"name":"Alibag","country_name":"India"},{"name":"Aligarh","country_name":"India"},{"name":"Allahabad","country_name":"India"},{"name":"Alwar","country_name":"India"},{"name":"Ambala","country_name":"India"},{"name":"Amritsar","country_name":"India"},{"name":"Anand","country_name":"India"},{"name":"Aurangabad","country_name":"India"},{"name":"Baddi","country_name":"India"},{"name":"Bangalore","country_name":"India"},{"name":"Bareilly","country_name":"India"},{"name":"Bathinda","country_name":"India"},{"name":"Behrampur","country_name":"India"},{"name":"Bhilai","country_name":"India"},{"name":"Bhilwara","country_name":"India"},{"name":"Bhiwadi","country_name":"India"},{"name":"Bhopal","country_name":"India"},{"name":"Bhubaneswar","country_name":"India"},{"name":"Bijainagar","country_name":"India"},{"name":"Bikaner","country_name":"India"},{"name":"Bilaspur","country_name":"India"},{"name":"Bodhgaya","country_name":"India"},{"name":"Calicut","country_name":"India"},{"name":"Cameron-Highlands","country_name":"Malaysia"},{"name":"Chandigarh","country_name":"India"},{"name":"Chennai","country_name":"India"},{"name":"Chikmagalur","country_name":"India"},{"name":"Chittorgarh","country_name":"India"},{"name":"Coimbatore","country_name":"India"},{"name":"Coonoor","country_name":"India"},{"name":"Coorg","country_name":"India"},{"name":"Corbett-Ramnagar","country_name":"India"},{"name":"Cuttack","country_name":"India"},{"name":"Dahej","country_name":"India"},{"name":"Dalhousie","country_name":"India"},{"name":"Daman","country_name":"India"},{"name":"Darjeeling","country_name":"India"},{"name":"Dehradun","country_name":"India"},{"name":"Delhi","country_name":"India"},{"name":"Dewas","country_name":"India"},{"name":"Dharamshala" ...
#         </script>
# <script>
#             window.__ROUTE_NAME__ = 'listing'
#         </script>
# <script src="/assets/desktop/runtime.d4e4471e99372df5fcc3.js"></script>
# <script src="/assets/desktop/externalvendor.1fd4612a45561d7117bb.js"></script>
# <script src="/assets/desktop/common.cb6bb20e01d65d694f3a.js"></script>
# <script src="/assets/desktop/commoncss.209925228a244e033ddd.js"></script>
# <script src="/assets/desktop/listing.06b76248591c9a1458b8.js"></script>
# <script src="/assets/desktop/main.6059aab2c8be16cb6f0a.js"></script>
# <noscript>
# <iframe height="0" src="http://www.googletagmanager.com/ns.html?id=GTM-PTZF36" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <script>
#         var prefetchExcludedList = [
#           '/assets/desktop/listing.06b76248591c9a1458b8.js'
#
#           ]
#           if (false){
#             prefetchExcludedList = [
#             '/assets/desktop/listing.b3cfc7a1b429e59faa40.v1.mjs'
#             ]
#           }
#           function script(url) {
#             if((url == "undefined") || (prefetchExcludedList.indexOf(url)>=0)){
#               return null;
#             }
#             var s = document.createElement('link');
#             s.rel = 'prefetch';
#             s.href = url;
#             var x = document.getElementsByTagName('head')[0];
#              //send simply
#             x.appendChild(s);
#           }
#           if (window.addEventListener) {
#               window.addEventListener('load', loadThirdPartyScript, false);
#           } else if (window.attachEvent) {
#               window.attachEvent('onload', loadThirdPartyScript);
#           }
#
#
#
#           function loadThirdPartyScript() {
#               var scriptNameArr = ["countryFlag","assist","home","newHome","listing","detail","bookingDetails","allcities","staticPage","wizard","wizardPlus","trust-and-safety","fourOfour","saveCard","postSaveCard","myBooking","unmarriedCouplesPage","accountDetails","deal","auth","SearchAffiliate","main","oyoforukraine","intl-id","intl-es","intl-ar","intl-vi","intl-hi","intl-pt","intl-ja","intl-th","intl-en","couponOffersPopup","PaymentWrapper/b","PaymentWrapper","authOld","yoImageUploadTemplate","sockjs","externalvendor","common","commoncss","","runtime"];
#               var isSWSupported = 'serviceWorker' in navigator;
#
#             //for other browsers
#             var legacyScriptsToLoad = [
#               '/assets/desktop/listing.06b76248591c9a1458b8.js',
#               '/assets/desktop/home.c75406d1d0c2d35f257d.js',
#               '/assets/desktop/detail.1314717f407dc8f9e11e.js',
#               ''
#             ]
#             for(var i=0 ; i<legacyScriptsToLoad.length;i++){
#                 !isSWSupported && script(legacyScriptsToLoad[i]);
#             }
#
#
#               // GTM
#               (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#               new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#               j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#               '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#               })(window,document,'script','dataLayer','GTM-PTZF36');
#
#               //Load moengage script
#               (function(i,s,o,g,r,a,m,n){
# 	          i['moengage_object']=r;t={}; q = function(f){return function(){(i['moengage_q']=i['moengage_q']||[]).push({f:f,a:arguments});};};
# 	          f = ['track_event','add_user_attribute','add_first_name','add_last_name','add_email','add_mobile',
# 	          'add_user_name','add_gender','add_birthday','destroy_session','add_unique_user_id','moe_events','call_web_push','track','location_type_attribute'];
# 	          for(k in f){t[f[k]]=q(f[k]);}
# 	          a=s.createElement(o);m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m);
# 	          i['moe']=i['moe'] || function(){n=arguments[0];return t;}; a.onload=function(){if(n){i[r] = moe(n);}};
# 	          })(window,document,'script','https://cdn.moengage.com/webpush/moe_webSdk.min.latest.js','Moengage');
# 	          Moengage = moe({
# 	            app_id:"MIJ2OM5MK5YSUOX8XMBAZJHD",
#               debug_logs: 0,
#               swPath: "/service-worker-desktop.js"
#             });
#           }
#         </script>
# </body>
# </html>>

# %%
HotelS = []
RatingS = []
ReviweS= []
PriceS = []
DiscountS=[]
Total_PriceS=[]
AmenitieS=[]
LocationS=[]
Information=[]


for i in range(1,30):
    start_time=time.time()
    url = 'https://www.oyorooms.com/search?location=Bangalore%2C%20Karnataka%2C%20India&city=Bangalore&searchType=city&coupon=&checkin=13%2F11%2F2022&checkout=14%2F11%2F2022&roomConfig%5B%5D=2&country=india&guests=2&rooms=1&countryName=India&filters%5Bcity_id%5D=4&page={}'.format(i)
    page = requests.get(url, headers={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36'})
    pagecontent=page.text
    soup = BeautifulSoup(page.text)
    
    for x in soup.find_all('div', attrs = {'class': 'oyo-cell--12-col oyo-cell--8-col-tablet oyo-cell--4-col-phone'}):
        
        
        #Hotels
        
        hotel_name = x.find('h3', attrs = {'class': 'listingHotelDescription__hotelName d-textEllipsis'})
        
        if hotel_name is None:
            HotelS.append(np.NaN)
        else:
            HotelS.append(hotel_name.text)
            
        
        #Ratings
        
        Ratings = x.find('span', attrs = {'class': 'is-fontBold hotelRating__rating hotelRating__rating--verygood hotelRating__rating--clickable'})

        if Ratings is None:
            RatingS.append(np.NaN)
        else:
            RatingS.append(Ratings.text)   
      
        #Reviwes
        
        Reviwes = x.find('span', attrs = {'class': 'hotelRating__ratingSummary'})

        if Reviwes is None:
            
            ReviweS.append(np.NaN)
        else:
            ReviweS.append(Reviwes.text)   

        
        #Price
        
        price = x.find('span',attrs = {'class': 'listingPrice__finalPrice'})
        
        if price is None:
            PriceS.append(np.NaN)
        else:
            PriceS.append(price.text)


        
        #Discounts
        
        Discount_on_price = x.find('span',attrs = {'class': 'listingPrice__percentage'})
        
        if Discount_on_price is None:
            DiscountS.append(np.NaN)
        else:
            DiscountS.append(Discount_on_price.text)
        
        
         #Total_price
            
        Total_price = x.find('span',attrs = {'class': 'listingPrice__slashedPrice d-body-lg'})
        
        if Total_price is None:
            Total_PriceS.append(np.NaN)
        else:
            Total_PriceS.append(Total_price.text)
        
        #Amenities
        
        Amenities = x.find('span', attrs = {'class':'d-body-sm'})
        
        if Amenities is None:
            AmenitieS.append(np.NaN)
        else:
            AmenitieS.append(Amenities.text)
            
            
            
            
        #Location
        
        Location = x.find('div',attrs = {'class': 'd-body-lg listingHotelDescription__hotelAddress'})
        
        if Location is None:
            LocationS.append(np.NaN)
        else:
            LocationS.append(Location.text)
            
            
            
        #Information
        
        Info = x.find('div',attrs = {'class': 'c-1sugwtq'})
        
        if Info is None:
            Information.append(np.NaN)
        else:
            Information.append(Info.text)
            
            
    end_time = time.time()
    print('Page {} completed in {} seconds'. format(i, end_time-start_time))
# Out:
# Page 1 completed in 6.325050592422485 seconds
# Page 2 completed in 4.863997220993042 seconds
# Page 3 completed in 7.10559868812561 seconds
# Page 4 completed in 7.338923215866089 seconds
# Page 5 completed in 7.004096031188965 seconds
# Page 6 completed in 7.958661079406738 seconds
# Page 7 completed in 8.66495680809021 seconds
# Page 8 completed in 8.770706415176392 seconds
# Page 9 completed in 5.685105323791504 seconds
# Page 10 completed in 6.361678600311279 seconds
# Page 11 completed in 5.019744873046875 seconds
# Page 12 completed in 5.313803672790527 seconds
# Page 13 completed in 7.29384708404541 seconds
# Page 14 completed in 5.7196385860443115 seconds
# Page 15 completed in 3.8816590309143066 seconds
# Page 16 completed in 4.395691633224487 seconds
# Page 17 completed in 4.680614709854126 seconds
# Page 18 completed in 3.7729403972625732 seconds
# Page 19 completed in 4.400382995605469 seconds
# Page 20 completed in 3.9298229217529297 seconds
# Page 21 completed in 3.6810221672058105 seconds
# Page 22 completed in 4.311968803405762 seconds
# Page 23 completed in 6.588525772094727 seconds
# Page 24 completed in 3.8390402793884277 seconds
# Page 25 completed in 5.301330089569092 seconds
# Page 26 completed in 4.155642509460449 seconds
# Page 27 completed in 3.323974132537842 seconds
# Page 28 completed in 3.2772724628448486 seconds
# Page 29 completed in 3.088813304901123 seconds

# %%
print(len(HotelS))
print(len(RatingS))
print(len(PriceS))
print(len(Total_PriceS))
print(len(DiscountS))
print(len(AmenitieS))
print(len(LocationS))
print(len(Information))
print(len(ReviweS))
# Out:
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256

# %%
df1 = pd.DataFrame({'Hotels':HotelS,
                    'Prices':PriceS,
                    'Total_Price':Total_PriceS,
                    'Ratings':RatingS,
                    'Booking_Discounts(%)':DiscountS,
                    'Reviews':ReviweS,
                    'Facilities':AmenitieS,
                    'Address':LocationS,
                    'Informations':Information})
df1
# Out:
#                                                 Hotels Prices Total_Price  \
# 0                               OYO 11915 Varcity Park  ₹1158       ₹4134
# 1    OYO Townhouse 385 Navya International Ramamurt...  ₹1402       ₹5005
# 2                             Capital O 12543 3 Square  ₹1330       ₹4751
# 3                             OYO 15358 Hotel Townhall   ₹974       ₹3477
# 4                              SPOT ON 65593 Yatra Inn  ₹1088       ₹3885
# ..                                                 ...    ...         ...
# 251                       OYO Townhouse 049 HSR Layout    NaN         NaN
# 252                 OYO Flagship 702960 Ericon Comfort    NaN         NaN
# 253              Flagship 29620 New Champion Residency    NaN         NaN
# 254                       OYO Flagship 67007 Manyu Inn    NaN         NaN
# 255              OYO Townhouse 159 Sarjapur (Yo Stays)    NaN         NaN
#
#     Ratings Booking_Discounts(%)         Reviews          Facilities  \
# 0       NaN              71% off  (2254 Ratings)     Doctor on call
# 1       NaN              71% off  (1903 Ratings)    Electric Kettle
# 2       NaN              72% off  (1323 Ratings)           Elevator
# 3       NaN              71% off  (1460 Ratings)   Parking facility
# 4       NaN              71% off  (2723 Ratings)          Reception
# ..      ...                  ...             ...                 ...
# 251    4.1                   NaN  (1253 Ratings)         Free Wi-Fi
# 252     NaN                  NaN             NaN           Elevator
# 253     NaN                  NaN   (611 Ratings)   Parking facility
# 254     NaN                  NaN   (409 Ratings)         Hair Dryer
# 255    4.0                   NaN  (1101 Ratings)     Doctor on call
#
#                                              Address  \
# 0             Near SV Hospitals, Madiwala, Bangalore
# 1    Near Rammamurthynagar Police Station, Bangalore
# 2     Next to Cafe Coffee Day, HBR Layout, Bangalore
# 3          Near Dhanlakshmi Bank, JC Road, Bangalore
# 4                                 Lalbagh, Bangalore
# ..                                               ...
# 251           Near HSR Club, Kadalda Meen, Bangalore
# 252                                Hebbal, Bangalore
# 253        Near Old Madras Road, KR Puram, Bangalore
# 254       Near Vibgyor School, HSR Layout, Bangalore
# 255                    Near Doddakannelli, Bangalore
#
#                              Informations
# 0      All staff vaccinated with 1st dose
# 1      All staff vaccinated with 1st dose
# 2      All staff vaccinated with 1st dose
# 3    All staff vaccinated with both doses
# 4        9 people booked this hotel today
# ..                                    ...
# 251    All staff vaccinated with 1st dose
# 252                                   NaN
# 253    All staff vaccinated with 1st dose
# 254    All staff vaccinated with 1st dose
# 255    All staff vaccinated with 1st dose
#
# [256 rows x 9 columns]

# %%
df1.duplicated().sum()
# Out:
# 13

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 256 entries, 0 to 255
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Hotels                256 non-null    object
#  1   Prices                214 non-null    object
#  2   Total_Price           214 non-null    object
#  3   Ratings               47 non-null     object
#  4   Booking_Discounts(%)  214 non-null    object
#  5   Reviews               244 non-null    object
#  6   Facilities            253 non-null    object
#  7   Address               256 non-null    object
#  8   Informations          213 non-null    object
# dtypes: object(9)
# memory usage: 18.1+ KB

# %%
df1['Prices'] = df1['Prices'].astype(str)

# %%
df1['Prices'] = df1['Prices'].apply(lambda x: x.replace('NaN','0000'))

# %%
df1['Prices'] = df1['Prices'].apply(lambda x: x.replace('₹',''))

# %%
df1['Prices'] = df1['Prices'].astype(float)

# %%
df1['Prices'].fillna(df1['Prices'].mean(), inplace = True)

# %%
df1
# Out:
#                                                 Hotels       Prices  \
# 0                               OYO 11915 Varcity Park  1158.000000
# 1    OYO Townhouse 385 Navya International Ramamurt...  1402.000000
# 2                             Capital O 12543 3 Square  1330.000000
# 3                             OYO 15358 Hotel Townhall   974.000000
# 4                              SPOT ON 65593 Yatra Inn  1088.000000
# ..                                                 ...          ...
# 251                       OYO Townhouse 049 HSR Layout  1276.369159
# 252                 OYO Flagship 702960 Ericon Comfort  1276.369159
# 253              Flagship 29620 New Champion Residency  1276.369159
# 254                       OYO Flagship 67007 Manyu Inn  1276.369159
# 255              OYO Townhouse 159 Sarjapur (Yo Stays)  1276.369159
#
#     Total_Price Ratings Booking_Discounts(%)         Reviews  \
# 0         ₹4134     NaN              71% off  (2254 Ratings)
# 1         ₹5005     NaN              71% off  (1903 Ratings)
# 2         ₹4751     NaN              72% off  (1323 Ratings)
# 3         ₹3477     NaN              71% off  (1460 Ratings)
# 4         ₹3885     NaN              71% off  (2723 Ratings)
# ..          ...     ...                  ...             ...
# 251         NaN    4.1                   NaN  (1253 Ratings)
# 252         NaN     NaN                  NaN             NaN
# 253         NaN     NaN                  NaN   (611 Ratings)
# 254         NaN     NaN                  NaN   (409 Ratings)
# 255         NaN    4.0                   NaN  (1101 Ratings)
#
#              Facilities                                          Address  \
# 0       Doctor on call            Near SV Hospitals, Madiwala, Bangalore
# 1      Electric Kettle   Near Rammamurthynagar Police Station, Bangalore
# 2             Elevator    Next to Cafe Coffee Day, HBR Layout, Bangalore
# 3     Parking facility         Near Dhanlakshmi Bank, JC Road, Bangalore
# 4            Reception                                Lalbagh, Bangalore
# ..                  ...                                              ...
# 251         Free Wi-Fi            Near HSR Club, Kadalda Meen, Bangalore
# 252           Elevator                                 Hebbal, Bangalore
# 253   Parking facility         Near Old Madras Road, KR Puram, Bangalore
# 254         Hair Dryer        Near Vibgyor School, HSR Layout, Bangalore
# 255     Doctor on call                     Near Doddakannelli, Bangalore
#
#                              Informations
# 0      All staff vaccinated with 1st dose
# 1      All staff vaccinated with 1st dose
# 2      All staff vaccinated with 1st dose
# 3    All staff vaccinated with both doses
# 4        9 people booked this hotel today
# ..                                    ...
# 251    All staff vaccinated with 1st dose
# 252                                   NaN
# 253    All staff vaccinated with 1st dose
# 254    All staff vaccinated with 1st dose
# 255    All staff vaccinated with 1st dose
#
# [256 rows x 9 columns]

# %%
df1['Total_Price'] = df1['Total_Price'].astype(str)

# %%
df1['Total_Price'] = df1['Total_Price'].apply(lambda x: x.replace('NaN','0000'))

# %%
df1['Total_Price'] = df1['Total_Price'].apply(lambda x: x.replace('₹',''))

# %%
df1['Total_Price'] = df1['Total_Price'].astype(float)

# %%
df1['Total_Price'].fillna(df1['Total_Price'].mean(), inplace = True)

# %%
df1
# Out:
#                                                 Hotels       Prices  \
# 0                               OYO 11915 Varcity Park  1158.000000
# 1    OYO Townhouse 385 Navya International Ramamurt...  1402.000000
# 2                             Capital O 12543 3 Square  1330.000000
# 3                             OYO 15358 Hotel Townhall   974.000000
# 4                              SPOT ON 65593 Yatra Inn  1088.000000
# ..                                                 ...          ...
# 251                       OYO Townhouse 049 HSR Layout  1276.369159
# 252                 OYO Flagship 702960 Ericon Comfort  1276.369159
# 253              Flagship 29620 New Champion Residency  1276.369159
# 254                       OYO Flagship 67007 Manyu Inn  1276.369159
# 255              OYO Townhouse 159 Sarjapur (Yo Stays)  1276.369159
#
#      Total_Price Ratings Booking_Discounts(%)         Reviews  \
# 0    4134.000000     NaN              71% off  (2254 Ratings)
# 1    5005.000000     NaN              71% off  (1903 Ratings)
# 2    4751.000000     NaN              72% off  (1323 Ratings)
# 3    3477.000000     NaN              71% off  (1460 Ratings)
# 4    3885.000000     NaN              71% off  (2723 Ratings)
# ..           ...     ...                  ...             ...
# 251  4141.593458    4.1                   NaN  (1253 Ratings)
# 252  4141.593458     NaN                  NaN             NaN
# 253  4141.593458     NaN                  NaN   (611 Ratings)
# 254  4141.593458     NaN                  NaN   (409 Ratings)
# 255  4141.593458    4.0                   NaN  (1101 Ratings)
#
#              Facilities                                          Address  \
# 0       Doctor on call            Near SV Hospitals, Madiwala, Bangalore
# 1      Electric Kettle   Near Rammamurthynagar Police Station, Bangalore
# 2             Elevator    Next to Cafe Coffee Day, HBR Layout, Bangalore
# 3     Parking facility         Near Dhanlakshmi Bank, JC Road, Bangalore
# 4            Reception                                Lalbagh, Bangalore
# ..                  ...                                              ...
# 251         Free Wi-Fi            Near HSR Club, Kadalda Meen, Bangalore
# 252           Elevator                                 Hebbal, Bangalore
# 253   Parking facility         Near Old Madras Road, KR Puram, Bangalore
# 254         Hair Dryer        Near Vibgyor School, HSR Layout, Bangalore
# 255     Doctor on call                     Near Doddakannelli, Bangalore
#
#                              Informations
# 0      All staff vaccinated with 1st dose
# 1      All staff vaccinated with 1st dose
# 2      All staff vaccinated with 1st dose
# 3    All staff vaccinated with both doses
# 4        9 people booked this hotel today
# ..                                    ...
# 251    All staff vaccinated with 1st dose
# 252                                   NaN
# 253    All staff vaccinated with 1st dose
# 254    All staff vaccinated with 1st dose
# 255    All staff vaccinated with 1st dose
#
# [256 rows x 9 columns]

# %%
df1['Ratings'] = df1['Ratings'].astype(str)

# %%
df1['Ratings'] = df1['Ratings'].apply(lambda x: x.replace('NaN','0000'))

# %%
df1['Ratings'] = df1['Ratings'].astype(float)

# %%
df1['Ratings'].fillna(df1['Ratings'].mean(), inplace = True)

# %%
df1
# Out:
#                                                 Hotels       Prices  \
# 0                               OYO 11915 Varcity Park  1158.000000
# 1    OYO Townhouse 385 Navya International Ramamurt...  1402.000000
# 2                             Capital O 12543 3 Square  1330.000000
# 3                             OYO 15358 Hotel Townhall   974.000000
# 4                              SPOT ON 65593 Yatra Inn  1088.000000
# ..                                                 ...          ...
# 251                       OYO Townhouse 049 HSR Layout  1276.369159
# 252                 OYO Flagship 702960 Ericon Comfort  1276.369159
# 253              Flagship 29620 New Champion Residency  1276.369159
# 254                       OYO Flagship 67007 Manyu Inn  1276.369159
# 255              OYO Townhouse 159 Sarjapur (Yo Stays)  1276.369159
#
#      Total_Price   Ratings Booking_Discounts(%)         Reviews  \
# 0    4134.000000  4.134043              71% off  (2254 Ratings)
# 1    5005.000000  4.134043              71% off  (1903 Ratings)
# 2    4751.000000  4.134043              72% off  (1323 Ratings)
# 3    3477.000000  4.134043              71% off  (1460 Ratings)
# 4    3885.000000  4.134043              71% off  (2723 Ratings)
# ..           ...       ...                  ...             ...
# 251  4141.593458  4.100000                  NaN  (1253 Ratings)
# 252  4141.593458  4.134043                  NaN             NaN
# 253  4141.593458  4.134043                  NaN   (611 Ratings)
# 254  4141.593458  4.134043                  NaN   (409 Ratings)
# 255  4141.593458  4.000000                  NaN  (1101 Ratings)
#
#              Facilities                                          Address  \
# 0       Doctor on call            Near SV Hospitals, Madiwala, Bangalore
# 1      Electric Kettle   Near Rammamurthynagar Police Station, Bangalore
# 2             Elevator    Next to Cafe Coffee Day, HBR Layout, Bangalore
# 3     Parking facility         Near Dhanlakshmi Bank, JC Road, Bangalore
# 4            Reception                                Lalbagh, Bangalore
# ..                  ...                                              ...
# 251         Free Wi-Fi            Near HSR Club, Kadalda Meen, Bangalore
# 252           Elevator                                 Hebbal, Bangalore
# 253   Parking facility         Near Old Madras Road, KR Puram, Bangalore
# 254         Hair Dryer        Near Vibgyor School, HSR Layout, Bangalore
# 255     Doctor on call                     Near Doddakannelli, Bangalore
#
#                              Informations
# 0      All staff vaccinated with 1st dose
# 1      All staff vaccinated with 1st dose
# 2      All staff vaccinated with 1st dose
# 3    All staff vaccinated with both doses
# 4        9 people booked this hotel today
# ..                                    ...
# 251    All staff vaccinated with 1st dose
# 252                                   NaN
# 253    All staff vaccinated with 1st dose
# 254    All staff vaccinated with 1st dose
# 255    All staff vaccinated with 1st dose
#
# [256 rows x 9 columns]

# %%
df1['Booking_Discounts(%)'] = df1['Booking_Discounts(%)'].str.replace('\D+','')
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2444\2563500470.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df1['Booking_Discounts(%)'] = df1['Booking_Discounts(%)'].str.replace('\D+','')

# %%
df1['Booking_Discounts(%)']=df1['Booking_Discounts(%)'].astype(float)

# %%
df1['Booking_Discounts(%)'].fillna(df1['Booking_Discounts(%)'].mean(),inplace=True)

# %%
df1
# Out:
#                                                 Hotels       Prices  \
# 0                               OYO 11915 Varcity Park  1158.000000
# 1    OYO Townhouse 385 Navya International Ramamurt...  1402.000000
# 2                             Capital O 12543 3 Square  1330.000000
# 3                             OYO 15358 Hotel Townhall   974.000000
# 4                              SPOT ON 65593 Yatra Inn  1088.000000
# ..                                                 ...          ...
# 251                       OYO Townhouse 049 HSR Layout  1276.369159
# 252                 OYO Flagship 702960 Ericon Comfort  1276.369159
# 253              Flagship 29620 New Champion Residency  1276.369159
# 254                       OYO Flagship 67007 Manyu Inn  1276.369159
# 255              OYO Townhouse 159 Sarjapur (Yo Stays)  1276.369159
#
#      Total_Price   Ratings  Booking_Discounts(%)         Reviews  \
# 0    4134.000000  4.134043             71.000000  (2254 Ratings)
# 1    5005.000000  4.134043             71.000000  (1903 Ratings)
# 2    4751.000000  4.134043             72.000000  (1323 Ratings)
# 3    3477.000000  4.134043             71.000000  (1460 Ratings)
# 4    3885.000000  4.134043             71.000000  (2723 Ratings)
# ..           ...       ...                   ...             ...
# 251  4141.593458  4.100000             68.626168  (1253 Ratings)
# 252  4141.593458  4.134043             68.626168             NaN
# 253  4141.593458  4.134043             68.626168   (611 Ratings)
# 254  4141.593458  4.134043             68.626168   (409 Ratings)
# 255  4141.593458  4.000000             68.626168  (1101 Ratings)
#
#              Facilities                                          Address  \
# 0       Doctor on call            Near SV Hospitals, Madiwala, Bangalore
# 1      Electric Kettle   Near Rammamurthynagar Police Station, Bangalore
# 2             Elevator    Next to Cafe Coffee Day, HBR Layout, Bangalore
# 3     Parking facility         Near Dhanlakshmi Bank, JC Road, Bangalore
# 4            Reception                                Lalbagh, Bangalore
# ..                  ...                                              ...
# 251         Free Wi-Fi            Near HSR Club, Kadalda Meen, Bangalore
# 252           Elevator                                 Hebbal, Bangalore
# 253   Parking facility         Near Old Madras Road, KR Puram, Bangalore
# 254         Hair Dryer        Near Vibgyor School, HSR Layout, Bangalore
# 255     Doctor on call                     Near Doddakannelli, Bangalore
#
#                              Informations
# 0      All staff vaccinated with 1st dose
# 1      All staff vaccinated with 1st dose
# 2      All staff vaccinated with 1st dose
# 3    All staff vaccinated with both doses
# 4        9 people booked this hotel today
# ..                                    ...
# 251    All staff vaccinated with 1st dose
# 252                                   NaN
# 253    All staff vaccinated with 1st dose
# 254    All staff vaccinated with 1st dose
# 255    All staff vaccinated with 1st dose
#
# [256 rows x 9 columns]

# %%
df1['Reviews'] = df1['Reviews'].str.replace('\D+','')
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2444\629340285.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df1['Reviews'] = df1['Reviews'].str.replace('\D+','')

# %%
df1['Reviews']=df1['Reviews'].astype(float)

# %%
df1['Reviews'].fillna(df1['Reviews'].mean(),inplace=True)

# %%
df1
# Out:
#                                                 Hotels       Prices  \
# 0                               OYO 11915 Varcity Park  1158.000000
# 1    OYO Townhouse 385 Navya International Ramamurt...  1402.000000
# 2                             Capital O 12543 3 Square  1330.000000
# 3                             OYO 15358 Hotel Townhall   974.000000
# 4                              SPOT ON 65593 Yatra Inn  1088.000000
# ..                                                 ...          ...
# 251                       OYO Townhouse 049 HSR Layout  1276.369159
# 252                 OYO Flagship 702960 Ericon Comfort  1276.369159
# 253              Flagship 29620 New Champion Residency  1276.369159
# 254                       OYO Flagship 67007 Manyu Inn  1276.369159
# 255              OYO Townhouse 159 Sarjapur (Yo Stays)  1276.369159
#
#      Total_Price   Ratings  Booking_Discounts(%)      Reviews  \
# 0    4134.000000  4.134043             71.000000  2254.000000
# 1    5005.000000  4.134043             71.000000  1903.000000
# 2    4751.000000  4.134043             72.000000  1323.000000
# 3    3477.000000  4.134043             71.000000  1460.000000
# 4    3885.000000  4.134043             71.000000  2723.000000
# ..           ...       ...                   ...          ...
# 251  4141.593458  4.100000             68.626168  1253.000000
# 252  4141.593458  4.134043             68.626168   794.565574
# 253  4141.593458  4.134043             68.626168   611.000000
# 254  4141.593458  4.134043             68.626168   409.000000
# 255  4141.593458  4.000000             68.626168  1101.000000
#
#              Facilities                                          Address  \
# 0       Doctor on call            Near SV Hospitals, Madiwala, Bangalore
# 1      Electric Kettle   Near Rammamurthynagar Police Station, Bangalore
# 2             Elevator    Next to Cafe Coffee Day, HBR Layout, Bangalore
# 3     Parking facility         Near Dhanlakshmi Bank, JC Road, Bangalore
# 4            Reception                                Lalbagh, Bangalore
# ..                  ...                                              ...
# 251         Free Wi-Fi            Near HSR Club, Kadalda Meen, Bangalore
# 252           Elevator                                 Hebbal, Bangalore
# 253   Parking facility         Near Old Madras Road, KR Puram, Bangalore
# 254         Hair Dryer        Near Vibgyor School, HSR Layout, Bangalore
# 255     Doctor on call                     Near Doddakannelli, Bangalore
#
#                              Informations
# 0      All staff vaccinated with 1st dose
# 1      All staff vaccinated with 1st dose
# 2      All staff vaccinated with 1st dose
# 3    All staff vaccinated with both doses
# 4        9 people booked this hotel today
# ..                                    ...
# 251    All staff vaccinated with 1st dose
# 252                                   NaN
# 253    All staff vaccinated with 1st dose
# 254    All staff vaccinated with 1st dose
# 255    All staff vaccinated with 1st dose
#
# [256 rows x 9 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 256 entries, 0 to 255
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Hotels                256 non-null    object
#  1   Prices                256 non-null    float64
#  2   Total_Price           256 non-null    float64
#  3   Ratings               256 non-null    float64
#  4   Booking_Discounts(%)  256 non-null    float64
#  5   Reviews               256 non-null    float64
#  6   Facilities            253 non-null    object
#  7   Address               256 non-null    object
#  8   Informations          213 non-null    object
# dtypes: float64(5), object(4)
# memory usage: 18.1+ KB

# %%
df1["City_Name"] = df1['Address'].apply(lambda x: x.split(',')[-1])
df1
# Out:
#                                                 Hotels       Prices  \
# 0                               OYO 11915 Varcity Park  1158.000000
# 1    OYO Townhouse 385 Navya International Ramamurt...  1402.000000
# 2                             Capital O 12543 3 Square  1330.000000
# 3                             OYO 15358 Hotel Townhall   974.000000
# 4                              SPOT ON 65593 Yatra Inn  1088.000000
# ..                                                 ...          ...
# 251                       OYO Townhouse 049 HSR Layout  1276.369159
# 252                 OYO Flagship 702960 Ericon Comfort  1276.369159
# 253              Flagship 29620 New Champion Residency  1276.369159
# 254                       OYO Flagship 67007 Manyu Inn  1276.369159
# 255              OYO Townhouse 159 Sarjapur (Yo Stays)  1276.369159
#
#      Total_Price   Ratings  Booking_Discounts(%)      Reviews  \
# 0    4134.000000  4.134043             71.000000  2254.000000
# 1    5005.000000  4.134043             71.000000  1903.000000
# 2    4751.000000  4.134043             72.000000  1323.000000
# 3    3477.000000  4.134043             71.000000  1460.000000
# 4    3885.000000  4.134043             71.000000  2723.000000
# ..           ...       ...                   ...          ...
# 251  4141.593458  4.100000             68.626168  1253.000000
# 252  4141.593458  4.134043             68.626168   794.565574
# 253  4141.593458  4.134043             68.626168   611.000000
# 254  4141.593458  4.134043             68.626168   409.000000
# 255  4141.593458  4.000000             68.626168  1101.000000
#
#              Facilities                                          Address  \
# 0       Doctor on call            Near SV Hospitals, Madiwala, Bangalore
# 1      Electric Kettle   Near Rammamurthynagar Police Station, Bangalore
# 2             Elevator    Next to Cafe Coffee Day, HBR Layout, Bangalore
# 3     Parking facility         Near Dhanlakshmi Bank, JC Road, Bangalore
# 4            Reception                                Lalbagh, Bangalore
# ..                  ...                                              ...
# 251         Free Wi-Fi            Near HSR Club, Kadalda Meen, Bangalore
# 252           Elevator                                 Hebbal, Bangalore
# 253   Parking facility         Near Old Madras Road, KR Puram, Bangalore
# 254         Hair Dryer        Near Vibgyor School, HSR Layout, Bangalore
# 255     Doctor on call                     Near Doddakannelli, Bangalore
#
#                              Informations   City_Name
# 0      All staff vaccinated with 1st dose   Bangalore
# 1      All staff vaccinated with 1st dose   Bangalore
# 2      All staff vaccinated with 1st dose   Bangalore
# 3    All staff vaccinated with both doses   Bangalore
# 4        9 people booked this hotel today   Bangalore
# ..                                    ...         ...
# 251    All staff vaccinated with 1st dose   Bangalore
# 252                                   NaN   Bangalore
# 253    All staff vaccinated with 1st dose   Bangalore
# 254    All staff vaccinated with 1st dose   Bangalore
# 255    All staff vaccinated with 1st dose   Bangalore
#
# [256 rows x 10 columns]

# %%
df1['Address']
# Out:
# 0               Near SV Hospitals, Madiwala, Bangalore
# 1      Near Rammamurthynagar Police Station, Bangalore
# 2       Next to Cafe Coffee Day, HBR Layout, Bangalore
# 3            Near Dhanlakshmi Bank, JC Road, Bangalore
# 4                                   Lalbagh, Bangalore
#                             ...
# 251             Near HSR Club, Kadalda Meen, Bangalore
# 252                                  Hebbal, Bangalore
# 253          Near Old Madras Road, KR Puram, Bangalore
# 254         Near Vibgyor School, HSR Layout, Bangalore
# 255                      Near Doddakannelli, Bangalore
# Name: Address, Length: 256, dtype: object

# %%
city = []
for i in df1['Address']:
    city.append(i.split())
city
# Out:
# [['Near', 'SV', 'Hospitals,', 'Madiwala,', 'Bangalore'],
#  ['Near', 'Rammamurthynagar', 'Police', 'Station,', 'Bangalore'],
#  ['Next', 'to', 'Cafe', 'Coffee', 'Day,', 'HBR', 'Layout,', 'Bangalore'],
#  ['Near', 'Dhanlakshmi', 'Bank,', 'JC', 'Road,', 'Bangalore'],
#  ['Lalbagh,', 'Bangalore'],
#  ['Centrally',
#   'Located,',
#   'Near',
#   'A',
#   'D',
#   'Halli',
#   'Park,',
#   'Housing',
#   'Board,',
#   'Bangalore'],
#  ['Near', 'Manyata', 'Tech', 'Park,Mesthri', 'Palya,', 'Bangalore'],
#  ['7th', 'Block,', 'Bangalore'],
#  ['achenahalli,',
#   'Thanisandra',
#   'main',
#   'road',
#   'Bangalore',
#   'India',
#   '-',
#   '560077'],
#  ['Opposite',
#   'Satelite',
#   'Bus',
#   'Stand',
#   'Bapujinagar',
#   'Mysore',
#   'Road',
#   'Bangalore',
#   '560026'],
#  ['Halasuru,', 'Bangalore'],
#  ['B', 't', 'm', 'Layout,', 'Bangalore'],
#  ['Behind', 'Manyata', 'Tech', 'Park,', 'Rechanahalli,', 'Bangalore'],
#  ['Near', 'Manyata', 'Tech', 'Park', 'Gate', '4,', 'Bangalore'],
#  ['Road,', 'Bangalore'],
#  ['Chikkajala,', 'Bangalore'],
#  ['Centrally',
#   'Located,',
#   'Near',
#   'HKP',
#   'Road,',
#   'Shivaji',
#   'Nagar,',
#   'Bangalore'],
#  ['Near', 'REVA', 'University,', 'Masjid', 'Road,', 'Kattigenahalli'],
#  ['Near', 'Naryana', 'PU', 'college,', 'BEML', 'Layout,', 'Bangalore'],
#  ['Near', 'NIAS,', 'Mathikere', 'Extension,', 'Bangalore'],
#  ['Addiganahalli', 'Bangalore'],
#  ['Hegganahalli', 'Main', 'Road,', 'Bangalore'],
#  ['Near', 'Electronic', 'City,', 'Basapura', 'Hosur', 'Road,', 'Bangalore'],
#  ['Near', 'NIAS,', 'Mathikere', 'Extension,', 'Bangalore'],
#  ['Near', 'Shanti', 'Niketan', 'School,', 'Maruthinagar,', 'Bangalore'],
#  ['NEAR', 'GKVK', 'JAKKUR', 'PLANTATION'],
#  ['1st', 'Cross', 'Ps', 'Lane', 'Cottonpet', 'Majestic,', 'Bangalore'],
#  ['BEML',
#   'Layout,',
#   'Near',
#   'RNS',
#   'Engineering',
#   'college,',
#   'Rajarajeshwari',
#   'Nagar,',
#   'Bangalore'],
#  ['Rajarajeshwari', 'Nagar', 'Zone,', 'Bangalore'],
#  ['Hulimangala',
#   'Main',
#   'Road',
#   'Electronic',
#   'City',
#   'Phase',
#   '1',
#   'Bangalore,',
#   'Bangalore'],
#  ['Near', 'MG', 'school,', 'Bilekahalli', ',', 'Bangalore'],
#  ['Near', 'Shamaro', 'Vittal', 'Co-Operative', 'Bank,', 'Bangalore'],
#  ['Near', 'Forum', 'Mall,', 'Koramangala,', 'Bangalore'],
#  ['Kalyan', 'Nagar,', 'Bangalore'],
#  ['Bangalore', 'Urban,', 'Bangalore'],
#  ['Next', 'to', 'Cafe', 'Coffee', 'Day,', 'HBR', 'Layout,', 'Bangalore'],
#  ['Near', 'Robert', 'Bosch', 'Company,', 'Mangammanapalya,', 'Bangalore'],
#  ['562107,', 'Bangalore'],
#  ['Koothi', 'Thope,', 'Bangalore'],
#  ['Near', 'Happy', 'Home', 'Shopping', 'Mall,', 'RR', 'Nagar,', 'Bangalore'],
#  ['India,', 'Bangalore'],
#  ['Btm', 'Layout,', 'Bangalore'],
#  ['49,',
#   '20th',
#   'main',
#   'road,',
#   'Gangotri',
#   'circle,',
#   'opposite',
#   'to',
#   'life',
#   'care',
#   'hospital,',
#   'Old',
#   'Madiwala,',
#   'Aicobo',
#   'Nagar,',
#   '1st',
#   'Stage,',
#   'BTM',
#   '1st',
#   'Stage,',
#   'Bengaluru,',
#   'Karnataka',
#   '560029'],
#  ['Centrally',
#   'Located,',
#   'Near',
#   'HKP',
#   'Road,',
#   'Shivaji',
#   'Nagar,',
#   'Bangalore'],
#  ['Near', 'Central', 'Silk', 'board,', 'BTM', 'Layout,', 'Bangalore'],
#  ['Near',
#   'Wonderla',
#   'Gate,',
#   'Mysore',
#   'Road,',
#   'Bangalore,',
#   'India',
#   '-',
#   '560091'],
#  ['Chamudeswary', 'layout,', 'Bangalore'],
#  ['Behind',
#   'Manyata',
#   'Tech',
#   'Park',
#   'Gate',
#   'No.5,',
#   'Rachenahalli',
#   'main',
#   'road',
#   'Bangalore'],
#  ['Near', 'Jayadeva', 'circel,', 'Vysya', 'Bank', 'Colony,', 'Bangalore'],
#  ['Rajarajeshwari', 'Nagar,', 'Bangalore'],
#  ['Near', 'Udupi', 'bhavan,', 'Attibele,', 'Bangalore'],
#  ['Near',
#   'Sapthagiri',
#   'engineering',
#   'college,',
#   'Jalahalli',
#   '-',
#   'West,',
#   'Bengaluru'],
#  ['NAR',
#   'Comforts,13,',
#   'G.K',
#   'temple',
#   'street,',
#   'opp.',
#   'Vijayalaxmi',
#   'theater,',
#   'Chickpet,',
#   'Bangalore'],
#  ['Bilekahalli,', 'Bangalore'],
#  ['India', 'Bangalore', 'Karnataka', 'India,', 'Bangalore'],
#  ['Near', 'SBI', 'Bank,', 'RT', 'Nagar', 'Main', 'Road,', 'Bangalore'],
#  ['Sector',
#   '6,',
#   'HSR',
#   'Layout',
#   'Ward,',
#   'Bommanahalli',
#   'Zone,',
#   'Bengaluru,',
#   'Bangalore',
#   'South,',
#   'Bangalore',
#   'Urban,',
#   'Karnataka'],
#  ['Near', 'State', 'Bank', 'Of', 'India,', 'Beltur,', 'Bangalore'],
#  ['Near', "St.Philomena's", 'Hospital,', 'Xavier', 'Layout,', 'Bangalore'],
#  ['Near', 'Vijaya', 'Nagar,', 'Bangalore'],
#  ['Kaveri', 'Nagar,', 'Bangalore'],
#  ['Near', 'Manyata', 'Tech', 'Park', 'Gate', '4,', 'Bangalore'],
#  ['Near', 'SV', 'Hospitals,', 'Madiwala,', 'Bangalore'],
#  ['Katakam',
#   'Complex',
#   'Shidedahalli',
#   'Circle',
#   'Nagasandra',
#   'Post,',
#   'Bangalore'],
#  ['Road,', 'Bangalore'],
#  ['Behind', 'Manyata', 'Tech', 'Park,', 'Rechanahalli,', 'Bangalore'],
#  ['Near', 'Chandapura', 'Market,', 'Anekal,', 'Bangalore'],
#  ['Ayappa',
#   'Block',
#   '1st',
#   'Floor',
#   'House',
#   '.no',
#   '62',
#   'Agrahar',
#   'Badavane',
#   'Kogilu',
#   'Yelahanka,',
#   'Bangalore'],
#  ['Dispensary', 'Rd,', 'Kalasipalya,Bangalore'],
#  ['Near', 'Thalaserry', 'Restaurant,', 'Prasanth', 'Layout,', 'Bangalore'],
#  ['machohalli', 'opposite', 'Pooja', 'hospital,', 'Bangalore'],
#  ['Near', 'Bata', 'Show', 'Room,', 'Yeshwanthpur,', 'Bangalore'],
#  ['4th', 'Block,', 'Rajaji', 'Nagar,', 'Bangalore'],
#  ['Near', 'Hosahalli', 'Main', 'Road,', 'Hunasamaranahalli,', 'Bangalore'],
#  ['Near', 'V.E.T', 'School,', 'J.P.', 'Nagar,', 'Bangalore'],
#  ['Bangalore', 'Urban,', 'Bangalore'],
#  ['Centrally',
#   'Located,',
#   'Near',
#   'A',
#   'D',
#   'Halli',
#   'Park,',
#   'Housing',
#   'Board,',
#   'Bangalore'],
#  ['Bidarahalli', 'Hobli,', 'Bangalore'],
#  ['Tavarekere', 'Main', 'Rd,', 'Bangalore'],
#  ['Near', 'MMR', 'Shopping', 'Complex,', 'Kammasandra,', 'Bangalore'],
#  ['Kammanahalli', 'Bangalore,', 'Bangalore'],
#  ['Near', 'Sagar', 'Hospital,', 'Tilak', 'Nagar,', 'Bangalore'],
#  ['Centrally',
#   'Located,',
#   'Near,',
#   'HMT',
#   'Layout',
#   'Bus',
#   'Stop,',
#   'R.T.Nagar,',
#   'Bangalore'],
#  ['Near', 'IIFT,', 'Vijayanagar,', 'Bangalore'],
#  ['Koramangala,', 'Bangalore'],
#  ['Bhuvanappa', 'Layout,', 'Bangalore'],
#  ['Jakkur', 'Plantation,', 'Bangalore'],
#  ['Hosapalya', 'Road,', 'Bangalore'],
#  ['56066,', 'Bangalore'],
#  ['Near', 'Maharaja', 'Signal,', 'Kormangala,', 'Bangalore'],
#  ['Near', 'Yeshwanthpur', ',', 'Sri', 'Raghavendra', 'Layout,', 'Bangalore'],
#  ['Near', 'Manyata', 'Tech', 'Park,Mesthri', 'Palya,', 'Bangalore'],
#  ['opposite',
#   'to',
#   'st',
#   'Joseph',
#   'high',
#   'school,',
#   'above',
#   'Just',
#   'bake',
#   'and',
#   'Apnaday',
#   'Market'],
#  ['5th',
#   'Main',
#   'K',
#   'C',
#   'Mallapa',
#   'Reddy',
#   'Layout',
#   'Kormangla,',
#   'Bangalore'],
#  ['Bangalore,', 'Bangalore'],
#  ['Sir', 'MVIT', 'College', 'Road,', 'Sonnapanahalli,', 'Bangalore'],
#  ['Behind',
#   'Manyata',
#   'Tech',
#   'Park',
#   'Gate',
#   'No.4,',
#   'Rachenahalli',
#   ',Bangalore'],
#  ['Dasarahalli,', 'Bangalore'],
#  ['Near', 'Vijaya', 'Bank,', 'Bidadi,', 'Bangalore'],
#  ['Near', 'Brand', 'Factory,', 'Bilekahalli,', 'Bangalore'],
#  ['Near', 'Apollo', 'Phaacy,', 'Mathikere', 'Main', 'Road,', 'Bangalore'],
#  ['Near', 'REVA', 'University,', 'Masjid', 'Road,', 'Kattigenahalli'],
#  ['Near', 'BGS', 'hospital,', 'Bangalore'],
#  ['Diagonally', 'Opp', 'Sri', 'Krishna', 'Nandagokula', 'Hotel,', 'Bangalore'],
#  ['5th', 'Stage,', 'Bangalore'],
#  ['Above', 'Vishal', 'Mega', 'mart'],
#  ['Chikkajala,', 'Bangalore'],
#  ['Kitthiganahalli,', 'Bangalore'],
#  ['Bangalore', 'Urban,', 'Bangalore'],
#  ['Arghar',
#   'Dasrahalli',
#   'Near',
#   'Madhu',
#   'Hospital',
#   'Opp',
#   'Maharaja',
#   'Tent',
#   'House',
#   'Reliance',
#   'Smart',
#   'Building',
#   'Magadi',
#   'Main',
#   'Road,',
#   'Bangalore'],
#  ['Near', 'Rammamurthynagar', 'Police', 'Station,', 'Bangalore'],
#  ['K', 'r', 'Puram,', 'Bangalore'],
#  ['Silver', 'Springs', 'Layout,', 'Bangalore'],
#  ['Near', 'Koramangala', 'Bus', 'Stand,', 'Bangalore'],
#  ['D', 'Group', 'Layout', 'Nagarbhavi,', 'Bangalore'],
#  ['Behind', 'Baptist', 'Hospital,', 'Hebbal'],
#  ['India,', 'Bangalore'],
#  ['Rajarajeshwari', 'Nagar', 'Zone,', 'Bangalore'],
#  ['Near', 'Thallasary', 'Restaurant,', 'Prasanth', 'Layout,', 'Bangalore'],
#  ['Mahadevapura', 'Zone,', 'Bangalore'],
#  ['Yelahanka', 'Zone,', 'Bangalore'],
#  ['Near', 'Indiranagar', 'Police', 'Station,', 'Indiranagar,', 'Bangalore'],
#  ['Bangalore', 'East,', 'Bangalore'],
#  ['Bangalore', 'Urban,', 'Bangalore'],
#  ['Huskur', 'Road,', 'Bangalore'],
#  ['West', 'Zone,', 'Bangalore'],
#  ['151,',
#   'Rachenahalli,',
#   'Manyata',
#   'Tech',
#   'Park,',
#   'Gate',
#   'No.5,',
#   'P&T',
#   'Layout,',
#   '7th',
#   'Cross,',
#   'Dr.SRK',
#   'Nagar',
#   'post,',
#   'Bangalore'],
#  ['Jnanabharthi,', 'Bangalore'],
#  ['Bangalore', 'Urban,', 'Bangalore'],
#  ['Near', 'Naryana', 'PU', 'college,', 'BEML', 'Layout,', 'Bangalore'],
#  ['560058,', 'Bangalore'],
#  ['Near', 'Dhobi', 'Ghat', 'junction,', 'Rajajinagar,', 'Bangalore'],
#  ['South,', 'Bangalore'],
#  ['Near', 'Jumma', 'masjid,', 'Shivaji', 'Nagar,', 'Bangalore'],
#  ['Rajajinagar,', 'Bangalore'],
#  ['Near', 'Ramamurthy', 'Nagar', 'Signal,', 'Bangalore,Karnataka'],
#  ['Domlur,', 'Bangalore'],
#  ['Near', 'Mosque', 'And', 'Above', 'Canara', 'Bank,', 'Bangalore'],
#  ['Near',
#   'Jeevika',
#   'Hospital,Outer',
#   'Ring',
#   'Road,',
#   'Marathahalli,',
#   'Bangalore'],
#  ['Halasuru,', 'Bangalore'],
#  ['opp', 'Raashi', 'Residency', 'Bangalore', 'Karnataka,', 'Bangalore'],
#  ['Rachenahalli',
#   'Main',
#   'Road',
#   'Beside',
#   'Manyata',
#   'Tech',
#   'Park',
#   'Gate',
#   '5,',
#   'Bangalore'],
#  ['Centrally',
#   'Located,',
#   'Near',
#   'Kalyan',
#   'Nagar',
#   'Bus',
#   'Stand,',
#   '1st',
#   'stage,',
#   'Bangalore'],
#  ['Whitefield,', 'Bangalore'],
#  ['Girinagar,', 'Bangalore'],
#  ['Near',
#   'Christ',
#   'University,',
#   'K',
#   'M',
#   'Jayaram',
#   'Complex,',
#   'Bangalore'],
#  ['Near', 'Sri', 'Balaji', 'medicals,', 'Zuzuvadi,', 'Bangalore'],
#  ['Near', 'BGS', 'Hospital,', 'Uttarahalli', 'Main', 'Road,', 'Bangalore'],
#  ['Near', 'Karnataka', 'Bank,', 'Babusapalya', 'Main', 'Road,', 'Bangalore'],
#  ['Near', 'BTM', 'Water', 'Tank,', 'Mico', 'Layout,', 'Bangalore'],
#  ['kumbalgodu', 'post,', 'Bangalore'],
#  ['Opposite', 'JP', 'Morgan,', 'Kadubeesanahalli,', 'Bangalore.'],
#  ['Rv', 'Layout,', 'Bangalore'],
#  ['Belathur', 'Main', 'Road,', 'Bangalore'],
#  ['Bangalore', 'Urban,', 'Bangalore'],
#  ['Near', 'Bengaluru', 'Airport,', 'Palya', 'Gate,', 'Bangalore'],
#  ['Near', 'MJ', 'infra,', 'singasamdra,', 'Bangalore'],
#  ['Near', 'Bsnl', 'Office,', 'Emerald', 'Residency,', 'Bangalore'],
#  ['Near', 'Quickr', 'Office,', 'P', '&', 'T', 'layout,', 'Bangalore'],
#  ['Outer', 'Ring', 'Road', 'Bangalore', 'KarnatakaIndia,', 'Bangalore'],
#  ['6th', 'Phase,', 'Bangalore'],
#  ['Amalodbhavi', 'Nagar', 'Bangalore', 'Karnatakaindia,', 'Bangalore'],
#  ['Shivaji', 'Nagar,', 'Bangalore'],
#  ['Near', 'Siddaganga', 'Mata,', 'Kythasandra,', 'Bangalore'],
#  ['Annaiah', 'Reddy', 'Layout', 'JP', 'Nagar,', 'Bangalore'],
#  ['Battarahalli,', 'Bangalore'],
#  ['Hosabasavanapura,', 'Bangalore'],
#  ['Near', 'Halasuru', 'Metro', 'Station,', 'Ulsoor,', 'Bangalore'],
#  ['National', 'Highway', '275,', 'Bangalore'],
#  ['Dasarahalli,', 'Bangalore'],
#  ['Bangalore', 'Urban,', 'Bangalore'],
#  ['Gruhalakshmi', 'Housing', 'Colony,', 'Bangalore'],
#  ['Near', 'Taj', 'Yeshwantpur,', 'M', 'S', 'K', 'Nagar,', 'Bangalore'],
#  ['Manyata', 'Tech', 'Park', 'Gate', 'Number', '4', 'Bangalore,', 'Bangalore'],
#  ['Near', "Teacher's", 'colony', 'Park,', 'Jakkasandra,', 'Bangalore'],
#  ['Near', 'Wipro', 'New', 'Office,', 'Kodathi,', 'Bengaluru'],
#  ['Kanakpura',
#   'main',
#   'road',
#   'metro',
#   'pillar',
#   'number',
#   '45',
#   'nearby',
#   'Banashankari',
#   'metro',
#   'station',
#   'JP',
#   'Nagar'],
#  ['Near', 'Indian', 'Bank,', 'Judicial', 'Layout,', 'Bangalore'],
#  ['Bangalore', 'Urban,', 'Bangalore'],
#  ['Centrally',
#   'Located,',
#   'Near',
#   'Sagar',
#   'Hospital,',
#   'Hombegowda',
#   'Nagar,',
#   'Bangalore'],
#  ['Bangalore,', 'Bangalore'],
#  ['Near', 'Forum', 'Mall,', 'Koramangala,', 'Bangalore'],
#  ['Near', 'VIVA', 'Toyota,', 'Hunasamaranahalli,', 'Bangalore'],
#  ['Near', 'Government', 'Hospital,', 'HBCS', 'Layout,', 'Bangalore'],
#  ['Near', 'CBI', 'Office,', 'Ganganagar,', 'Bangalore'],
#  ['Madiwala,',
#   'South',
#   'Zone,',
#   'Bengaluru,',
#   'Bangalore',
#   'South,',
#   'Bangalore',
#   'Urban,',
#   'Karnataka,',
#   '-',
#   '560034,',
#   'India',
#   'Bangalore.'],
#  ['Old',
#   'Madras',
#   'Road,',
#   'Near',
#   'TC',
#   'Palya',
#   'Signal',
#   'Kr',
#   'puram,',
#   'Bangalore'],
#  ['Near', 'Maha', 'Bazaar,', 'Mks', 'Square,', 'Bangalore'],
#  ['Kaggadasapura,', 'Bangalore'],
#  ['Mahadevapura', 'Zone,', 'Bangalore'],
#  ['Kiadb', 'Export', 'Promotion', 'Industrial', 'Area,', 'Bangalore'],
#  ['Bda', 'Layout', 'Btm', '4th', 'Stage,', 'Bangalore'],
#  ['India', 'Bangalore', 'Karnatakaindia560102,', 'Bangalore'],
#  ['Near', 'Perseverance', 'HBR,', 'Saint', 'Thomas', 'Town,', 'Bangalore'],
#  ['Bangalore', 'Urban,', 'Bangalore'],
#  ['Karnatakanull,', 'Bangalore'],
#  ['Bhuvaneswari', 'Nagar,', 'Bangalore'],
#  ['Near', 'PVR', 'Koramangala,', '7th', 'Block,', 'Bangalore'],
#  ['achenahalli',
#   'main',
#   'road',
#   'opp',
#   'to',
#   'Manayata',
#   'gate',
#   '5,',
#   'Bangalore'],
#  ['1ST', 'MAIN,', 'Bangalore'],
#  ['560016,', 'Bangalore'],
#  ['Near',
#   'kadugudi',
#   'post',
#   'office',
#   ',',
#   'Brindavan',
#   'Layout,',
#   'Bangalore'],
#  ['Btm', '2nd', 'Stage,', 'Bangalore'],
#  ['india,', 'Bangalore'],
#  ['14', 'cross', 'Hosur', 'Main', 'road,', 'Bangalore'],
#  ['Near',
#   'Sarvodaya',
#   'College',
#   'of',
#   'Nursing,',
#   'Magadi',
#   'Rd,',
#   'Bangalore'],
#  ['Bellandur,', 'Bangalore'],
#  ['INDIA-.,', 'Bangalore'],
#  ['Near', 'Karnataka', 'Bank,', 'Shanti', 'Nagar,', 'Bangalore'],
#  ['Near', 'Global', 'Tech', 'Park,', 'Rr', 'Nagar,', 'Bangalore'],
#  ['Bangalore', '-', ',', 'Bangalore'],
#  ['Krishnarajapura,', 'Bangalore'],
#  ['Near', 'Aet', 'College', 'Junction,', 'Gear', 'Road,', 'Bangalore'],
#  ['Near',
#   'Shantiniketan',
#   'Educational',
#   'Institute,',
#   'BTM',
#   'Layout,',
#   'Bnagalore'],
#  ['Near', 'Ejipura', 'Bus', 'stand,', 'Ashwini', 'Layout,', 'Bangalore'],
#  ['Centrally',
#   'Located,',
#   'Near',
#   'Shanti',
#   'Niketan',
#   'School,',
#   'Kodigehalli,',
#   'Bangalore'],
#  ['2nd', 'Main', 'Opp', 'Axis', 'Bank,', 'Bangalore'],
#  ['Near', 'Mantri', 'Square', 'Mall,', 'Sheshadripuram,', 'Bangalore'],
#  ['Marathahalli,', 'Bangalore'],
#  ['560', '036,', 'Bangalore'],
#  ['560029,', 'Bangalore'],
#  ['Near', 'ITPL', 'Main', 'Rd,', 'AECS', 'Layout,', 'Bengaluru'],
#  ['Centrally',
#   'Located,',
#   'Near',
#   'Liberty',
#   'Showroom,',
#   'Varthur',
#   'Road,',
#   'Bangalore'],
#  ['Near', 'Kalyan', 'silks', 'commercial', 'street,', 'Bangalore'],
#  ['Bangalore', 'Urban,', 'Bangalore'],
#  ['Near', 'Amrita', 'School', 'of', 'Engineering,', 'Bangalore'],
#  ['Koramangala,', 'Bangalore'],
#  ['Near', 'Manyatha', 'Tech', 'Park,', 'P', '&', 'T', 'Layout,', 'Bangalore'],
#  ['Near', 'Uttam', 'Sagar,', 'Banaswadi', 'main', 'road,', 'Bangalore'],
#  ['India', 'Bangalore', 'KarnatakaIndia,', 'Bangalore'],
#  ['Yelahanka', 'New', 'Town,', 'Bangalore'],
#  ['Near', 'Banaswadi', 'Police', 'Station,', 'Hrbr', 'Layout,', 'Bangalore'],
#  ['Bangalore', 'Karnataka,', 'Bangalore'],
#  ['Near', 'Mariyappa', 'Road,', 'Jayanagar', 'Ward,', 'Bangalore'],
#  ['Near', 'Adams', 'Creation,', 'Victoria', 'Layout,', 'Bangalore'],
#  ['Heggde', 'Nagar', 'Main', 'Gate,', 'Bangalore'],
#  ['India', 'Bangalore', 'Karnataka,', 'Bangalore'],
#  ['5th', 'Block,', 'Jayanagar,', 'Bangalore'],
#  ['Sarjapur', 'Road,', 'Bangalore'],
#  ['Near', 'MSO', 'Colony,', 'Maruthi', 'Seva', 'Nagar,', 'Bangalore'],
#  ['Near', 'Baldwin', 'Women', 'College,', 'Richmond', 'Town,', 'Bengaluru'],
#  ['Bangalore', 'South,', 'Bangalore'],
#  ['H', 's', 'r', 'Layout,', 'Bangalore'],
#  ['Bangalore', 'Urban,', 'Bangalore'],
#  ['Near', 'Eat', 'Street,', 'Kormangala,', 'Bangalore'],
#  ['Near',
#   'krishna',
#   'Theature',
#   'Bommanahalli,',
#   'Hosur',
#   'main',
#   'road,',
#   'Bangalore'],
#  ['Near', 'Domlur', 'Bridge,', 'Indiranagar,', 'Bangalore'],
#  ['Jeevan', 'Bhima', 'Nagar,', 'Bangalore'],
#  ['Near', 'Lane', '11,', 'Bengaluru,', 'Bangalore'],
#  ['Near', 'Nano', 'Hospital,', 'Bannerghatta', 'Road,', 'Bangalore'],
#  ['Nagarbhavi,', 'Bangalore'],
#  ['Near', 'HSR', 'Club,', 'Kadalda', 'Meen,', 'Bangalore'],
#  ['Hebbal,', 'Bangalore'],
#  ['Near', 'Old', 'Madras', 'Road,', 'KR', 'Puram,', 'Bangalore'],
#  ['Near', 'Vibgyor', 'School,', 'HSR', 'Layout,', 'Bangalore'],
#  ['Near', 'Doddakannelli,', 'Bangalore']]

# %%
City = []
for i in city:
    if i == "Bangalore":
        City.append(i)
    else:
        City.append("Bangalore")
City
# Out:
# ['Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore']

# %%
df1['City_Name']=City
df1
# Out:
#                                                 Hotels       Prices  \
# 0                               OYO 11915 Varcity Park  1158.000000
# 1    OYO Townhouse 385 Navya International Ramamurt...  1402.000000
# 2                             Capital O 12543 3 Square  1330.000000
# 3                             OYO 15358 Hotel Townhall   974.000000
# 4                              SPOT ON 65593 Yatra Inn  1088.000000
# ..                                                 ...          ...
# 251                       OYO Townhouse 049 HSR Layout  1276.369159
# 252                 OYO Flagship 702960 Ericon Comfort  1276.369159
# 253              Flagship 29620 New Champion Residency  1276.369159
# 254                       OYO Flagship 67007 Manyu Inn  1276.369159
# 255              OYO Townhouse 159 Sarjapur (Yo Stays)  1276.369159
#
#      Total_Price   Ratings  Booking_Discounts(%)      Reviews  \
# 0    4134.000000  4.134043             71.000000  2254.000000
# 1    5005.000000  4.134043             71.000000  1903.000000
# 2    4751.000000  4.134043             72.000000  1323.000000
# 3    3477.000000  4.134043             71.000000  1460.000000
# 4    3885.000000  4.134043             71.000000  2723.000000
# ..           ...       ...                   ...          ...
# 251  4141.593458  4.100000             68.626168  1253.000000
# 252  4141.593458  4.134043             68.626168   794.565574
# 253  4141.593458  4.134043             68.626168   611.000000
# 254  4141.593458  4.134043             68.626168   409.000000
# 255  4141.593458  4.000000             68.626168  1101.000000
#
#              Facilities                                          Address  \
# 0       Doctor on call            Near SV Hospitals, Madiwala, Bangalore
# 1      Electric Kettle   Near Rammamurthynagar Police Station, Bangalore
# 2             Elevator    Next to Cafe Coffee Day, HBR Layout, Bangalore
# 3     Parking facility         Near Dhanlakshmi Bank, JC Road, Bangalore
# 4            Reception                                Lalbagh, Bangalore
# ..                  ...                                              ...
# 251         Free Wi-Fi            Near HSR Club, Kadalda Meen, Bangalore
# 252           Elevator                                 Hebbal, Bangalore
# 253   Parking facility         Near Old Madras Road, KR Puram, Bangalore
# 254         Hair Dryer        Near Vibgyor School, HSR Layout, Bangalore
# 255     Doctor on call                     Near Doddakannelli, Bangalore
#
#                              Informations  City_Name
# 0      All staff vaccinated with 1st dose  Bangalore
# 1      All staff vaccinated with 1st dose  Bangalore
# 2      All staff vaccinated with 1st dose  Bangalore
# 3    All staff vaccinated with both doses  Bangalore
# 4        9 people booked this hotel today  Bangalore
# ..                                    ...        ...
# 251    All staff vaccinated with 1st dose  Bangalore
# 252                                   NaN  Bangalore
# 253    All staff vaccinated with 1st dose  Bangalore
# 254    All staff vaccinated with 1st dose  Bangalore
# 255    All staff vaccinated with 1st dose  Bangalore
#
# [256 rows x 10 columns]

# %%
df1.to_csv('Oyo Hotels Bangalore.csv',index=False)

# %%
df1 = pd.read_csv('Oyo Hotels Bangalore.csv')
df1
# Out:
#                                                 Hotels       Prices  \
# 0                               OYO 11915 Varcity Park  1158.000000
# 1    OYO Townhouse 385 Navya International Ramamurt...  1402.000000
# 2                             Capital O 12543 3 Square  1330.000000
# 3                             OYO 15358 Hotel Townhall   974.000000
# 4                              SPOT ON 65593 Yatra Inn  1088.000000
# ..                                                 ...          ...
# 251                       OYO Townhouse 049 HSR Layout  1276.369159
# 252                 OYO Flagship 702960 Ericon Comfort  1276.369159
# 253              Flagship 29620 New Champion Residency  1276.369159
# 254                       OYO Flagship 67007 Manyu Inn  1276.369159
# 255              OYO Townhouse 159 Sarjapur (Yo Stays)  1276.369159
#
#      Total_Price   Ratings  Booking_Discounts(%)      Reviews  \
# 0    4134.000000  4.134043             71.000000  2254.000000
# 1    5005.000000  4.134043             71.000000  1903.000000
# 2    4751.000000  4.134043             72.000000  1323.000000
# 3    3477.000000  4.134043             71.000000  1460.000000
# 4    3885.000000  4.134043             71.000000  2723.000000
# ..           ...       ...                   ...          ...
# 251  4141.593458  4.100000             68.626168  1253.000000
# 252  4141.593458  4.134043             68.626168   794.565574
# 253  4141.593458  4.134043             68.626168   611.000000
# 254  4141.593458  4.134043             68.626168   409.000000
# 255  4141.593458  4.000000             68.626168  1101.000000
#
#              Facilities                                          Address  \
# 0       Doctor on call            Near SV Hospitals, Madiwala, Bangalore
# 1      Electric Kettle   Near Rammamurthynagar Police Station, Bangalore
# 2             Elevator    Next to Cafe Coffee Day, HBR Layout, Bangalore
# 3     Parking facility         Near Dhanlakshmi Bank, JC Road, Bangalore
# 4            Reception                                Lalbagh, Bangalore
# ..                  ...                                              ...
# 251         Free Wi-Fi            Near HSR Club, Kadalda Meen, Bangalore
# 252           Elevator                                 Hebbal, Bangalore
# 253   Parking facility         Near Old Madras Road, KR Puram, Bangalore
# 254         Hair Dryer        Near Vibgyor School, HSR Layout, Bangalore
# 255     Doctor on call                     Near Doddakannelli, Bangalore
#
#                              Informations  City_Name
# 0      All staff vaccinated with 1st dose  Bangalore
# 1      All staff vaccinated with 1st dose  Bangalore
# 2      All staff vaccinated with 1st dose  Bangalore
# 3    All staff vaccinated with both doses  Bangalore
# 4        9 people booked this hotel today  Bangalore
# ..                                    ...        ...
# 251    All staff vaccinated with 1st dose  Bangalore
# 252                                   NaN  Bangalore
# 253    All staff vaccinated with 1st dose  Bangalore
# 254    All staff vaccinated with 1st dose  Bangalore
# 255    All staff vaccinated with 1st dose  Bangalore
#
# [256 rows x 10 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 256 entries, 0 to 255
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Hotels                256 non-null    object
#  1   Prices                256 non-null    float64
#  2   Total_Price           256 non-null    float64
#  3   Ratings               256 non-null    float64
#  4   Booking_Discounts(%)  256 non-null    float64
#  5   Reviews               256 non-null    float64
#  6   Facilities            253 non-null    object
#  7   Address               256 non-null    object
#  8   Informations          213 non-null    object
#  9   City_Name             256 non-null    object
# dtypes: float64(5), object(5)
# memory usage: 20.1+ KB

# %%
df1.shape
# Out:
# (256, 10)

# %%
df1.describe()
# Out:
#             Prices   Total_Price     Ratings  Booking_Discounts(%)  \
# count   256.000000    256.000000  256.000000            256.000000
# mean   1276.369159   4141.593458    4.134043             68.626168
# std     491.819056   1530.930202    0.057583              4.456365
# min     477.000000   1704.000000    4.000000             44.000000
# 25%     938.000000   3110.500000    4.134043             65.000000
# 50%    1276.369159   4141.593458    4.134043             71.000000
# 75%    1451.000000   4645.250000    4.134043             72.000000
# max    3775.000000  10785.000000    4.400000             79.000000
#
#            Reviews
# count   256.000000
# mean    794.565574
# std     722.843150
# min       1.000000
# 25%     231.250000
# 50%     665.000000
# 75%    1195.500000
# max    3987.000000

# %%
df1.corr()
# Out:
#                         Prices  Total_Price   Ratings  Booking_Discounts(%)  \
# Prices                1.000000     0.940737  0.025184             -0.222075
# Total_Price           0.940737     1.000000  0.025655              0.094708
# Ratings               0.025184     0.025655  1.000000             -0.007897
# Booking_Discounts(%) -0.222075     0.094708 -0.007897              1.000000
# Reviews               0.285341     0.338149  0.072717              0.096827
#
#                        Reviews
# Prices                0.285341
# Total_Price           0.338149
# Ratings               0.072717
# Booking_Discounts(%)  0.096827
# Reviews               1.000000

# %%
df1.Hotels.value_counts()
# Out:
# OYO 11915 Varcity Park                   2
# OYO Townhouse 238 Ulssor                 2
# Capital O 37517 Withinn Hotel            2
# OYO Townhouse 071 Brookfield             2
# OYO 75132 K N Residency                  2
#                                         ..
# OYO 28119 Omkar Global Inn               1
# SPOT ON 80165 S3 Comforts                1
# OYO Flagship 701999 Jj Home Stay         1
# Capital O 5683 Ss Suites                 1
# OYO Townhouse 159 Sarjapur (Yo Stays)    1
# Name: Hotels, Length: 242, dtype: int64

# %%
df1.duplicated().sum()
# Out:
# 13
