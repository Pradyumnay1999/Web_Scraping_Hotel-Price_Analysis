# %%
import numpy as np
import pandas as pd

# %%
import requests
from bs4 import BeautifulSoup
import time

# %%
url='https://www.oyorooms.com/search?location=Kolkata%2C%20West%20Bengal%2C%20India&city=Kolkata&searchType=city&coupon=&checkin=13%2F11%2F2022&checkout=14%2F11%2F2022&roomConfig%5B%5D=2&showSearchElements=false&guests=2&rooms=1&countryName=India&country=india&filters%5Bcity_id%5D=14'

# %%
page = requests.get(url, headers={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36'})
print(page.status_code)       #page = requests.get(url)
# Out:
# 200

# %%
pagecontent = page.text
pagecontent
# Out:
# '\n    <!doctype html>\n    <html lang="en" dir=ltr>\n    <head>\n      <meta charSet="utf-8" />\n      <meta httpEquiv="x-ua-compatible" content="ie=edge; chrome=1" />\n      <meta name="google-site-verification" content="lCkLu-7S0Eb5LOgDgmoWxSWzbopNfzKW01ZEe3ldsOc" />\n      <script type="text/javascript">\n      \twindow.renderingSource=\'server\'\n        var host = window.location.hostname;\n        if (!String.prototype.endsWith) {\n\t        String.prototype.endsWith = function(search, this_len) {\n\t\t        if (this_len === undefined || this_len > this.length) {\n\t\t\t        this_len = this.length;\n\t\t        }\n\t      \t  return this.substring(this_len - search.length, this_len) === search;\n\t        };\n        }\n        if (! (host.endsWith("oyorooms.com") || host.endsWith("oyorooms.ms") || host.endsWith("oyohotels.co.jp") || host.endsWith("hotelesoyo.com") || host.endsWith("oyohotels.com") || host.endsWith("belvilla.co.in") || host.endsWith("oyorooms.io")) && host.indexOf(\'localhost\') < 0){\n          window.location.href="https://www.oyorooms.com";\n        }\n        </script>\n      <meta httpEquiv="content-language" content="en-IN" />\n      <meta name="viewport" content="width=device-width, initial-scale=1.0, user-scalable=0, minimum-scale=1.0" />\n      \n      <meta name="full-screen" content="yes" />\n\n      <meta name="theme-color" content="#F5F5F5" />\n      <link rel="manifest" href="/manifest.json" />\n      <link rel="alternate" href="android-app://com.oyo.consumer/https/www.oyorooms.com/" />\n      <meta name="google" content="notranslate" />\n\n      <meta name="apple-mobile-web-app-capable" content="yes">\n      <meta name="mobile-web-app-capable" content="yes">\n\n\n      <link rel="preconnect" href="https://assets.oyoroomscdn.com" />\n      <link rel="preconnect" href="https://images.oyoroomscdn.com" />\n      <link rel="preconnect" href="https://cdn.moengage.com" />\n      <link rel="preconnect" href="https://www.google-analytics.com" />\n      <link rel="dns-prefetch" href="https://assets.oyoroomscdn.com" />\n      <link rel="dns-prefetch" href="https://images.oyoroomscdn.com" />\n      <link rel="dns-prefetch" href="https://cdn.moengage.com" />\n      <link rel="dns-prefetch" href="https://www.google-analytics.com" />\n      <link href=/assets/desktop/main.e953701e38dac851bad4.css rel="stylesheet" type="text/css" />\n      <link href=/assets/desktop/commoncss.4b11f9835e190a537f3c.css rel="stylesheet" type="text/css" />\n      <link href=/assets/desktop/listing.f60cc288d2f35137d287.css rel="stylesheet" type="text/css" />\n      <script type="text/javascript">\n          window.trackingId = "UA-52365165-1";\n          window.user_id = undefined || \'\';\n          (function(i,s,o,g,r,a,m){i[\'GoogleAnalyticsObject\']=r;i[r]=i[r]||function(){\n                      (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),\n                  m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)\n          })(window,document,\'script\',\'https://www.google-analytics.com/analytics.js\',\'ga\');\n          ga(\'create\', {\n              userId : window.user_id || \'\',\n              trackingId: window.trackingId,\n              cookieDomain: \'auto\',\n              siteSpeedSampleRate: 30,\n              useAmpClientId: true,\n              cookieFlags: "SameSite=None; Secure"\n          });\n          ga(\'require\',\'ec\');\n      </script>\n\n      <script type="application/ld+json">\n        {\n          "@context": "https://schema.org/",\n          "@type": "Organization",\n          "name": "OYO Rooms",\n          "url":"https://www.oyorooms.com/",\n          "logo":"https://www.oyorooms.com/favicon.ico",\n          "sameAs":["https://www.facebook.com/oyorooms", "https://twitter.com/oyorooms", "https://www.pinterest.com/oyorooms/", "https://plus.google.com/u/0/116027434827284400729/posts"],\n          "contactPoint":{\n            "@t ...

# %%
soup = BeautifulSoup(pagecontent)
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# <html dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="ie=edge; chrome=1" httpequiv="x-ua-compatible"/>
# <meta content="lCkLu-7S0Eb5LOgDgmoWxSWzbopNfzKW01ZEe3ldsOc" name="google-site-verification"/>
# <script type="text/javascript">
#       	window.renderingSource='server'
#         var host = window.location.hostname;
#         if (!String.prototype.endsWith) {
# 	        String.prototype.endsWith = function(search, this_len) {
# 		        if (this_len === undefined || this_len > this.length) {
# 			        this_len = this.length;
# 		        }
# 	      	  return this.substring(this_len - search.length, this_len) === search;
# 	        };
#         }
#         if (! (host.endsWith("oyorooms.com") || host.endsWith("oyorooms.ms") || host.endsWith("oyohotels.co.jp") || host.endsWith("hotelesoyo.com") || host.endsWith("oyohotels.com") || host.endsWith("belvilla.co.in") || host.endsWith("oyorooms.io")) && host.indexOf('localhost') < 0){
#           window.location.href="https://www.oyorooms.com";
#         }
#         </script>
# <meta content="en-IN" httpequiv="content-language"/>
# <meta content="width=device-width, initial-scale=1.0, user-scalable=0, minimum-scale=1.0" name="viewport"/>
# <meta content="yes" name="full-screen"/>
# <meta content="#F5F5F5" name="theme-color"/>
# <link href="/manifest.json" rel="manifest"/>
# <link href="android-app://com.oyo.consumer/https/www.oyorooms.com/" rel="alternate"/>
# <meta content="notranslate" name="google"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="yes" name="mobile-web-app-capable"/>
# <link href="https://assets.oyoroomscdn.com" rel="preconnect"/>
# <link href="https://images.oyoroomscdn.com" rel="preconnect"/>
# <link href="https://cdn.moengage.com" rel="preconnect"/>
# <link href="https://www.google-analytics.com" rel="preconnect"/>
# <link href="https://assets.oyoroomscdn.com" rel="dns-prefetch"/>
# <link href="https://images.oyoroomscdn.com" rel="dns-prefetch"/>
# <link href="https://cdn.moengage.com" rel="dns-prefetch"/>
# <link href="https://www.google-analytics.com" rel="dns-prefetch"/>
# <link href="/assets/desktop/main.e953701e38dac851bad4.css" rel="stylesheet" type="text/css"/>
# <link href="/assets/desktop/commoncss.4b11f9835e190a537f3c.css" rel="stylesheet" type="text/css"/>
# <link href="/assets/desktop/listing.f60cc288d2f35137d287.css" rel="stylesheet" type="text/css"/>
# <script type="text/javascript">
#           window.trackingId = "UA-52365165-1";
#           window.user_id = undefined || '';
#           (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#                       (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#                   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#           })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#           ga('create', {
#               userId : window.user_id || '',
#               trackingId: window.trackingId,
#               cookieDomain: 'auto',
#               siteSpeedSampleRate: 30,
#               useAmpClientId: true,
#               cookieFlags: "SameSite=None; Secure"
#           });
#           ga('require','ec');
#       </script>
# <script type="application/ld+json">
#         {
#           "@context": "https://schema.org/",
#           "@type": "Organization",
#           "name": "OYO Rooms",
#           "url":"https://www.oyorooms.com/",
#           "logo":"https://www.oyorooms.com/favicon.ico",
#           "sameAs":["https://www.facebook.com/oyorooms", "https://twitter.com/oyorooms", "https://www.pinterest.com/oyorooms/", "https://plus.google.com/u/0/116027434827284400729/posts"],
#           "contactPoint":{
#             "@type":"ContactPoint",
#             "telephone":"+91 9313 9313 93",
#             "contactType":"Customer Service"
#           }
#         }
#       </script>
# <title data-react-helmet="true">Hotels in Kolkata Starting @ ₹388 - Upto 84% OFF on 268 Kolkata Hotels</title>
# <meta content="https://www.facebook.com/oyorooms" data-react-helmet="true" property="og:publisher"/><meta content="/search/?location=Kolkata%2C%20West%20Bengal%2C%20India&amp;city=Kolkata&amp;searchType=city&amp;coupon=&amp;checkin=13%2F11%2F2022&amp;checkout=14%2F11%2F2022&amp;roomConfig%5B%5D=2&amp;showSearchElements=false&amp;guests=2&amp;rooms=1&amp;countryName=India&amp;country=india&amp;filters%5Bcity_id%5D=14" data-react-helmet="true" property="og:url"/><meta content="1576475359296300" data-react-helmet="true" property="fb:app_id"/><meta content="app" data-react-helmet="true" name="twitter:card"/><meta content="in" data-react-helmet="true" name="twitter:app:country"/><meta content="OYO Rooms" data-react-helmet="true" name="twitter:text:title"/><meta content="https://assets.oyoroomscdn.com/pwa/icons/oyo-logo-120x120.jpg" data-react-helmet="true" name="twitter:image"/><meta content="Book Hotels in Kolkata &amp; Save up to 84%, Price starts @₹388. OYO Promises &amp;#9989Complimentary Breakfast &amp;#9989Free Cancellation &amp;#9989Free WiFi &amp;#9989AC Room &amp;#9989Spotless linen &amp; &amp;#9989Clean Washrooms." data-react-helmet="true" name="description"/><meta content="OYO Rooms, OYO Hotels, OYO Inn, Budget Hotels, Guest House, Budget Hotels in Gurgaon, Guest House in Gurgaon, Budget Hotels in Delhi, Guest House in Delhi, Budget Hotels in Noida, Guest House in Noida, Budget Hotels in Bangalore, Guest House in Bangalore, Budget Hotels in Mumbai, Guest House in Mumbai, Cheap Hotels in Delhi, Cheap Hotels in Gurgaon, Cheap Hotels in Noida, Cheap Hotels in Bangalore, Cheap Hotels in Mumbai" data-react-helmet="true" name="keywords"/><meta content="Hotels in Kolkata Starting @ ₹388 - Upto 84% OFF on 268 Kolkata Hotels" data-react-helmet="true" property="og:title"/><meta content="Book Hotels in Kolkata &amp; Save up to 84%, Price starts @₹388. OYO Promises &amp;#9989Complimentary Breakfast &amp;#9989Free Cancellation &amp;#9989Free WiFi &amp;#9989AC Room &amp;#9989Spotless linen &amp; &amp;#9989Clean Washrooms." data-react-helmet="true" property="og:description"/><meta content="Hotels in Kolkata Starting @ ₹388 - Upto 84% OFF on 268 Kolkata Hotels" data-react-helmet="true" name="twitter:title"/><meta content="Book Hotels in Kolkata &amp; Save up to 84%, Price starts @₹388. OYO Promises &amp;#9989Complimentary Breakfast &amp;#9989Free Cancellation &amp;#9989Free WiFi &amp;#9989AC Room &amp;#9989Spotless linen &amp; &amp;#9989Clean Washrooms." data-react-helmet="true" name="twitter:description"/><meta content="OYO Rooms" data-react-helmet="true" property="og:site_name"/><meta content="https://images.oyoroomscdn.com/uploads/hotel_image/86693/d52130b9b182b49a.jpg" data-react-helmet="true" property="og:image"/><meta content="hotel" data-react-helmet="true" property="og:type"/><meta content="https://www.oyorooms.com/" data-react-helmet="true" name="twitter:url"/><meta content="NOINDEX, NOFOLLOW" data-react-helmet="true" name="ROBOTS"/><meta content="unavailable_after: Wednesday, 01-Jan-20 01:00:00 IST" data-react-helmet="true" name="robots"/>
# <link data-react-helmet="true" href="https://www.oyorooms.com/favicon.ico" rel="icon"/><link data-react-helmet="true" href="https://www.oyorooms.com/favicon.ico" rel="icon" sizes="48x48" type="image/x-icon"/><link data-react-helmet="true" href="https://assets.oyoroomscdn.com/pwa/icons/oyo-logo-48x48.jpg" rel="apple-touch-icon" sizes="48x48"/><link data-react-helmet="true" href="https://assets.oyoroomscdn.com/pwa/icons/oyo-logo-76x76.jpg" rel="apple-touch-icon" sizes="76x76"/><link data-react-helmet="true" href="https://assets.oyoroomscdn.com/pwa/icons/oyo-logo-120x120.jpg" rel="apple-touch-icon" sizes="120x120"/><link data-react-helmet="true" href="https://assets.oyoroomscdn.com/pwa/icons/oyo-logo-152x152.jpg" rel="apple-touch-icon" sizes="152x152"/><link data-react-helmet="true" href="/" rel="canonical"/>
# <link as="script" href="/assets/desktop/runtime.d4e4471e99372df5fcc3.js" rel="preload"/>
# <link as="script" href="/assets/desktop/externalvendor.1fd4612a45561d7117bb.js" rel="preload"/>
# <link as="script" href="/assets/desktop/common.cb6bb20e01d65d694f3a.js" rel="preload"/>
# <link as="script" href="/assets/desktop/commoncss.209925228a244e033ddd.js" rel="preload"/>
# <link as="script" href="/assets/desktop/listing.06b76248591c9a1458b8.js" rel="preload"/>
# <link as="script" href="/assets/desktop/main.6059aab2c8be16cb6f0a.js" rel="preload"/>
# </head>
# <body itemscope="" itemtype="http://schema.org/WebPage">
# <script type="text/javascript">
#             window.abExpConfig = {"sold":{"val":0,"v":1},"mww2":{"val":"1","v":"4"},"hbad":{"val":0,"v":1},"BnTc":{"val":0,"v":1},"near":{"val":0,"v":1},"ioab":{"val":"1","v":"2"},"mhdp":{"val":"1","v":"5"},"bcrp":{"val":"0","v":"5"},"pwbs":{"val":"1","v":"3"},"mwsb":{"val":0,"v":1},"slin":{"val":"1","v":"11"},"hsdm":{"val":"2","v":"2"},"lpex":{"val":0,"v":1},"lphv":{"val":0,"v":1},"dpcv":{"val":0,"v":1},"gmab":{"val":0,"v":1},"urhe":{"val":0,"v":1},"prdp":{"val":0,"v":1},"comp":{"val":"0","v":"5"},"sldw":{"val":0,"v":1},"mdab":{"val":0,"v":1},"nrmp":{"val":"1","v":"3"},"nhyw":{"val":"1","v":"1"},"wboi":{"val":0,"v":1},"sst":{"val":0,"v":1},"txwb":{"val":0,"v":1},"pod2":{"val":0,"v":1},"lnhd":{"val":0,"v":1},"ppsi":{"val":"0","v":"1"},"gcer":{"val":"0","v":"3"},"recs":{"val":"1","v":"1"},"swhp":{"val":0,"v":1},"lvhm":{"val":"1","v":"3"},"gmbr":{"val":"1","v":"15"},"yolo":{"val":"1","v":"6"},"rcta":{"val":"1","v":"3"},"cbot":{"val":"1","v":"5"},"otpv":{"val":"1","v":"7"},"trtr":{"val":0,"v":1},"lbhw":{"val":0,"v":1},"ndbp":{"val":"1","v":"2"},"mapu":{"val":"1","v":"3"},"nclc":{"val":"1","v":"5"},"dwsl":{"val":"1","v":"2"},"eopt":{"val":"1","v":"3"},"wizi":{"val":"1","v":"2"},"morr":{"val":"1","v":"2"},"yopb":{"val":"1","v":"3"},"TTP":{"val":"1","v":"4"},"Dweb":{"val":"1","v":1},"aimw":{"val":"1","v":"2"},"hdpn":{"val":"1","v":"4"},"web2":{"val":"0","v":"3"},"log2":{"val":"0","v":"3"},"spw1":{"val":0,"v":1},"strf":{"val":0,"v":1},"ugce":{"val":"0","v":"2"},"ltvr":{"val":"1","v":"4"},"hwiz":{"val":"0","v":"3"},"wizz":{"val":"1","v":"5"},"lpcp":{"val":"0","v":"2"},"clhp":{"val":"0","v":"2"},"prwt":{"val":"0","v":"2"},"cbhd":{"val":"0","v":"2"},"ins2":{"val":"2","v":"8"}};
#
#             // SW-INSTALLATION
#             (function() {
#               if ('serviceWorker' in navigator ) {
#                   window.addEventListener('load', function(){
#                     navigator.serviceWorker.register("/service-worker-desktop.js",{scope: "/"});
#                   });
#               }
#           })();
#         </script>
# <div id="root" style="height:100vh;"><style data-emotion-c="1acbpvw r9lts4 g49e0i 1iupfd9 s2hsb0 162c9d0 8ijf8a p2g0oj jj695s 1x32axc xotlao 1t05q14 mk5v0g bxjamc g7fw8n gcjisk qwx4r ml1sc2">@-webkit-keyframes animation-1acbpvw{0%{opacity:0;}100%{opacity:1;}}@keyframes animation-1acbpvw{0%{opacity:0;}100%{opacity:1;}}@-webkit-keyframes animation-r9lts4{0%{background-position:-350px 0;}100%{background-position:350px 0;}}@keyframes animation-r9lts4{0%{background-position:-350px 0;}100%{background-position:350px 0;}}@-webkit-keyframes animation-g49e0i{from{-webkit-transform:translate3d(0,-100 %,0);-ms-transform:translate3d(0,-100 %,0);transform:translate3d(0,-100 %,0);visibility:visible;}to{-webkit-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);transform:translate3d(0,0,0);}}@keyframes animation-g49e0i{from{-webkit-transform:translate3d(0,-100 %,0);-ms-transform:translate3d(0,-100 %,0);transform:translate3d(0,-100 %,0);visibility:visible;}to{-webkit-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);transform:translate3d(0,0,0);}}@-webkit-keyframes animation-1iupfd9{from{-webkit-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);transform:translate3d(0,0,0);}to{visibility:hidden;-webkit-transform:translate3d(0,-100 %,0);-ms-transform:translate3d(0,-100 %,0);transform:translate3d(0,-100 %,0);}}@keyframes animation-1iupfd9{from{-webkit-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);transform:translate3d(0,0,0);}to{visibility:hidden;-webkit-transform:translate3d(0,-100 %,0);-ms-transform:translate3d(0,-100 %,0);transform:translate3d(0,-100 %,0);}}@-webkit-keyframes animation-s2hsb0{from{-webkit-transform:translate3d(100 %,0,0);-ms-transform:translate3d(100 %,0,0);transform:translate3d(100 %,0,0);visibility:visible;}to{-webkit-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);transform:translate3d(0,0,0);}}@keyframes animation-s2hsb0{from{-webkit-transform:translate3d(100 %,0,0);-ms-transform:translate3d(100 %,0,0);transform:translate3d(100 %,0,0);visibility:visible;}to{-webkit-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);transform:translate3d(0,0,0);}}@-webkit-keyframes animation-162c9d0{from{-webkit-transform:translate3d(0,100 %,0);-ms-transform:translate3d(0,100 %,0);transform:translate3d(0,100 %,0);visibility:visible;}to{-webkit-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);transform:translate3d(0,0,0);}}@keyframes animation-162c9d0{from{-webkit-transform:translate3d(0,100 %,0);-ms-transform:translate3d(0,100 %,0);transform:translate3d(0,100 %,0);visibility:visible;}to{-webkit-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);transform:translate3d(0,0,0);}}@-webkit-keyframes animation-8ijf8a{from{-webkit-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);transform:translate3d(0,0,0);}to{visibility:hidden;-webkit-transform:translate3d(100 %,0,0);-ms-transform:translate3d(100 %,0,0);transform:translate3d(100 %,0,0);}}@keyframes animation-8ijf8a{from{-webkit-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);transform:translate3d(0,0,0);}to{visibility:hidden;-webkit-transform:translate3d(100 %,0,0);-ms-transform:translate3d(100 %,0,0);transform:translate3d(100 %,0,0);}}@-webkit-keyframes animation-p2g0oj{from{-webkit-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);transform:translate3d(0,0,0);opacity:0;}to{opacity:1;-webkit-transform:translate3d(0,100%,0);-ms-transform:translate3d(0,100%,0);transform:translate3d(0,100%,0);}}@keyframes animation-p2g0oj{from{-webkit-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);transform:translate3d(0,0,0);opacity:0;}to{opacity:1;-webkit-transform:translate3d(0,100%,0);-ms-transform:translate3d(0,100%,0);transform:translate3d(0,100%,0);}}@-webkit-keyframes animation-jj695s{0%{-webkit-transform:scale(1) translate3d(0,0,0);-ms-transform:scale(1) translate3d(0,0,0);transform:scale(1) translate3d(0,0,0);-webkit-transform-origin:50% 16%;-ms-transfo ...
# <script>
#           window.__PRELOADED_STATE__ = {"home":{"loading":true,"error":null,"data":[{"data":{"left_icons":[{"icon_name":"OyoIcon","icon_title":"","icon_description":"","cta":{"type":"","data":{"action_url":"/"}}}],"right_icons":[{"icon_name":"Text","icon_title":"About us","icon_description":"","cta":{"type":"","data":{"action_url":"https://www.oyorooms.com/about"}}},{"icon_name":"Text","icon_title":"Partner with us","icon_description":"","cta":{"type":"","data":{"action_url":"https://partner.oyorooms.com/?utm_campaign=dweb&utm_medium=dweb&utm_source=dweb"}}},{"icon_name":"TextWithBorder","icon_title":"Login","icon_description":"","show_sticky":true,"cta":{"type":"","data":{"action_url":"https://www.oyorooms.com/login?country=us&retUrl=/us"}}}],"search_data":{"hint":"Search for a city or hotel","show_near_me":true,"near_me_data":{"icon_name":"near me","icon_title":"Near me","icon_description":"","cta":{"type":"","data":{}}},"show_search_bar":true,"error_message":"Please enter your destination","show_sticky":true},"datepax_data":{"checkin_title":"Check-in","checkout_title":"Check-out","show_datepax_picker":true,"nights":"%sN","guest_title":"Rooms and guests","rooms_config":"1,0,0","date_title":"Date"},"search_button_cta":{"title":"Search"},"content_list":["search_data","datepax_data","search_button_cta"],"bgData":[{"media_url":"http://assets.oyoroomscdn.com/Homepageimagewithoverlay.png","media_type":"image"}],"tagLine":{"title":"You are on your way","sub_title":"Book hotels & homes in","sub_titles":["250+ locations","80+ Countries","3 Taps"]}},"id":3767,"type":"home_header_web","data_source":"inline"}],"loaded":false,"extra":false},"searchobj":{"location":"Kolkata, West Bengal, India","city":"kolkata","searchType":"city","tag":"","coupon":"","checkin":"13/11/2022","checkout":"14/11/2022","roomConfig":[2],"localityId":"","showSearchElements":false,"guests":2,"rooms":1,"countryName":"India","cityId":"14"},"deal":{"isFetching":true,"data":{},"error":""},"citiesByChar":{"isFetching":true,"data":{},"error":{}},"cities":{"count":195,"isFetching":true,"data":[{"name":"Agra","country_name":"India"},{"name":"Ahmedabad","country_name":"India"},{"name":"Ajmer","country_name":"India"},{"name":"Alappuzha","country_name":"India"},{"name":"Alibag","country_name":"India"},{"name":"Aligarh","country_name":"India"},{"name":"Allahabad","country_name":"India"},{"name":"Alwar","country_name":"India"},{"name":"Ambala","country_name":"India"},{"name":"Amritsar","country_name":"India"},{"name":"Anand","country_name":"India"},{"name":"Aurangabad","country_name":"India"},{"name":"Baddi","country_name":"India"},{"name":"Bangalore","country_name":"India"},{"name":"Bareilly","country_name":"India"},{"name":"Bathinda","country_name":"India"},{"name":"Behrampur","country_name":"India"},{"name":"Bhilai","country_name":"India"},{"name":"Bhilwara","country_name":"India"},{"name":"Bhiwadi","country_name":"India"},{"name":"Bhopal","country_name":"India"},{"name":"Bhubaneswar","country_name":"India"},{"name":"Bijainagar","country_name":"India"},{"name":"Bikaner","country_name":"India"},{"name":"Bilaspur","country_name":"India"},{"name":"Bodhgaya","country_name":"India"},{"name":"Calicut","country_name":"India"},{"name":"Cameron-Highlands","country_name":"Malaysia"},{"name":"Chandigarh","country_name":"India"},{"name":"Chennai","country_name":"India"},{"name":"Chikmagalur","country_name":"India"},{"name":"Chittorgarh","country_name":"India"},{"name":"Coimbatore","country_name":"India"},{"name":"Coonoor","country_name":"India"},{"name":"Coorg","country_name":"India"},{"name":"Corbett-Ramnagar","country_name":"India"},{"name":"Cuttack","country_name":"India"},{"name":"Dahej","country_name":"India"},{"name":"Dalhousie","country_name":"India"},{"name":"Daman","country_name":"India"},{"name":"Darjeeling","country_name":"India"},{"name":"Dehradun","country_name":"India"},{"name":"Delhi","country_name":"India"},{"name":"Dewas","country_name":"India"},{"name":"Dharamshala", ...
#         </script>
# <script>
#             window.__ROUTE_NAME__ = 'listing'
#         </script>
# <script src="/assets/desktop/runtime.d4e4471e99372df5fcc3.js"></script>
# <script src="/assets/desktop/externalvendor.1fd4612a45561d7117bb.js"></script>
# <script src="/assets/desktop/common.cb6bb20e01d65d694f3a.js"></script>
# <script src="/assets/desktop/commoncss.209925228a244e033ddd.js"></script>
# <script src="/assets/desktop/listing.06b76248591c9a1458b8.js"></script>
# <script src="/assets/desktop/main.6059aab2c8be16cb6f0a.js"></script>
# <noscript>
# <iframe height="0" src="http://www.googletagmanager.com/ns.html?id=GTM-PTZF36" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <script>
#         var prefetchExcludedList = [
#           '/assets/desktop/listing.06b76248591c9a1458b8.js'
#
#           ]
#           if (false){
#             prefetchExcludedList = [
#             '/assets/desktop/listing.b3cfc7a1b429e59faa40.v1.mjs'
#             ]
#           }
#           function script(url) {
#             if((url == "undefined") || (prefetchExcludedList.indexOf(url)>=0)){
#               return null;
#             }
#             var s = document.createElement('link');
#             s.rel = 'prefetch';
#             s.href = url;
#             var x = document.getElementsByTagName('head')[0];
#              //send simply
#             x.appendChild(s);
#           }
#           if (window.addEventListener) {
#               window.addEventListener('load', loadThirdPartyScript, false);
#           } else if (window.attachEvent) {
#               window.attachEvent('onload', loadThirdPartyScript);
#           }
#
#
#
#           function loadThirdPartyScript() {
#               var scriptNameArr = ["countryFlag","assist","home","newHome","listing","detail","bookingDetails","allcities","staticPage","wizard","wizardPlus","trust-and-safety","fourOfour","saveCard","postSaveCard","myBooking","unmarriedCouplesPage","accountDetails","deal","auth","SearchAffiliate","main","oyoforukraine","intl-id","intl-es","intl-ar","intl-vi","intl-hi","intl-pt","intl-ja","intl-th","intl-en","couponOffersPopup","PaymentWrapper/b","PaymentWrapper","authOld","yoImageUploadTemplate","sockjs","externalvendor","common","commoncss","","runtime"];
#               var isSWSupported = 'serviceWorker' in navigator;
#
#             //for other browsers
#             var legacyScriptsToLoad = [
#               '/assets/desktop/listing.06b76248591c9a1458b8.js',
#               '/assets/desktop/home.c75406d1d0c2d35f257d.js',
#               '/assets/desktop/detail.1314717f407dc8f9e11e.js',
#               ''
#             ]
#             for(var i=0 ; i<legacyScriptsToLoad.length;i++){
#                 !isSWSupported && script(legacyScriptsToLoad[i]);
#             }
#
#
#               // GTM
#               (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#               new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#               j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#               '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#               })(window,document,'script','dataLayer','GTM-PTZF36');
#
#               //Load moengage script
#               (function(i,s,o,g,r,a,m,n){
# 	          i['moengage_object']=r;t={}; q = function(f){return function(){(i['moengage_q']=i['moengage_q']||[]).push({f:f,a:arguments});};};
# 	          f = ['track_event','add_user_attribute','add_first_name','add_last_name','add_email','add_mobile',
# 	          'add_user_name','add_gender','add_birthday','destroy_session','add_unique_user_id','moe_events','call_web_push','track','location_type_attribute'];
# 	          for(k in f){t[f[k]]=q(f[k]);}
# 	          a=s.createElement(o);m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m);
# 	          i['moe']=i['moe'] || function(){n=arguments[0];return t;}; a.onload=function(){if(n){i[r] = moe(n);}};
# 	          })(window,document,'script','https://cdn.moengage.com/webpush/moe_webSdk.min.latest.js','Moengage');
# 	          Moengage = moe({
# 	            app_id:"MIJ2OM5MK5YSUOX8XMBAZJHD",
#               debug_logs: 0,
#               swPath: "/service-worker-desktop.js"
#             });
#           }
#         </script>
# </body>
# </html>>

# %%
HotelS = []
RatingS = []
ReviweS= []
PriceS = []
DiscountS=[]
Total_PriceS=[]
AmenitieS=[]
LocationS=[]
Information=[]


for i in range(1,30):
    start_time=time.time()
    url = 'https://www.oyorooms.com/search?location=Kolkata%2C%20West%20Bengal%2C%20India&city=Kolkata&searchType=city&coupon=&checkin=13%2F11%2F2022&checkout=14%2F11%2F2022&roomConfig%5B%5D=2&showSearchElements=false&guests=2&rooms=1&countryName=India&country=india&filters%5Bcity_id%5D=14&page={}'.format(i)
    page = requests.get(url, headers={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36'})
    pagecontent=page.text
    soup = BeautifulSoup(page.text)
    
    for x in soup.find_all('div', attrs = {'class': 'oyo-cell--12-col oyo-cell--8-col-tablet oyo-cell--4-col-phone'}):
        
        
        #Hotels
        
        hotel_name = x.find('h3', attrs = {'class': 'listingHotelDescription__hotelName d-textEllipsis'})
        
        if hotel_name is None:
            HotelS.append(np.NaN)
        else:
            HotelS.append(hotel_name.text)
            
        
        #Ratings
        
        Ratings = x.find('span', attrs = {'class': 'is-fontBold hotelRating__rating hotelRating__rating--verygood hotelRating__rating--clickable'})

        if Ratings is None:
            RatingS.append(np.NaN)
        else:
            RatingS.append(Ratings.text)   
      
        #Reviwes
        
        Reviwes = x.find('span', attrs = {'class': 'hotelRating__ratingSummary'})

        if Reviwes is None:
            
            ReviweS.append(np.NaN)
        else:
            ReviweS.append(Reviwes.text)   

        
        #Price
        
        price = x.find('span',attrs = {'class': 'listingPrice__finalPrice'})
        
        if price is None:
            PriceS.append(np.NaN)
        else:
            PriceS.append(price.text)


        
        #Discounts
        
        Discount_on_price = x.find('span',attrs = {'class': 'listingPrice__percentage'})
        
        if Discount_on_price is None:
            DiscountS.append(np.NaN)
        else:
            DiscountS.append(Discount_on_price.text)
        
        
         #Total_price
            
        Total_price = x.find('span',attrs = {'class': 'listingPrice__slashedPrice d-body-lg'})
        
        if Total_price is None:
            Total_PriceS.append(np.NaN)
        else:
            Total_PriceS.append(Total_price.text)
        
        #Amenities
        
        Amenities = x.find('span', attrs = {'class':'d-body-sm'})
        
        if Amenities is None:
            AmenitieS.append(np.NaN)
        else:
            AmenitieS.append(Amenities.text)
            
            
            
            
        #Location
        
        Location = x.find('div',attrs = {'class': 'd-body-lg listingHotelDescription__hotelAddress'})
        
        if Location is None:
            LocationS.append(np.NaN)
        else:
            LocationS.append(Location.text)
            
            
            
        #Information
        
        Info = x.find('div',attrs = {'class': 'c-1sugwtq'})
        
        if Info is None:
            Information.append(np.NaN)
        else:
            Information.append(Info.text)
            
            
    end_time = time.time()
    print('Page {} completed in {} seconds'. format(i, end_time-start_time))
# Out:
# Page 1 completed in 24.4348783493042 seconds
# Page 2 completed in 16.873433828353882 seconds
# Page 3 completed in 7.148456811904907 seconds
# Page 4 completed in 9.82576870918274 seconds
# Page 5 completed in 6.030953645706177 seconds
# Page 6 completed in 8.287374496459961 seconds
# Page 7 completed in 11.961612939834595 seconds
# Page 8 completed in 8.162399291992188 seconds
# Page 9 completed in 7.688265800476074 seconds
# Page 10 completed in 8.22495412826538 seconds
# Page 11 completed in 7.369750738143921 seconds
# Page 12 completed in 4.970282554626465 seconds
# Page 13 completed in 4.148661136627197 seconds
# Page 14 completed in 10.246036767959595 seconds
# Page 15 completed in 3.1698155403137207 seconds
# Page 16 completed in 3.2718257904052734 seconds
# Page 17 completed in 3.1843507289886475 seconds
# Page 18 completed in 3.026611089706421 seconds
# Page 19 completed in 3.064754009246826 seconds
# Page 20 completed in 3.49027156829834 seconds
# Page 21 completed in 4.175285577774048 seconds
# Page 22 completed in 8.414027690887451 seconds
# Page 23 completed in 5.9092607498168945 seconds
# Page 24 completed in 5.098705291748047 seconds
# Page 25 completed in 4.807533025741577 seconds
# Page 26 completed in 3.185136318206787 seconds
# Page 27 completed in 3.260305643081665 seconds
# Page 28 completed in 3.3605356216430664 seconds
# Page 29 completed in 11.05379056930542 seconds

# %%
print(len(HotelS))
print(len(RatingS))
print(len(PriceS))
print(len(Total_PriceS))
print(len(DiscountS))
print(len(AmenitieS))
print(len(LocationS))
print(len(Information))
print(len(ReviweS))
# Out:
# 268
# 268
# 268
# 268
# 268
# 268
# 268
# 268
# 268

# %%
df1 = pd.DataFrame({'Hotels':HotelS,
                    'Prices':PriceS,
                    'Total_Price':Total_PriceS,
                    'Ratings':RatingS,
                    'Booking_Discounts(%)':DiscountS,
                    'Reviews':ReviweS,
                    'Facilities':AmenitieS,
                    'Address':LocationS,
                    'Informations':Information})
df1
# Out:
#                                                 Hotels Prices Total_Price  \
# 0                                     OYO 11368 Dk Inn  ₹1600       ₹5714
# 1                 Townhouse Oak Hotel Lake View Royal   ₹1133       ₹4045
# 2             Flagship 701196 Sonar Bangla Guest House   ₹599       ₹2261
# 3                     Capital O 700752 Hotel Dak Plaza   ₹634       ₹2262
# 4                 Flagship 700875 Shyamali Guest House   ₹625       ₹2232
# ..                                                 ...    ...         ...
# 263                  Flagship 13524 Swapan Guest House    NaN         NaN
# 264               OYO Townhouse 727 Hotel The Platinum    NaN         NaN
# 265                   Flagship 9662 Kajali Guest House    NaN         NaN
# 266  OYO Flagship 702311 Bigboss Hotel & Restaurant...    NaN         NaN
# 267                 OYO Townhouse 567 MB International    NaN         NaN
#
#     Ratings Booking_Discounts(%)         Reviews          Facilities  \
# 0       NaN              72% off  (1767 Ratings)           Elevator
# 1      4.2               71% off   (166 Ratings)          Reception
# 2       NaN              73% off   (158 Ratings)         Free Wi-Fi
# 3       NaN              71% off   (318 Ratings)          Reception
# 4       NaN              72% off    (53 Ratings)           Elevator
# ..      ...                  ...             ...                 ...
# 263     NaN                  NaN   (348 Ratings)         Free Wi-Fi
# 264     NaN                  NaN  (1738 Ratings)   Parking facility
# 265     NaN                  NaN    (43 Ratings)         Free Wi-Fi
# 266     NaN                  NaN             NaN                 AC
# 267     NaN                  NaN  (1845 Ratings)   Parking facility
#
#                                                Address  \
# 0              Near Deshapriya Park, Kalighat, Kolkata
# 1                            East Topsia Road, Kolkata
# 2                             Near Gst Bhawan, Kolkata
# 3    Near Axis Mall, CE Block, Newtown, Kolkata 700156
# 4                   72/1, Jessore road, Kolkata 700124
# ..                                                 ...
# 263                         Cl Block Saltlake, Kolkata
# 264                                  Sector-1, Kolkata
# 265                     Near Bosepukur, Kasba, Kolkata
# 266          Ayeshpur Near flipkart warehouse, Kolkata
# 267                                Beniapukur, Kolkata
#
#                                      Informations
# 0              All staff vaccinated with 1st dose
# 1     14 people booked this hotel in last 6 hours
# 2                        Hurry, Only 1 room left!
# 3      6 people booked this hotel in last 6 hours
# 4                                             NaN
# ..                                            ...
# 263  700+ people booked this OYO in last 6 months
# 264            All staff vaccinated with 1st dose
# 265                                           NaN
# 266                                           NaN
# 267   11 people booked this hotel in last 6 hours
#
# [268 rows x 9 columns]

# %%
df1.duplicated().sum()
# Out:
# 13

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 268 entries, 0 to 267
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Hotels                268 non-null    object
#  1   Prices                210 non-null    object
#  2   Total_Price           210 non-null    object
#  3   Ratings               59 non-null     object
#  4   Booking_Discounts(%)  210 non-null    object
#  5   Reviews               245 non-null    object
#  6   Facilities            268 non-null    object
#  7   Address               268 non-null    object
#  8   Informations          154 non-null    object
# dtypes: object(9)
# memory usage: 19.0+ KB

# %%
df1['Prices'] = df1['Prices'].astype(str)

# %%
df1['Prices'] = df1['Prices'].apply(lambda x: x.replace('NaN','0000'))

# %%
df1['Prices'] = df1['Prices'].apply(lambda x: x.replace('₹',''))

# %%
df1['Prices'] = df1['Prices'].astype(float)

# %%
df1['Prices'].fillna(df1['Prices'].mean(), inplace = True)

# %%
df1
# Out:
#                                                 Hotels       Prices  \
# 0                                     OYO 11368 Dk Inn  1600.000000
# 1                 Townhouse Oak Hotel Lake View Royal   1133.000000
# 2             Flagship 701196 Sonar Bangla Guest House   599.000000
# 3                     Capital O 700752 Hotel Dak Plaza   634.000000
# 4                 Flagship 700875 Shyamali Guest House   625.000000
# ..                                                 ...          ...
# 263                  Flagship 13524 Swapan Guest House  1092.452381
# 264               OYO Townhouse 727 Hotel The Platinum  1092.452381
# 265                   Flagship 9662 Kajali Guest House  1092.452381
# 266  OYO Flagship 702311 Bigboss Hotel & Restaurant...  1092.452381
# 267                 OYO Townhouse 567 MB International  1092.452381
#
#     Total_Price Ratings Booking_Discounts(%)         Reviews  \
# 0         ₹5714     NaN              72% off  (1767 Ratings)
# 1         ₹4045    4.2               71% off   (166 Ratings)
# 2         ₹2261     NaN              73% off   (158 Ratings)
# 3         ₹2262     NaN              71% off   (318 Ratings)
# 4         ₹2232     NaN              72% off    (53 Ratings)
# ..          ...     ...                  ...             ...
# 263         NaN     NaN                  NaN   (348 Ratings)
# 264         NaN     NaN                  NaN  (1738 Ratings)
# 265         NaN     NaN                  NaN    (43 Ratings)
# 266         NaN     NaN                  NaN             NaN
# 267         NaN     NaN                  NaN  (1845 Ratings)
#
#              Facilities                                            Address  \
# 0             Elevator             Near Deshapriya Park, Kalighat, Kolkata
# 1            Reception                           East Topsia Road, Kolkata
# 2           Free Wi-Fi                            Near Gst Bhawan, Kolkata
# 3            Reception   Near Axis Mall, CE Block, Newtown, Kolkata 700156
# 4             Elevator                  72/1, Jessore road, Kolkata 700124
# ..                  ...                                                ...
# 263         Free Wi-Fi                          Cl Block Saltlake, Kolkata
# 264   Parking facility                                   Sector-1, Kolkata
# 265         Free Wi-Fi                      Near Bosepukur, Kasba, Kolkata
# 266                 AC           Ayeshpur Near flipkart warehouse, Kolkata
# 267   Parking facility                                 Beniapukur, Kolkata
#
#                                      Informations
# 0              All staff vaccinated with 1st dose
# 1     14 people booked this hotel in last 6 hours
# 2                        Hurry, Only 1 room left!
# 3      6 people booked this hotel in last 6 hours
# 4                                             NaN
# ..                                            ...
# 263  700+ people booked this OYO in last 6 months
# 264            All staff vaccinated with 1st dose
# 265                                           NaN
# 266                                           NaN
# 267   11 people booked this hotel in last 6 hours
#
# [268 rows x 9 columns]

# %%
df1['Total_Price'] = df1['Total_Price'].astype(str)

# %%
df1['Total_Price'] = df1['Total_Price'].apply(lambda x: x.replace('NaN','0000'))

# %%
df1['Total_Price'] = df1['Total_Price'].apply(lambda x: x.replace('₹',''))

# %%
df1['Total_Price'] = df1['Total_Price'].astype(float)

# %%
df1['Total_Price'].fillna(df1['Total_Price'].mean(), inplace = True)

# %%
df1
# Out:
#                                                 Hotels       Prices  \
# 0                                     OYO 11368 Dk Inn  1600.000000
# 1                 Townhouse Oak Hotel Lake View Royal   1133.000000
# 2             Flagship 701196 Sonar Bangla Guest House   599.000000
# 3                     Capital O 700752 Hotel Dak Plaza   634.000000
# 4                 Flagship 700875 Shyamali Guest House   625.000000
# ..                                                 ...          ...
# 263                  Flagship 13524 Swapan Guest House  1092.452381
# 264               OYO Townhouse 727 Hotel The Platinum  1092.452381
# 265                   Flagship 9662 Kajali Guest House  1092.452381
# 266  OYO Flagship 702311 Bigboss Hotel & Restaurant...  1092.452381
# 267                 OYO Townhouse 567 MB International  1092.452381
#
#      Total_Price Ratings Booking_Discounts(%)         Reviews  \
# 0    5714.000000     NaN              72% off  (1767 Ratings)
# 1    4045.000000    4.2               71% off   (166 Ratings)
# 2    2261.000000     NaN              73% off   (158 Ratings)
# 3    2262.000000     NaN              71% off   (318 Ratings)
# 4    2232.000000     NaN              72% off    (53 Ratings)
# ..           ...     ...                  ...             ...
# 263  3492.885714     NaN                  NaN   (348 Ratings)
# 264  3492.885714     NaN                  NaN  (1738 Ratings)
# 265  3492.885714     NaN                  NaN    (43 Ratings)
# 266  3492.885714     NaN                  NaN             NaN
# 267  3492.885714     NaN                  NaN  (1845 Ratings)
#
#              Facilities                                            Address  \
# 0             Elevator             Near Deshapriya Park, Kalighat, Kolkata
# 1            Reception                           East Topsia Road, Kolkata
# 2           Free Wi-Fi                            Near Gst Bhawan, Kolkata
# 3            Reception   Near Axis Mall, CE Block, Newtown, Kolkata 700156
# 4             Elevator                  72/1, Jessore road, Kolkata 700124
# ..                  ...                                                ...
# 263         Free Wi-Fi                          Cl Block Saltlake, Kolkata
# 264   Parking facility                                   Sector-1, Kolkata
# 265         Free Wi-Fi                      Near Bosepukur, Kasba, Kolkata
# 266                 AC           Ayeshpur Near flipkart warehouse, Kolkata
# 267   Parking facility                                 Beniapukur, Kolkata
#
#                                      Informations
# 0              All staff vaccinated with 1st dose
# 1     14 people booked this hotel in last 6 hours
# 2                        Hurry, Only 1 room left!
# 3      6 people booked this hotel in last 6 hours
# 4                                             NaN
# ..                                            ...
# 263  700+ people booked this OYO in last 6 months
# 264            All staff vaccinated with 1st dose
# 265                                           NaN
# 266                                           NaN
# 267   11 people booked this hotel in last 6 hours
#
# [268 rows x 9 columns]

# %%
df1['Ratings'] = df1['Ratings'].astype(str)

# %%
df1['Ratings'] = df1['Ratings'].apply(lambda x: x.replace('NaN','0000'))

# %%
df1['Ratings'] = df1['Ratings'].astype(float)

# %%
df1['Ratings'].fillna(df1['Ratings'].mean(), inplace = True)

# %%
df1
# Out:
#                                                 Hotels       Prices  \
# 0                                     OYO 11368 Dk Inn  1600.000000
# 1                 Townhouse Oak Hotel Lake View Royal   1133.000000
# 2             Flagship 701196 Sonar Bangla Guest House   599.000000
# 3                     Capital O 700752 Hotel Dak Plaza   634.000000
# 4                 Flagship 700875 Shyamali Guest House   625.000000
# ..                                                 ...          ...
# 263                  Flagship 13524 Swapan Guest House  1092.452381
# 264               OYO Townhouse 727 Hotel The Platinum  1092.452381
# 265                   Flagship 9662 Kajali Guest House  1092.452381
# 266  OYO Flagship 702311 Bigboss Hotel & Restaurant...  1092.452381
# 267                 OYO Townhouse 567 MB International  1092.452381
#
#      Total_Price   Ratings Booking_Discounts(%)         Reviews  \
# 0    5714.000000  4.147458              72% off  (1767 Ratings)
# 1    4045.000000  4.200000              71% off   (166 Ratings)
# 2    2261.000000  4.147458              73% off   (158 Ratings)
# 3    2262.000000  4.147458              71% off   (318 Ratings)
# 4    2232.000000  4.147458              72% off    (53 Ratings)
# ..           ...       ...                  ...             ...
# 263  3492.885714  4.147458                  NaN   (348 Ratings)
# 264  3492.885714  4.147458                  NaN  (1738 Ratings)
# 265  3492.885714  4.147458                  NaN    (43 Ratings)
# 266  3492.885714  4.147458                  NaN             NaN
# 267  3492.885714  4.147458                  NaN  (1845 Ratings)
#
#              Facilities                                            Address  \
# 0             Elevator             Near Deshapriya Park, Kalighat, Kolkata
# 1            Reception                           East Topsia Road, Kolkata
# 2           Free Wi-Fi                            Near Gst Bhawan, Kolkata
# 3            Reception   Near Axis Mall, CE Block, Newtown, Kolkata 700156
# 4             Elevator                  72/1, Jessore road, Kolkata 700124
# ..                  ...                                                ...
# 263         Free Wi-Fi                          Cl Block Saltlake, Kolkata
# 264   Parking facility                                   Sector-1, Kolkata
# 265         Free Wi-Fi                      Near Bosepukur, Kasba, Kolkata
# 266                 AC           Ayeshpur Near flipkart warehouse, Kolkata
# 267   Parking facility                                 Beniapukur, Kolkata
#
#                                      Informations
# 0              All staff vaccinated with 1st dose
# 1     14 people booked this hotel in last 6 hours
# 2                        Hurry, Only 1 room left!
# 3      6 people booked this hotel in last 6 hours
# 4                                             NaN
# ..                                            ...
# 263  700+ people booked this OYO in last 6 months
# 264            All staff vaccinated with 1st dose
# 265                                           NaN
# 266                                           NaN
# 267   11 people booked this hotel in last 6 hours
#
# [268 rows x 9 columns]

# %%
df1['Booking_Discounts(%)'] = df1['Booking_Discounts(%)'].str.replace('\D+','')
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_3960\2563500470.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df1['Booking_Discounts(%)'] = df1['Booking_Discounts(%)'].str.replace('\D+','')

# %%
df1['Booking_Discounts(%)']=df1['Booking_Discounts(%)'].astype(float)

# %%
df1['Booking_Discounts(%)'].fillna(df1['Booking_Discounts(%)'].mean(),inplace=True)

# %%
df1
# Out:
#                                                 Hotels       Prices  \
# 0                                     OYO 11368 Dk Inn  1600.000000
# 1                 Townhouse Oak Hotel Lake View Royal   1133.000000
# 2             Flagship 701196 Sonar Bangla Guest House   599.000000
# 3                     Capital O 700752 Hotel Dak Plaza   634.000000
# 4                 Flagship 700875 Shyamali Guest House   625.000000
# ..                                                 ...          ...
# 263                  Flagship 13524 Swapan Guest House  1092.452381
# 264               OYO Townhouse 727 Hotel The Platinum  1092.452381
# 265                   Flagship 9662 Kajali Guest House  1092.452381
# 266  OYO Flagship 702311 Bigboss Hotel & Restaurant...  1092.452381
# 267                 OYO Townhouse 567 MB International  1092.452381
#
#      Total_Price   Ratings  Booking_Discounts(%)         Reviews  \
# 0    5714.000000  4.147458             72.000000  (1767 Ratings)
# 1    4045.000000  4.200000             71.000000   (166 Ratings)
# 2    2261.000000  4.147458             73.000000   (158 Ratings)
# 3    2262.000000  4.147458             71.000000   (318 Ratings)
# 4    2232.000000  4.147458             72.000000    (53 Ratings)
# ..           ...       ...                   ...             ...
# 263  3492.885714  4.147458             68.314286   (348 Ratings)
# 264  3492.885714  4.147458             68.314286  (1738 Ratings)
# 265  3492.885714  4.147458             68.314286    (43 Ratings)
# 266  3492.885714  4.147458             68.314286             NaN
# 267  3492.885714  4.147458             68.314286  (1845 Ratings)
#
#              Facilities                                            Address  \
# 0             Elevator             Near Deshapriya Park, Kalighat, Kolkata
# 1            Reception                           East Topsia Road, Kolkata
# 2           Free Wi-Fi                            Near Gst Bhawan, Kolkata
# 3            Reception   Near Axis Mall, CE Block, Newtown, Kolkata 700156
# 4             Elevator                  72/1, Jessore road, Kolkata 700124
# ..                  ...                                                ...
# 263         Free Wi-Fi                          Cl Block Saltlake, Kolkata
# 264   Parking facility                                   Sector-1, Kolkata
# 265         Free Wi-Fi                      Near Bosepukur, Kasba, Kolkata
# 266                 AC           Ayeshpur Near flipkart warehouse, Kolkata
# 267   Parking facility                                 Beniapukur, Kolkata
#
#                                      Informations
# 0              All staff vaccinated with 1st dose
# 1     14 people booked this hotel in last 6 hours
# 2                        Hurry, Only 1 room left!
# 3      6 people booked this hotel in last 6 hours
# 4                                             NaN
# ..                                            ...
# 263  700+ people booked this OYO in last 6 months
# 264            All staff vaccinated with 1st dose
# 265                                           NaN
# 266                                           NaN
# 267   11 people booked this hotel in last 6 hours
#
# [268 rows x 9 columns]

# %%
df1['Reviews'] = df1['Reviews'].str.replace('\D+','')
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_3960\629340285.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df1['Reviews'] = df1['Reviews'].str.replace('\D+','')

# %%
df1['Reviews']=df1['Reviews'].astype(float)

# %%
df1['Reviews'].fillna(df1['Reviews'].mean(),inplace=True)

# %%
df1
# Out:
#                                                 Hotels       Prices  \
# 0                                     OYO 11368 Dk Inn  1600.000000
# 1                 Townhouse Oak Hotel Lake View Royal   1133.000000
# 2             Flagship 701196 Sonar Bangla Guest House   599.000000
# 3                     Capital O 700752 Hotel Dak Plaza   634.000000
# 4                 Flagship 700875 Shyamali Guest House   625.000000
# ..                                                 ...          ...
# 263                  Flagship 13524 Swapan Guest House  1092.452381
# 264               OYO Townhouse 727 Hotel The Platinum  1092.452381
# 265                   Flagship 9662 Kajali Guest House  1092.452381
# 266  OYO Flagship 702311 Bigboss Hotel & Restaurant...  1092.452381
# 267                 OYO Townhouse 567 MB International  1092.452381
#
#      Total_Price   Ratings  Booking_Discounts(%)      Reviews  \
# 0    5714.000000  4.147458             72.000000  1767.000000
# 1    4045.000000  4.200000             71.000000   166.000000
# 2    2261.000000  4.147458             73.000000   158.000000
# 3    2262.000000  4.147458             71.000000   318.000000
# 4    2232.000000  4.147458             72.000000    53.000000
# ..           ...       ...                   ...          ...
# 263  3492.885714  4.147458             68.314286   348.000000
# 264  3492.885714  4.147458             68.314286  1738.000000
# 265  3492.885714  4.147458             68.314286    43.000000
# 266  3492.885714  4.147458             68.314286   787.530612
# 267  3492.885714  4.147458             68.314286  1845.000000
#
#              Facilities                                            Address  \
# 0             Elevator             Near Deshapriya Park, Kalighat, Kolkata
# 1            Reception                           East Topsia Road, Kolkata
# 2           Free Wi-Fi                            Near Gst Bhawan, Kolkata
# 3            Reception   Near Axis Mall, CE Block, Newtown, Kolkata 700156
# 4             Elevator                  72/1, Jessore road, Kolkata 700124
# ..                  ...                                                ...
# 263         Free Wi-Fi                          Cl Block Saltlake, Kolkata
# 264   Parking facility                                   Sector-1, Kolkata
# 265         Free Wi-Fi                      Near Bosepukur, Kasba, Kolkata
# 266                 AC           Ayeshpur Near flipkart warehouse, Kolkata
# 267   Parking facility                                 Beniapukur, Kolkata
#
#                                      Informations
# 0              All staff vaccinated with 1st dose
# 1     14 people booked this hotel in last 6 hours
# 2                        Hurry, Only 1 room left!
# 3      6 people booked this hotel in last 6 hours
# 4                                             NaN
# ..                                            ...
# 263  700+ people booked this OYO in last 6 months
# 264            All staff vaccinated with 1st dose
# 265                                           NaN
# 266                                           NaN
# 267   11 people booked this hotel in last 6 hours
#
# [268 rows x 9 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 268 entries, 0 to 267
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Hotels                268 non-null    object
#  1   Prices                268 non-null    float64
#  2   Total_Price           268 non-null    float64
#  3   Ratings               268 non-null    float64
#  4   Booking_Discounts(%)  268 non-null    float64
#  5   Reviews               268 non-null    float64
#  6   Facilities            268 non-null    object
#  7   Address               268 non-null    object
#  8   Informations          154 non-null    object
# dtypes: float64(5), object(4)
# memory usage: 19.0+ KB

# %%
df1["City_Name"] = df1['Address'].apply(lambda x: x.split(',')[-1])
df1
# Out:
#                                                 Hotels       Prices  \
# 0                                     OYO 11368 Dk Inn  1600.000000
# 1                 Townhouse Oak Hotel Lake View Royal   1133.000000
# 2             Flagship 701196 Sonar Bangla Guest House   599.000000
# 3                     Capital O 700752 Hotel Dak Plaza   634.000000
# 4                 Flagship 700875 Shyamali Guest House   625.000000
# ..                                                 ...          ...
# 263                  Flagship 13524 Swapan Guest House  1092.452381
# 264               OYO Townhouse 727 Hotel The Platinum  1092.452381
# 265                   Flagship 9662 Kajali Guest House  1092.452381
# 266  OYO Flagship 702311 Bigboss Hotel & Restaurant...  1092.452381
# 267                 OYO Townhouse 567 MB International  1092.452381
#
#      Total_Price   Ratings  Booking_Discounts(%)      Reviews  \
# 0    5714.000000  4.147458             72.000000  1767.000000
# 1    4045.000000  4.200000             71.000000   166.000000
# 2    2261.000000  4.147458             73.000000   158.000000
# 3    2262.000000  4.147458             71.000000   318.000000
# 4    2232.000000  4.147458             72.000000    53.000000
# ..           ...       ...                   ...          ...
# 263  3492.885714  4.147458             68.314286   348.000000
# 264  3492.885714  4.147458             68.314286  1738.000000
# 265  3492.885714  4.147458             68.314286    43.000000
# 266  3492.885714  4.147458             68.314286   787.530612
# 267  3492.885714  4.147458             68.314286  1845.000000
#
#              Facilities                                            Address  \
# 0             Elevator             Near Deshapriya Park, Kalighat, Kolkata
# 1            Reception                           East Topsia Road, Kolkata
# 2           Free Wi-Fi                            Near Gst Bhawan, Kolkata
# 3            Reception   Near Axis Mall, CE Block, Newtown, Kolkata 700156
# 4             Elevator                  72/1, Jessore road, Kolkata 700124
# ..                  ...                                                ...
# 263         Free Wi-Fi                          Cl Block Saltlake, Kolkata
# 264   Parking facility                                   Sector-1, Kolkata
# 265         Free Wi-Fi                      Near Bosepukur, Kasba, Kolkata
# 266                 AC           Ayeshpur Near flipkart warehouse, Kolkata
# 267   Parking facility                                 Beniapukur, Kolkata
#
#                                      Informations        City_Name
# 0              All staff vaccinated with 1st dose          Kolkata
# 1     14 people booked this hotel in last 6 hours          Kolkata
# 2                        Hurry, Only 1 room left!          Kolkata
# 3      6 people booked this hotel in last 6 hours   Kolkata 700156
# 4                                             NaN   Kolkata 700124
# ..                                            ...              ...
# 263  700+ people booked this OYO in last 6 months          Kolkata
# 264            All staff vaccinated with 1st dose          Kolkata
# 265                                           NaN          Kolkata
# 266                                           NaN          Kolkata
# 267   11 people booked this hotel in last 6 hours          Kolkata
#
# [268 rows x 10 columns]

# %%
df1['Address']
# Out:
# 0                Near Deshapriya Park, Kalighat, Kolkata
# 1                              East Topsia Road, Kolkata
# 2                               Near Gst Bhawan, Kolkata
# 3      Near Axis Mall, CE Block, Newtown, Kolkata 700156
# 4                     72/1, Jessore road, Kolkata 700124
#                              ...
# 263                           Cl Block Saltlake, Kolkata
# 264                                    Sector-1, Kolkata
# 265                       Near Bosepukur, Kasba, Kolkata
# 266            Ayeshpur Near flipkart warehouse, Kolkata
# 267                                  Beniapukur, Kolkata
# Name: Address, Length: 268, dtype: object

# %%
city = []
for i in df1['Address']:
    city.append(i.split())
city
# Out:
# [['Near', 'Deshapriya', 'Park,', 'Kalighat,', 'Kolkata'],
#  ['East', 'Topsia', 'Road,', 'Kolkata'],
#  ['Near', 'Gst', 'Bhawan,', 'Kolkata'],
#  ['Near', 'Axis', 'Mall,', 'CE', 'Block,', 'Newtown,', 'Kolkata', '700156'],
#  ['72/1,', 'Jessore', 'road,', 'Kolkata', '700124'],
#  ['Kolkata',
#   'International',
#   'Airport',
#   'Gate',
#   'no',
#   '2,',
#   'Beside',
#   'Phoenix',
#   'Hospital',
#   '&',
#   'Diagnostics',
#   '11',
#   'Nirmal',
#   'Sengupta',
#   'Sarani',
#   'Kolkata',
#   'West',
#   'Bengal'],
#  ['Near', 'Bypass', 'Connector,', 'Kolkata'],
#  ['West', 'Bengal,', 'Kolkata'],
#  ['NEW',
#   'TOWN',
#   'ACTION',
#   'AREA',
#   '2',
#   'DLF',
#   '2',
#   'NEAR',
#   'CHITRAKUT',
#   'HEIGHTS',
#   'LASKARAIT',
#   'BAZAR',
#   'ROAD',
#   'CANAL',
#   'BANK',
#   'ROAD',
#   'SHAPOORJI',
#   'BUS',
#   'STAND'],
#  ['Mukundapur',
#   'Main',
#   'Road',
#   'Seven',
#   'Maddox',
#   'Square',
#   'Multi',
#   'cuisine',
#   'Restaurant',
#   'Kolkata',
#   'EM',
#   'Bye',
#   'Pass',
#   'Opposite',
#   'Dr.',
#   'Devi',
#   'Shetty',
#   'Hospital'],
#  ['Kolkata', '-', ',', 'Kolkata'],
#  ['KOLKATA', '700099', 'BESIDE', 'YAMAHA', 'SHOWROOM.,', 'Kolkata'],
#  ['Aa', 'Iid,', 'Kolkata'],
#  ['STREET',
#   'NO',
#   '568',
#   'BLOCK',
#   'AA',
#   '-',
#   '2B',
#   'AKANKHA',
#   'MORE,',
#   'NEW',
#   'TOWN',
#   'KOLKATA',
#   '-',
#   '700135',
#   'NAER',
#   'HP',
#   'PETROL',
#   'PUMP'],
#  ['Opposite',
#   'New',
#   'Alipore',
#   'Residency,',
#   'Near',
#   'New',
#   'Alipore',
#   'Petrol',
#   'Pump'],
#  ['Near', 'Raj', 'Market,', 'Kolkata'],
#  [',', 'Kolkata'],
#  ['Kolkata,', 'Kolkata'],
#  ['Nayabad,', 'Kolkata'],
#  ['Near',
#   'Topsia',
#   'More,',
#   'beside',
#   'Roshan',
#   'Garden',
#   '&',
#   'Orchid',
#   'Banquet,',
#   'Science',
#   'City',
#   'area,',
#   'Kolkata'],
#  ['DPS',
#   'Megacity',
#   'beside',
#   'Indian',
#   'Oil',
#   'petrol',
#   'pump',
#   'New',
#   'Town',
#   'Rajarhat'],
#  ['Akankha',
#   'More',
#   'NKDA',
#   'Community',
#   'Hall',
#   'Street',
#   'no',
#   '632',
#   'Plot',
#   'No',
#   '3209',
#   'New',
#   'Town',
#   'Action',
#   'Area',
#   '2C'],
#  ['595,',
#   'Rajdanga',
#   'main',
#   'road,',
#   'Near',
#   'KMDA',
#   'office',
#   'Kolkata,',
#   '700107'],
#  ['Hussainpur,', 'Kolkata'],
#  ['North', '24', 'Parganas,', 'Kolkata'],
#  ['Near', 'Acropolis', 'Mall,', 'Purba', 'Abasan,', 'Kolkata'],
#  ['Howrah,', 'Kolkata'],
#  ['Kolkata,', 'Kolkata'],
#  ['Near', 'Akankha', 'More,', 'Kolkata'],
#  ['East', 'Topsia', 'Road,', 'Kolkata'],
#  ['Kolkata,', 'Kolkata'],
#  ['Near', 'Barrackpore', 'City', 'Hospital,', 'Barrackpore,', 'Kolkata'],
#  ['Near', 'Buxarah', 'Road,', 'Howrah,', 'Kolkata'],
#  ['Action', 'Area', 'IIE,', 'Kolkata'],
#  ['Near', 'Tagore', 'Park,', 'Kasba,', 'Kolkata'],
#  ['New',
#   'Town',
#   'School',
#   'Tank',
#   'No',
#   '7',
#   'Action',
#   'Area',
#   '1,',
#   'DD',
#   '240',
#   'Street',
#   'No',
#   '277',
#   'Kolkata',
#   'West',
#   'Bengal'],
#  ['Near', 'Vivekananda', 'Park,', 'Mukundapur,', 'Kolkata'],
#  ['Chinar',
#   'Park,',
#   'Kali',
#   'Park,',
#   'Bablatala',
#   'Petrol',
#   'Pump,',
#   'Near',
#   'Indian',
#   'Gas',
#   'Office,',
#   'Gopalpur,',
#   'Kolkata',
#   '-',
#   '700136'],
#  ['CL',
#   '246,',
#   'CL',
#   'Block,',
#   'Saltlake',
#   'Sector',
#   '2',
#   'Near',
#   'Sector',
#   '5',
#   'Metro',
#   'Station'],
#  ['Near', 'Deshapriya', 'Park,', 'Kalighat,', 'Kolkata'],
#  ['Near', 'Deshapriya', 'Park,', 'Kalighat,', 'Kolkata'],
#  ['Salt', 'Lake', 'Sector', ':2,', 'Kolkata'],
#  ['Gopalpur', 'I,', 'Kolkata'],
#  ['Saltlake', 'Sector', '2,', 'Kolkata'],
#  ['Akankha,', 'Newtown,', 'Action', 'Area', 'II-', 'B'],
#  ['New', 'Airport', 'Punjab', 'Dhaba'],
#  ['Action', 'Area', 'I,', 'Kolkata'],
#  ['Bablatola', 'Opposite', 'Of', 'Bajaj', 'Showroom,', 'Kolkata'],
#  ['Thakurpukur,', 'Kolkata'],
#  ['Near', 'Shree', 'Krishna', 'Medical', 'Store,', 'Kolkata'],
#  ['Near', 'Mukundapur', 'Colony,', 'Mukundapur,', 'Kolkata'],
#  ['Ghola', 'Taki', 'Road,', 'Kolkata'],
#  [',', 'Kolkata'],
#  ['Newtown,', 'Kolkata'],
#  ['Rajarhat', 'Newtown,', 'Kolkata'],
#  ['West', 'Bengal', ',', 'Kolkata'],
#  ['Kolkata,', 'Kolkata'],
#  ['Aa', 'Iid,', 'Kolkata'],
#  ['72/1,', 'Jessore', 'road,', 'Kolkata', '700124'],
#  ['Indianull,', 'Kolkata'],
#  ['West', 'Bengal,', 'Kolkata'],
#  ['Opposite',
#   'Indiranagar',
#   'Indian',
#   'Oil',
#   'Petrol',
#   'Pump,',
#   'Rajarhat',
#   'Main',
#   'Road,',
#   '3rd',
#   'Floor',
#   'Above',
#   'Bank',
#   'of',
#   'Baroda'],
#  ['Near', 'Chingrighata', 'EM-Bypass', 'crossing'],
#  ['TN',
#   'MUKHERJEE',
#   'ROAD',
#   'DANKUNI',
#   'NEAR',
#   'AXIS',
#   'BANK',
#   '712311,',
#   'Kolkata'],
#  ['Mukundapur',
#   'Main',
#   'Road',
#   'Seven',
#   'Maddox',
#   'Square',
#   'Multi',
#   'cuisine',
#   'Restaurant',
#   'Kolkata',
#   'EM',
#   'Bye',
#   'Pass',
#   'Opposite',
#   'Dr.',
#   'Devi',
#   'Shetty',
#   'Hospital'],
#  ['Near', 'SBI', 'E-Corner,', 'Kolkata'],
#  ['Near', 'HP', 'Petrol', 'Pump,', 'Kolkata'],
#  ['Street',
#   'Number',
#   '715,',
#   'Tali',
#   'Park,',
#   'Action',
#   'Area',
#   'IID,',
#   'Newtown,',
#   'New',
#   'Town',
#   'Near',
#   'Eco',
#   'Children',
#   'Park',
#   'City',
#   'Centre',
#   '2',
#   'Kolkata',
#   'International',
#   'Airport,',
#   'West',
#   'Bengal',
#   '700052'],
#  ['New', 'Town,', 'Rajarhat,', 'Biswabangla', 'Gate'],
#  ['KOLKATA', '700099', 'BESIDE', 'YAMAHA', 'SHOWROOM.,', 'Kolkata'],
#  ['STREET',
#   'NO',
#   '568',
#   'BLOCK',
#   'AA',
#   '-',
#   '2B',
#   'AKANKHA',
#   'MORE,',
#   'NEW',
#   'TOWN',
#   'KOLKATA',
#   '-',
#   '700135',
#   'NAER',
#   'HP',
#   'PETROL',
#   'PUMP'],
#  ['kajibari', 'Jagannath', 'pur,', 'Kolkata'],
#  ['288/2,',
#   'Block-',
#   'B,',
#   'Binoy',
#   'Krishna',
#   'Bhawan,',
#   'Bangur',
#   'Avenue,',
#   'Kolkata,',
#   '700055'],
#  ['Julpia,', 'Kolkata'],
#  ['Near', 'R.N.Tagore', 'Hospital,', 'Nitainagar,', 'Kolkata'],
#  ['Dum', 'Dum', 'Park,', 'Kolkata'],
#  ['Purba', 'Diganta,', 'Kolkata'],
#  ['Gopalpur,',
#   'Narayanpur,',
#   'Netaji',
#   'Sangha',
#   'Swimming',
#   'Pool',
#   'Rajarhat',
#   'Chinar',
#   'Park,',
#   'Kolkata',
#   'Airport',
#   ','],
#  ['India', ',', 'Kolkata'],
#  ['Rajarhat',
#   'Reckjeoni',
#   'Chowmatha',
#   'City',
#   'Centre',
#   '2,',
#   'Bank',
#   'Of',
#   'India'],
#  ['New', 'Town', 'West', 'Bengal,', 'Kolkata'],
#  ['DE',
#   '150,',
#   'Street',
#   'number',
#   '336,',
#   'DE',
#   'Block,',
#   'Newton',
#   'action',
#   'area',
#   '1',
#   'Kolkata,',
#   '700156'],
#  ['Kolkata-700107,', 'Kolkata'],
#  ['Above', 'Bank', 'Of', 'Baroda,', 'Kolkata'],
#  ['41/6,',
#   'kendua',
#   'main',
#   'road',
#   'Garia,',
#   'kolkata-700047',
#   'Behind',
#   'K.K.',
#   'DAS',
#   'College,',
#   'Patuli'],
#  ['Kolkata,', 'Kolkata'],
#  ['Near',
#   'Uniworld',
#   'City,',
#   'New',
#   'Town,',
#   'Action',
#   'Area',
#   'III,',
#   'Kolkata-',
#   '700160'],
#  ['Behind',
#   'City',
#   'Center',
#   '2,',
#   'Rajarhat',
#   'New',
#   'Town',
#   'Action',
#   'Area',
#   '2D',
#   'Street',
#   'No',
#   '723',
#   'Plot',
#   'No',
#   '2504',
#   'Tali',
#   'Park',
#   ',',
#   'Kolkata,',
#   'West',
#   'Bengal'],
#  ['Rajarhat,', 'Kolkata'],
#  ['953',
#   'Purbachal',
#   'Road',
#   'adapt',
#   'House',
#   'Prince',
#   'Park',
#   'Kalikapur',
#   '(in',
#   'lane',
#   'between',
#   'Tata',
#   'chroma',
#   'showroom',
#   '&',
#   'Yamaha',
#   'Moters',
#   'Showroom'],
#  ['Near',
#   'Mukundapur',
#   'Bus',
#   'Stop',
#   'R.N',
#   'Tagore',
#   'Institute',
#   'of',
#   'Cardiac',
#   'Sciences,',
#   'Narayana',
#   'Health,',
#   'Kolkata'],
#  ['North', '24', 'Parganas,', 'Kolkata'],
#  ['Jothbhim',
#   'main',
#   'Rd,',
#   'jodthbhim',
#   'newtown',
#   'new',
#   'Town',
#   'kolkata',
#   'West',
#   'Bengal',
#   'india',
#   '700156'],
#  ['Avisar', 'Spencer', 'Kalikapur'],
#  ['Sakher', 'Bazar', 'Kolkata', 'West', 'Bengal', 'India,', 'Kolkata'],
#  ['AL/15,',
#   'new',
#   'town,',
#   'action',
#   'area',
#   '1,',
#   'near',
#   '3',
#   'no.',
#   'tank,',
#   'Kolkata'],
#  ['Chinar',
#   'Park',
#   'Kolkata',
#   'International',
#   'Airport',
#   'Beside',
#   'Spencers',
#   'Rajarhat',
#   'Main',
#   'Road'],
#  ['Action', 'Area', 'IIB,', 'Kolkata'],
#  ['Saltlake,', 'Kolkata'],
#  ['Near', 'Vidyasagar', 'Hospital,', 'Kolkata'],
#  ['Near', 'Bata', 'More,', 'Royd', 'Street,', 'Kolkata'],
#  ['India', '-', '.', ',', 'Kolkata'],
#  ['Kolkata',
#   'Opposite',
#   'Bangladesh',
#   'High',
#   'Commission)',
#   'Near',
#   'A.J.C',
#   'Bose',
#   'Flyover'],
#  ['Tollygunge,', 'Kolkata'],
#  ['Near', 'Oxfoard', 'House', 'School', ',', 'Kolkata'],
#  ['New', 'Town,', 'Kolkata'],
#  ['Action', 'Area', 'I,', 'Kolkata'],
#  ['VIP',
#   'Road',
#   'Baguihati',
#   'Kolkata',
#   'Airport',
#   'Near',
#   'Ladies',
#   'Hostel,',
#   'Narayantala'],
#  ['Jadavpur,', 'Kolkata'],
#  ['India', '-', ',', 'Kolkata'],
#  ['Near',
#   'Uniworld',
#   'City',
#   ',',
#   'New',
#   'Town,',
#   'Action',
#   'Area',
#   'III,',
#   'Kolkata-',
#   '700160'],
#  ['Near', 'Acropolis', 'Mall,', 'Rajdanga', 'Main', 'Road,', 'Kolkata'],
#  ['Chinar', 'Park,', 'Kolkata'],
#  ['Kolkata',
#   'International',
#   'Airport,',
#   'Chinar',
#   'Park',
#   'New',
#   'Town',
#   'Rajarhat',
#   'Near',
#   'Dashdrone',
#   'Bus',
#   'Stop'],
#  ['Kolkata', '-', ',', 'Kolkata'],
#  ['Newtown,', 'Kolkata'],
#  ['Unitech', 'gate', '1', 'bus', 'stop', 'vangar', 'more,', 'Kolkata'],
#  [',', 'Kolkata'],
#  ['AA', 'II,', 'Kolkata'],
#  ['Above', 'Reliance', 'Trends,', 'Raghunathpur,', 'Kolkata'],
#  ['Opposite', 'Hotel', 'Swagath,', 'Kolkata'],
#  ['Near', 'Airport', 'Gate', 'No', '2,', 'Kolkata'],
#  ['Uttar', 'Panchanna', 'Gram,', 'Kolkata'],
#  ['Near', 'Near', 'Salt', 'Lake,', 'Sector', '2,', 'Kolkata'],
#  ['West', 'Bengal', 'Kolkata', 'West', 'BengalIndia,', 'Kolkata'],
#  ['700', '156,', 'Kolkata'],
#  ['Action',
#   'Area',
#   '2B,',
#   'Inside',
#   'Urban',
#   'Village,',
#   'Opposite',
#   'Eco',
#   'Park,',
#   'Newtown,',
#   'Kolkata,',
#   'West',
#   'Bengal'],
#  ['Near', 'Sealdah', 'railway', 'station,', 'Sealdah,', 'Kolkata'],
#  ['Westin',
#   'Near',
#   'Eco',
#   'Park',
#   'Gate',
#   'No',
#   '1',
#   'New',
#   'Town',
#   'Biswa',
#   'Bangla',
#   'Gate'],
#  ['Howrah,', 'Kolkata'],
#  ['FD',
#   '390',
#   'SECTOR',
#   '3',
#   'SALT',
#   'LAKE',
#   'CENTRAL',
#   'PARK',
#   'MANI',
#   'SQUARE',
#   'CITY',
#   'CENTRE',
#   '1'],
#  ['North', '24', 'Parganas,', 'Kolkata'],
#  ['Dum', 'Dum,', 'Kolkata'],
#  ['Rajarhat,', 'Kolkata'],
#  ['Street',
#   'No.510',
#   'Opposite',
#   'Peabody',
#   'Building',
#   'Action',
#   'Area',
#   '2b',
#   'Newtown',
#   'Near',
#   'Aakankha',
#   'Petrol',
#   'Pump,',
#   'Kolkata'],
#  ['Near', 'Sector', 'II,', 'Bidhannagar,', 'Kolkata'],
#  ['Salt', 'Lake,', 'Kolkata'],
#  ['India,', 'Kolkata'],
#  ['49/A,',
#   'G',
#   'T',
#   'Road',
#   'East',
#   'Rishra',
#   'HOOGHLY,',
#   'Near',
#   'Punjab',
#   'National',
#   'Bank'],
#  ['Near', 'BSNL', 'Office', ',', 'Bhawanipore,', 'Kolkata'],
#  ['Biswa',
#   'Bangla',
#   'Sarani',
#   'Behind',
#   'Binany',
#   'Building,',
#   'Chinar',
#   'Park,',
#   'Beside',
#   'NPG',
#   'Hotel,',
#   'Nibedita',
#   'Apartment',
#   ',',
#   'Kolkata',
#   '700157'],
#  ['Near', 'Amri', 'Hospital,', 'South', 'End', 'Park', 'Road,', 'Kolkata'],
#  ['Ward', '107,', 'Kolkata'],
#  ['Stand', 'Road,', 'Kolkata'],
#  ['Near',
#   'Chinar',
#   'Park',
#   'Dash',
#   'Drone,',
#   'Newtown',
#   'Kolkata',
#   'Airport,',
#   'Urban',
#   'Green',
#   'Kolkata',
#   'City',
#   'Centre',
#   '2'],
#  ['Near', 'Croma', 'Showroom,', 'Kolkata'],
#  ['Choumatha,', 'Kolkata'],
#  ['Near',
#   'Bus',
#   'Stand,',
#   'Anandaloke',
#   'Hospital,',
#   'Cl',
#   'Block,',
#   'Kolkata'],
#  ['Kolkata,', 'Kolkata'],
#  ['Near', 'Park', 'street', 'area'],
#  ['Saltlake', 'Sector', '1,', 'Kolkata'],
#  ['AI',
#   '87',
#   'Street',
#   'No',
#   '23',
#   'Action',
#   'Area',
#   '1',
#   'Newtown,',
#   'Rajarhat'],
#  ['AI',
#   '-',
#   '34,',
#   'Street',
#   'No',
#   '-',
#   '33,',
#   'Tank',
#   'No-3,',
#   'Newtown',
#   'Rajarhat'],
#  ['Action', 'Area', 'I,', 'Kolkata'],
#  ['Bidhannagar,', 'Kolkata'],
#  ['Kolkata-700064,', 'Kolkata'],
#  ['AI', 'Block,', 'Near', 'Tank', 'No', '3,', 'Newtown,', 'Kolkata'],
#  ['Esplanade',
#   'Row',
#   'East',
#   'Beside',
#   'K.',
#   'c',
#   'Das',
#   'Sweet',
#   'Esplanade',
#   'Post',
#   'Office,',
#   'Kolkata'],
#  ['Near',
#   'Topsia',
#   'More,',
#   'beside',
#   'Roshan',
#   'Garden',
#   '&',
#   'Orchid',
#   'Banquet,',
#   'Science',
#   'City',
#   'area,',
#   'Kolkata'],
#  ['Near', 'Action', 'Area', 'I,', 'New', 'Town,', 'Kolkata'],
#  ['Sealdah', '-', 'Entally,', 'Kolkata'],
#  ['street',
#   'no',
#   '197',
#   'CC',
#   'block',
#   'Newtown',
#   'action',
#   'area',
#   '1',
#   'north',
#   '24',
#   'parganas,',
#   'Kolkata'],
#  ['Near',
#   'Biswabangla',
#   'Gate,',
#   'Beside',
#   'Newtown',
#   'School,',
#   'DD',
#   'Block,',
#   'Street',
#   'number',
#   '295'],
#  ['Opposite', 'ILS', 'Hospital,', 'Nagerbazar,', 'Kolkata.'],
#  ['North', '24', 'Paraganas,', 'Kolkata'],
#  ['Near', 'Raja', 'Santosh', 'Road,', 'Alipore,', 'Kolkata'],
#  ['Near', 'Barrackpore', 'Wireless', 'More,', 'Kolkata'],
#  ['Lindsay',
#   'Street',
#   'Khadya',
#   'Bhavan,',
#   'New',
#   'Market',
#   'Esplanade',
#   'Metro',
#   'Station',
#   'Kolkata'],
#  ['Near',
#   'Metro',
#   'Station,',
#   'Rabindra',
#   'Tirtha,',
#   'Street',
#   'No121,',
#   'Kolkata'],
#  ['Kalyani',
#   'expressway',
#   'near',
#   'sodepur',
#   'Muragaccha',
#   'More,',
#   'madahyamgram',
#   'road,',
#   'kolkata-700110'],
#  ['Kasba,', 'Kolkata'],
#  ['Kolkata',
#   'International',
#   'Airport,',
#   'Belghoria',
#   'Express',
#   'Way',
#   'Noapara',
#   '&',
#   'Baranagar',
#   'Metro',
#   'Station'],
#  ['Near', 'Metropolitan', 'More,', 'Bypass,', 'Kolkata'],
#  ['Near', 'Alipore', 'guest', 'House,', 'Mangalam,', 'Kolkata'],
#  ['AA-IIB/424,',
#   'Street',
#   'No.-',
#   '511,',
#   'OWL',
#   'More,',
#   'In',
#   'Front',
#   'Of',
#   'ECO',
#   'Park,',
#   'New',
#   'Town,',
#   'Action',
#   'Area-IIB'],
#  ['Behind', 'Aahirini', 'Market,', 'Newtown,', 'Kolkata'],
#  ['Near', 'Acropolis', 'Mall,', 'Kolkata'],
#  ['Near', 'New', 'Alipore', 'Residency,', 'Behala,', 'Kolkata'],
#  ['40/4,',
#   'Selimpur',
#   'Petrol',
#   'Pump,',
#   'Jodhpur',
#   'Park,',
#   'Gariahat',
#   'Road',
#   '(South),',
#   'Kolkata'],
#  ['Kolkata', 'International', 'Airport', 'Gate', 'No', '1'],
#  ['Opp', 'Gariahat', 'Police', 'Station,', 'Kolkata'],
#  ['Park', 'Circus,', 'Kolkata'],
#  ['Salt', 'Lake', 'City,', 'Kolkata'],
#  ['Esplanade,', 'Kolkata'],
#  ['Action',
#   'Area',
#   '2D',
#   'New',
#   'Town',
#   'Owl',
#   'More',
#   'Eco',
#   'Space',
#   'Street',
#   'no',
#   '-',
#   '523',
#   '&',
#   '548,',
#   'Plot',
#   'No',
#   '140,',
#   'Block',
#   '-',
#   'AA',
#   '-',
#   'llBB',
#   'Kolkata,',
#   'West',
#   'Bengal'],
#  ['India,', 'Kolkata'],
#  ['700017,', 'Kolkata'],
#  ['4th',
#   'avenue',
#   'FF',
#   'block',
#   'Bhangar-',
#   'II',
#   'south',
#   '24',
#   'Parganas',
#   'west',
#   'Bengal',
#   'India',
#   'Kolkata',
#   'west',
#   'Bengal',
#   'India',
#   '700091'],
#  ['Ballygunge,', 'Kolkata'],
#  ['Bidhannagar,', 'Kolkata'],
#  ['Esplanade,', 'Kolkata'],
#  ['Braunfield', 'Road', 'Mominpore', 'Kolkata,', 'Kolkata'],
#  ['12/2',
#   'A,',
#   'KYD',
#   'street',
#   'near',
#   'MLA',
#   'Hostel,',
#   'Kolkata,',
#   '700016'],
#  ['Near', 'CK', 'CL', 'park', 'club,', 'CK', 'Block,', 'Kolkata'],
#  ['Grand', 'Trunk', 'Road,', 'Belur', 'Math,Kolkata'],
#  [',', 'Kolkata'],
#  ['Kolkata',
#   'International',
#   'Airport',
#   'Gate',
#   'No',
#   '1',
#   'Jessore',
#   'Road,',
#   'Dum',
#   'Dum,',
#   'Kolkata'],
#  ['Beniapukur,', 'Kolkata'],
#  ['Tagore', 'Park,', 'Kolkata'],
#  ['Jatin', 'Das', 'Road,', 'Kolkata'],
#  ['India', '.,', 'Kolkata'],
#  ['Bangur',
#   'Avenue',
#   'Block',
#   'B,',
#   'Kolkata',
#   'Kolkata',
#   'West',
#   'Bengal,',
#   'India',
#   '700055'],
#  ['TCS', 'Gitobitan,', 'Kolkata'],
#  ['AI',
#   '30,',
#   'Street',
#   'Number',
#   '33,',
#   'Behind',
#   'New',
#   'Town',
#   'Bus',
#   'Stand,',
#   'New',
#   'Town,',
#   'Kolkata'],
#  ['Near', 'Quest', 'Mall,', 'Karaya', 'Road,', 'Kolkata'],
#  ['West', 'Bengal', 'Kolkata', 'West', 'Bengalindian,', 'Kolkata'],
#  ['21,', 'AINUDDIN', 'GHAT', 'MAJHI', 'LANE,', 'HOWRAH'],
#  ['Sector', 'III,', 'Kolkata'],
#  ['NEAR',
#   'NEW',
#   'TOWN',
#   'BUS',
#   'STAND',
#   'AHIRINI',
#   'MARKET',
#   'DLF1',
#   'ACTION',
#   'AREA',
#   '1'],
#  ['Hazra', 'Road,', 'Kolkata'],
#  ['Near',
#   'Acropolis',
#   'Mall,',
#   'Rene',
#   'Tower,',
#   'Garden',
#   'High',
#   'school',
#   'Kasba'],
#  ['Near', 'Acropolis', 'Mall,', 'Kolkata'],
#  ['Kaikhali',
#   'Main',
#   'Road',
#   'Near',
#   'Chiriamore',
#   'Maa',
#   'Sarada',
#   'Nursing',
#   'Home,',
#   'Kolkata'],
#  ['Shantipally,', 'Kolkata'],
#  ['318,Shanti',
#   'Pally,',
#   'Kasba,',
#   'Behind',
#   'Acropolis',
#   'Mall,',
#   'Near',
#   'Siemens',
#   'Bus',
#   'Stop'],
#  ['Action', 'Area', 'I,', 'Kolkata'],
#  ['Kasbah', 'North,', 'Kolkata'],
#  ['Near', 'Jameson', 'Inn,', 'Park', 'St,', 'Kolkata'],
#  ['Near', 'Emami', 'City,', 'Nagerbazar,', 'Dum', 'Dum,', 'Kolkata'],
#  ['Sector', 'V,', 'Kolkata'],
#  ['Near',
#   'Opposite',
#   'To',
#   'Hotel',
#   'Moon',
#   'Light,',
#   'Bediapara,',
#   'Kolkata'],
#  ['Near', 'Ladies', 'Park,', 'Beniapukur,', 'Kolkata'],
#  ['Near', 'Akankha', 'More', 'Hp', 'Petrol', 'Pump,', 'Newtown,', 'Kolkata'],
#  ['Near', 'GST', 'Bhawan,', 'Ruby,', 'Acropolis', 'Mall'],
#  ['Behind',
#   'New',
#   'Life',
#   'Nurshing',
#   'Home,',
#   'Oppssite',
#   'Arati',
#   'cinema,',
#   'Sahabagan,',
#   'Kolkata'],
#  ['Behind',
#   'Binayak',
#   'Marriage',
#   'Hall',
#   'Beside',
#   'Sayambor',
#   'Hall,',
#   'Kolkata'],
#  ['Near', 'Dhan', 'Math,', 'Kolkata'],
#  ['29/2',
#   'Sayan',
#   'Abasan,',
#   'Nishi',
#   'Kanan,',
#   'Beside',
#   'AR',
#   'Motors,',
#   'Chinar',
#   'Park,',
#   'Kolkata'],
#  ['Near', 'Sector', '1,', 'Bidhan', 'Nagar,', 'Kolkata'],
#  ['Spandan',
#   'Nursing',
#   'Home,',
#   'Kali',
#   'Bari',
#   'Complex',
#   'Rd,',
#   'Reekjoyoni,',
#   'Kolkata,',
#   'West',
#   'Bengal',
#   '700135',
#   'Rajarhat',
#   'Main',
#   'Road',
#   'SRCM',
#   'Road,',
#   'Rajarhat',
#   'Chowmatha',
#   'Bhatenda',
#   'Matiagachha,'],
#  ['VIP',
#   'Road',
#   'Kaikhali',
#   'Taxi',
#   'Stand',
#   'Kolkata',
#   'International',
#   'Airport,',
#   'Kolkata',
#   '700052,',
#   'West',
#   'Bengal'],
#  ['Rajarhat,', 'Kolkata'],
#  ['Near', 'PVR', 'Diamond', 'Plaza,', 'Kidwai', 'Road,', 'Kolkata'],
#  ['India', '700100,', 'Kolkata'],
#  ['Near',
#   'Sarojini',
#   'Naidu',
#   'College',
#   'for',
#   'Women,',
#   'Golpark,',
#   'Dumdum',
#   'Kolkata'],
#  ['T.',
#   'N.',
#   'Mukherjee',
#   'Road,',
#   'Near',
#   'Dankuni',
#   'Housing',
#   '&',
#   'Above',
#   'Lakhotia',
#   'Medical',
#   'Centre',
#   'Dankuni,',
#   'Hooghly',
#   'West',
#   'Bengal'],
#  ['Near', 'FD', 'Block,', 'Bidhannagar,', 'Kolkata'],
#  ['Near', 'Acropolis', 'Mall,', 'Kashba,', 'Kolkata'],
#  ['Near', 'Sector-v', 'Metro', 'Station,', 'Kolkata'],
#  ['Manoharpukur', 'Road,', 'Kolkata'],
#  ['Near', 'EDEN', 'GROUP', 'BUILDING,', 'Manoharpukur,', 'Kolkata'],
#  ['Near', 'Ankurhati', 'check', 'post,', 'Biswaspara,', 'Kolkata'],
#  ['DL-34',
#   'Karunamoyee',
#   'Near',
#   'Anandalok',
#   'Hospital',
#   'Bidhannagar',
#   'Saltlake'],
#  ['Near', 'College', 'Road,', 'Shalimar,', 'Kolkata'],
#  ['Off', 'Park', 'Street,', 'Kolkata'],
#  ['Near', 'Laxminarayan', 'Temple,', 'Sarat', 'Bose', 'Road,', 'Kolkata'],
#  ['Near',
#   'Howrah',
#   'railway',
#   'station,',
#   'Howrah',
#   'AC',
#   'Market,',
#   'Kolkata'],
#  ['Near',
#   'ILS',
#   'Hospitals',
#   'Dum',
#   'Dum',
#   'Nagerbazar',
#   'Opposite',
#   'Bhutan',
#   'House,',
#   'Kolkata'],
#  ['Near', 'South', 'City', 'Business', 'Park,', 'Anandapur,', 'Kolkata'],
#  ['Near', 'Beliaghata', 'lake', 'side', 'club,', 'Phool', 'Bagan,', 'Kolkata'],
#  ['Near', 'AA1,', 'Newtown,', 'Kolkata'],
#  ['Saltlake,', 'Kolkata'],
#  ['Karunamoyee', 'Bus', 'Terminal,', 'Bidhannagar,', 'Kolkata'],
#  ['Belghoriya',
#   'Expy',
#   'and',
#   'Jessore',
#   'Rd',
#   'connector',
#   '3',
#   'No',
#   'Kolkata',
#   'International',
#   'Airport,',
#   'West',
#   'Bengal,',
#   'Kolkata,',
#   '700079'],
#  ['Kaikhali',
#   'Above',
#   'IndusInd',
#   'Bank',
#   'ATM',
#   'Kolkata',
#   'International',
#   'Airport',
#   '02',
#   'Hotel',
#   'VIP',
#   'Road'],
#  ['Near', 'city', 'college', 'Opp', '68', 'Satsang', 'Ashram', 'Kolkata'],
#  ['Sector', 'V', 'Kolkata', 'West', 'Bengal,', 'Kolkata'],
#  ['Haora,', 'Kolkata'],
#  ['Chinarpark', 'Amenia;', 'Arsalan'],
#  ['IB-66,',
#   'Saltlake',
#   'Sec-III,',
#   'Near',
#   'Amri',
#   'Hospital,',
#   'Smart',
#   'Bazaar,',
#   'Saltlake',
#   'Stadium,',
#   'Kolkata,',
#   'India'],
#  ['Beside', 'Yogayog', 'Bhavan,', 'Kolkata'],
#  ['Near', 'College', 'Street,', 'MG', 'Road,', 'Kolkata'],
#  ['North', '24', 'Parganas,', 'Kolkata'],
#  ['Cl', 'Block', 'Saltlake,', 'Kolkata'],
#  ['Sector-1,', 'Kolkata'],
#  ['Near', 'Bosepukur,', 'Kasba,', 'Kolkata'],
#  ['Ayeshpur', 'Near', 'flipkart', 'warehouse,', 'Kolkata'],
#  ['Beniapukur,', 'Kolkata']]

# %%
City = []
for i in city:
    if i == "Kolkata":
        City.append(i)
    else:
        City.append("Kolkata")
City
# Out:
# ['Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata']

# %%
df1['City_Name']=City
df1
# Out:
#                                                 Hotels       Prices  \
# 0                                     OYO 11368 Dk Inn  1600.000000
# 1                 Townhouse Oak Hotel Lake View Royal   1133.000000
# 2             Flagship 701196 Sonar Bangla Guest House   599.000000
# 3                     Capital O 700752 Hotel Dak Plaza   634.000000
# 4                 Flagship 700875 Shyamali Guest House   625.000000
# ..                                                 ...          ...
# 263                  Flagship 13524 Swapan Guest House  1092.452381
# 264               OYO Townhouse 727 Hotel The Platinum  1092.452381
# 265                   Flagship 9662 Kajali Guest House  1092.452381
# 266  OYO Flagship 702311 Bigboss Hotel & Restaurant...  1092.452381
# 267                 OYO Townhouse 567 MB International  1092.452381
#
#      Total_Price   Ratings  Booking_Discounts(%)      Reviews  \
# 0    5714.000000  4.147458             72.000000  1767.000000
# 1    4045.000000  4.200000             71.000000   166.000000
# 2    2261.000000  4.147458             73.000000   158.000000
# 3    2262.000000  4.147458             71.000000   318.000000
# 4    2232.000000  4.147458             72.000000    53.000000
# ..           ...       ...                   ...          ...
# 263  3492.885714  4.147458             68.314286   348.000000
# 264  3492.885714  4.147458             68.314286  1738.000000
# 265  3492.885714  4.147458             68.314286    43.000000
# 266  3492.885714  4.147458             68.314286   787.530612
# 267  3492.885714  4.147458             68.314286  1845.000000
#
#              Facilities                                            Address  \
# 0             Elevator             Near Deshapriya Park, Kalighat, Kolkata
# 1            Reception                           East Topsia Road, Kolkata
# 2           Free Wi-Fi                            Near Gst Bhawan, Kolkata
# 3            Reception   Near Axis Mall, CE Block, Newtown, Kolkata 700156
# 4             Elevator                  72/1, Jessore road, Kolkata 700124
# ..                  ...                                                ...
# 263         Free Wi-Fi                          Cl Block Saltlake, Kolkata
# 264   Parking facility                                   Sector-1, Kolkata
# 265         Free Wi-Fi                      Near Bosepukur, Kasba, Kolkata
# 266                 AC           Ayeshpur Near flipkart warehouse, Kolkata
# 267   Parking facility                                 Beniapukur, Kolkata
#
#                                      Informations City_Name
# 0              All staff vaccinated with 1st dose   Kolkata
# 1     14 people booked this hotel in last 6 hours   Kolkata
# 2                        Hurry, Only 1 room left!   Kolkata
# 3      6 people booked this hotel in last 6 hours   Kolkata
# 4                                             NaN   Kolkata
# ..                                            ...       ...
# 263  700+ people booked this OYO in last 6 months   Kolkata
# 264            All staff vaccinated with 1st dose   Kolkata
# 265                                           NaN   Kolkata
# 266                                           NaN   Kolkata
# 267   11 people booked this hotel in last 6 hours   Kolkata
#
# [268 rows x 10 columns]

# %%
df1.to_csv('Oyo Hotels Kolkata.csv',index=False)

# %%
df1 = pd.read_csv('Oyo Hotels Kolkata.csv')
df1
# Out:
#                                                 Hotels       Prices  \
# 0                                     OYO 11368 Dk Inn  1600.000000
# 1                 Townhouse Oak Hotel Lake View Royal   1133.000000
# 2             Flagship 701196 Sonar Bangla Guest House   599.000000
# 3                     Capital O 700752 Hotel Dak Plaza   634.000000
# 4                 Flagship 700875 Shyamali Guest House   625.000000
# ..                                                 ...          ...
# 263                  Flagship 13524 Swapan Guest House  1092.452381
# 264               OYO Townhouse 727 Hotel The Platinum  1092.452381
# 265                   Flagship 9662 Kajali Guest House  1092.452381
# 266  OYO Flagship 702311 Bigboss Hotel & Restaurant...  1092.452381
# 267                 OYO Townhouse 567 MB International  1092.452381
#
#      Total_Price   Ratings  Booking_Discounts(%)      Reviews  \
# 0    5714.000000  4.147458             72.000000  1767.000000
# 1    4045.000000  4.200000             71.000000   166.000000
# 2    2261.000000  4.147458             73.000000   158.000000
# 3    2262.000000  4.147458             71.000000   318.000000
# 4    2232.000000  4.147458             72.000000    53.000000
# ..           ...       ...                   ...          ...
# 263  3492.885714  4.147458             68.314286   348.000000
# 264  3492.885714  4.147458             68.314286  1738.000000
# 265  3492.885714  4.147458             68.314286    43.000000
# 266  3492.885714  4.147458             68.314286   787.530612
# 267  3492.885714  4.147458             68.314286  1845.000000
#
#              Facilities                                            Address  \
# 0             Elevator             Near Deshapriya Park, Kalighat, Kolkata
# 1            Reception                           East Topsia Road, Kolkata
# 2           Free Wi-Fi                            Near Gst Bhawan, Kolkata
# 3            Reception   Near Axis Mall, CE Block, Newtown, Kolkata 700156
# 4             Elevator                  72/1, Jessore road, Kolkata 700124
# ..                  ...                                                ...
# 263         Free Wi-Fi                          Cl Block Saltlake, Kolkata
# 264   Parking facility                                   Sector-1, Kolkata
# 265         Free Wi-Fi                      Near Bosepukur, Kasba, Kolkata
# 266                 AC           Ayeshpur Near flipkart warehouse, Kolkata
# 267   Parking facility                                 Beniapukur, Kolkata
#
#                                      Informations City_Name
# 0              All staff vaccinated with 1st dose   Kolkata
# 1     14 people booked this hotel in last 6 hours   Kolkata
# 2                        Hurry, Only 1 room left!   Kolkata
# 3      6 people booked this hotel in last 6 hours   Kolkata
# 4                                             NaN   Kolkata
# ..                                            ...       ...
# 263  700+ people booked this OYO in last 6 months   Kolkata
# 264            All staff vaccinated with 1st dose   Kolkata
# 265                                           NaN   Kolkata
# 266                                           NaN   Kolkata
# 267   11 people booked this hotel in last 6 hours   Kolkata
#
# [268 rows x 10 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 268 entries, 0 to 267
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Hotels                268 non-null    object
#  1   Prices                268 non-null    float64
#  2   Total_Price           268 non-null    float64
#  3   Ratings               268 non-null    float64
#  4   Booking_Discounts(%)  268 non-null    float64
#  5   Reviews               268 non-null    float64
#  6   Facilities            268 non-null    object
#  7   Address               268 non-null    object
#  8   Informations          154 non-null    object
#  9   City_Name             268 non-null    object
# dtypes: float64(5), object(5)
# memory usage: 21.1+ KB

# %%
df1.shape
# Out:
# (268, 10)

# %%
df1.describe()
# Out:
#             Prices   Total_Price     Ratings  Booking_Discounts(%)  \
# count   268.000000    268.000000  268.000000            268.000000
# mean   1092.452381   3492.885714    4.147458             68.314286
# std     435.379373   1335.965029    0.056327              3.962019
# min     400.000000   1428.000000    4.000000             47.000000
# 25%     755.250000   2609.750000    4.147458             65.000000
# 50%    1092.452381   3492.885714    4.147458             68.314286
# 75%    1257.000000   3851.250000    4.147458             71.000000
# max    3449.000000  10829.000000    4.400000             83.000000
#
#            Reviews
# count   268.000000
# mean    787.530612
# std    1131.066467
# min       2.000000
# 25%     114.750000
# 50%     412.000000
# 75%     853.750000
# max    8221.000000

# %%
df1.corr()
# Out:
#                         Prices  Total_Price   Ratings  Booking_Discounts(%)  \
# Prices                1.000000     0.937182  0.050936             -0.326619
# Total_Price           0.937182     1.000000  0.035392             -0.006308
# Ratings               0.050936     0.035392  1.000000             -0.036527
# Booking_Discounts(%) -0.326619    -0.006308 -0.036527              1.000000
# Reviews               0.131872     0.139444  0.017354              0.015318
#
#                        Reviews
# Prices                0.131872
# Total_Price           0.139444
# Ratings               0.017354
# Booking_Discounts(%)  0.015318
# Reviews               1.000000

# %%
df1.Hotels.value_counts()
# Out:
# OYO 11368 Dk Inn                             3
# Capital O 85376 Kabita Guest House           2
# Townhouse OAK 92847 Hotel Glorious Palace    2
# OYO 702008 Avenue Inn                        2
# OYO 82221 Hotel Regency                      2
#                                             ..
# OYO Townhouse 1127 Dream World Residency     1
# OYO Townhouse 209 Habitat New Town           1
# OYO 14778 G R Hospitality                    1
# OYO 82087 Sai Hospitality                    1
# OYO Townhouse 567 MB International           1
# Name: Hotels, Length: 255, dtype: int64

# %%
df1.duplicated().sum()
# Out:
# 13
